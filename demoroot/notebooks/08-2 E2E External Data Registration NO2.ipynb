# %% [markdown]
# # EOEPCA+ Use Case: NO2 Tropospheric Content Cloud Filtering - Register Input Data: NO2

# %% [markdown]
# # Table of Contents
#
# 1. Introduction
# 1. Get external data: Cloud Fraction
# 2. Apply STAC Best Practices
# 3. Save metadata to the EOEPCA Workspace
# 4. Register metadata to the EOEPCA STAC API
# 5. Access and process the data

# %% [markdown]
# # Introduction
#
# ## What happens in this notebook
# In this notebook the STAC Metadata of the Sentinel-5P NO2 Tropospheric Content Data is pulled from VITO Terrascope. Only the spatial extent of Europe is requested. The STAC Metadata is adapted to follow STAC Best Practices. Then the adapted metadata is registered to the EOEPCA STAC API. From there the processing building block can be used to process the data.

# %% [markdown]
# ![end2end_workflow](img/end2end_workflow_no2.png)

# %% [markdown]
# ```
# from odc.stac import stac_load
# import pystac
# from pystac import Item, Collection, Catalog, Extent, SpatialExtent, TemporalExtent, Asset
# from datetime import datetime
# from pystac_client import Client
# import requests
# ```

# %%
from pystac_client import Client
from odc.stac import stac_load
from pystac import Item, Collection, Catalog, Extent, SpatialExtent, TemporalExtent, Asset
from datetime import datetime
import numpy as np
import pandas as pd
import openeo
import certifi

# for workspace management
import requests
import jwt
import time
import boto3
import os
# Out:
# Warning 3: Cannot find gdalvrt.xsd (GDAL_DATA is not defined)

# %% [markdown]
# ## NO2 Tropospheric Content
#
# Get Tropospheric NO2 Content data from the VITO Terrascope STAC API.
#
# - S5P NO2 Tropospheric Content: terrascope-s5p-l3-no2-td-v2
# - https://stac.terrascope.be/collections/terrascope-s5p-l3-no2-td-v2
#
# Use Case: Regional DataCube: We are pulling STAC metadata from a collection containing all items with global coverage. We are extracting the spatial bbox we are intereseted in and provide this to the stac catalog/users. When users interact with the collection it is still fetched from the original source. But the extents are adapted.

# %% [markdown]
# References:
# - How to access NO2 tests: https://gist.github.com/soxofaan/67dfad89da88b9036ee301e410cd0ae7
# - In response to questions regarding credentials with Terrascope STAC download in notebook   https://github.com/EOEPCA/demo/blob/main/demoroot/notebooks/08%20Use%20Case%20External%20Data%20Registration.ipynb

# %% [markdown]
# ### Request

# %%
#url = "https://services.terrascope.be/stac/"
url = "https://stac.terrascope.be/"
catalog = Client.open(url)

# %%
# https://stac.terrascope.be/collections/terrascope-s5p-l3-no2-td-v2 --> STAC 1.1
# collection_id = "urn:eop:VITO:TERRASCOPE_S5P_L3_NO2_TD_V2" # stac 1.0

collection_id = "terrascope-s5p-l3-no2-td-v2" # stac 1.1
bbox = [3.0, 51.0, 4.0, 52.0]
bbox = [-10.0, 35.0, 30.0, 70.0]  # Europe
date_time = "2023-08-01T00:00:00Z/2023-12-31T23:59:59Z"

search = catalog.search(
    collections=[collection_id],
    bbox=bbox,
    datetime=date_time,
    limit=400,
)

# %%
items = list(search.items())
print(f"{len(items)=}")
# Out:
# len(items)=153

# %% [markdown]
# ### Check Data

# %% [markdown]
# Get asset URL of an item

# %%
items[0]
# Out:
# <Item id=S5P_OFFL_L3_NO2_TD_20231231_V200>

# %%
asset_url = items[0].assets["NO2"].href
asset_url
# Out:
# 'https://services.terrascope.be/download/Sentinel5P/L3_NO2_TD_V2/2023/12/S5P_OFFL_L3_NO2_TD_20231231_V200/S5P_NO2_TD_20231231_NO2_V200.tif'

# %% [markdown]
# Try to load as from GeoServer

# %%
ds = stac_load(
    items,
    #bands=["CF"], 
    crs="EPSG:4326",
    resolution=0.1,
    bbox=bbox,
    chunks={"time": 1} 
)

# %%
ds
# Out:
# <xarray.Dataset> Size: 171MB
# Dimensions:      (latitude: 350, longitude: 400, time: 153)
# Coordinates:
#   * latitude     (latitude) float64 3kB 69.95 69.85 69.75 ... 35.25 35.15 35.05
#   * longitude    (longitude) float64 3kB -9.95 -9.85 -9.75 ... 29.75 29.85 29.95
#     spatial_ref  int32 4B 4326
#   * time         (time) datetime64[ns] 1kB 2023-08-01T00:40:57 ... 2023-12-31...
# Data variables:
#     NO2          (time, latitude, longitude) float32 86MB dask.array<chunksize=(1, 350, 400), meta=np.ndarray>
#     NO2_WEIGHT   (time, latitude, longitude) float32 86MB dask.array<chunksize=(1, 350, 400), meta=np.ndarray>

# %%
monthly_mean_no2 = ds['NO2'].groupby('time.month').median(dim='time')

# %% [markdown]
# This is loading the data into memory. **Gives 401 Unauthorized.**

# %%
# %%time
monthly_mean_no2.plot(col="month",
    col_wrap=3,
    cmap="viridis",
    vmin=0,
    vmax=1,
    figsize=(12, 6),
    cbar_kwargs={"label": "NO2"}) # 401 unauthorized

# %% [markdown]
# ### Register to EOEPCA via Registration BB

# %% [markdown]
# For registration in EOEPCA create a catalogue and collection from these items.

# %%
print(len(items))
print(items[0])
print(items[-1])
# Out:
# 153
# <Item id=S5P_OFFL_L3_NO2_TD_20231231_V200>
# <Item id=S5P_OFFL_L3_NO2_TD_20230801_V200>

# %%
items[0].stac_extensions # there are already most extensions for the best practices
# Out:
# ['https://stac-extensions.github.io/product/v0.1.0/schema.json',
#  'https://stac-extensions.github.io/processing/v1.2.0/schema.json',
#  'https://stac-extensions.github.io/file/v2.1.0/schema.json',
#  'https://stac-extensions.github.io/raster/v2.0.0/schema.json',
#  'https://stac-extensions.github.io/projection/v2.0.0/schema.json',
#  'https://stac-extensions.github.io/alternate-assets/v1.2.0/schema.json',
#  'https://stac-extensions.github.io/authentication/v1.1.0/schema.json']

# %% [markdown]
# **DataCubeAccess BB:** Adapt collection and items to stac data cube access best practices, add them to the collection and save. Best Practices [here](https://github.com/EOEPCA/datacube-access/blob/main/best_practices/stac_best_practices.md).

# %% [markdown]
# Set a local folder for saving and name of the catalog.

# %%
local_folder = 's5p-no2-stac-catalog'

# %%
# ToDo: Apply best practices @Juraj --> Analog to other demo script
original_items = items

catalog = Catalog(
    id="s5p-no2-root",
    description="Root catalog for S5P NO2 STAC data."
)

# %% [markdown]
# get collection info from original terrascope url

# %%
url = "https://stac.terrascope.be/collections/terrascope-s5p-l3-no2-td-v2"
collection = Collection.from_file(url)
print(collection.id)
print(collection.title)

# Adapt some things, extent
# Out:
# terrascope-s5p-l3-no2-td-v2
# Sentinel-5P Level-3 NO2 Daily Product - V2

# %%
# check what else to adapt
# id, ..., ..., 

bbox_actual = [
    float(ds.longitude.min()), float(ds.latitude.min()),
    float(ds.longitude.max()), float(ds.latitude.max())
]

new_extent = Extent(
    SpatialExtent([bbox_actual]),
    TemporalExtent([[datetime(2023, 8, 1), datetime(2023, 8, 31, 23, 59, 59)]])
)
collection.extent = new_extent
collection.extent.spatial.bboxes
# Out:
# [[-9.95, 35.050000000000004, 29.950000000000006, 69.95]]

# %%
# add items to collection
# and adapt what is to be adapted

for i, src_item in enumerate(original_items):
    t = ds['time'].values[i]

    # ...
    
    # Update properties with extension fields
    properties = dict(src_item.properties)

    # ...
    
    # Add/Update extension fields
    properties.update({
        "proj:bbox": bbox_actual,
        "proj:epsg": 4326,
        "proj:shape": [ds.latitude.size, ds.longitude.size],
        "proj:transform": [
            float(ds.longitude[1] - ds.longitude[0]), 0.0, float(ds.longitude.min()),
            0.0, float(ds.latitude[1] - ds.latitude[0]), float(ds.latitude.min())
        ],
        "cube:dimensions": {
            "x": {"type": "spatial", "axis": "x", "extent": [float(ds.longitude.min()), float(ds.longitude.max())]},
            "y": {"type": "spatial", "axis": "y", "extent": [float(ds.latitude.min()), float(ds.latitude.max())]},
            "t": {"type": "temporal", "extent": [str(t), str(t)]}
        }
    })

   # ...

    src_item.geometry = {
        "type": "Polygon",
        "coordinates": [[
            [bbox_actual[0], bbox_actual[1]],
            [bbox_actual[2], bbox_actual[1]],
            [bbox_actual[2], bbox_actual[3]],
            [bbox_actual[0], bbox_actual[3]],
            [bbox_actual[0], bbox_actual[1]]
        ]]
    }
    src_item.bbox = bbox_actual
    src_item.datetime = pd.to_datetime(t).to_pydatetime()
    src_item.properties = properties

    collection.add_item(src_item)

# %%
catalog.add_child(collection)
catalog.normalize_and_save(local_folder, catalog_type="SELF_CONTAINED")
print(f"Catalog saved to: {local_folder}")
print(f"Number of items in collection: {len(list(collection.get_all_items()))}")
# Out:
# Catalog saved to: s5p-no2-stac-catalog
# Number of items in collection: 153

# %%
catalog = Catalog.from_file(f"{local_folder}/catalog.json")
catalog.validate()
# Out:
# ['https://schemas.stacspec.org/v1.1.0/catalog-spec/json-schema/catalog.json']

# %%
collection = catalog.get_child("terrascope-s5p-l3-no2-td-v2") # has to be adapted to match naming scheme of other script
collection.validate()
# Out:
# ['https://schemas.stacspec.org/v1.1.0/collection-spec/json-schema/collection.json',
#  'https://stac-extensions.github.io/render/v1.0.0/schema.json',
#  'https://stac-extensions.github.io/version/v1.2.0/schema.json',
#  'https://stac-extensions.github.io/authentication/v1.1.0/schema.json']

# %% [markdown]
# ### Best practice changes from Demonstration 2025/12
# Haven't been tested yet.

# %% [raw]
# import pystac
# from pystac.extensions.eo import EOExtension, Band
# from pystac.extensions.projection import ProjectionExtension
# from pystac.extensions.datacube import SpatialDimension, TemporalDimension, Dimension, DatacubeExtension
# from pystac.extensions.raster import RasterExtension
# from pystac.extensions.storage import StorageExtension
# from pystac.extensions.scientific import ScientificExtension
# from pystac import Item, Asset, Collection, Catalog, Extent, SpatialExtent, TemporalExtent, Summaries
# from pystac.extensions.raster import RasterExtension, RasterBand
# import xarray as xr
# import rioxarray
# import pandas as pd
# from datetime import timezone
# import rasterio
# from shapely.geometry import Polygon, mapping
#
# local_folder_no2 = "./s5p-bp-l3-no2-v2"
#
# stac_extensions_catalog = [
#         "https://stac-extensions.github.io/authentication/v1.1.0/schema.json"
# ]
#
# stac_extensions_collection = [
#     "https://stac-extensions.github.io/item-assets/v1.0.0/schema.json",
#     "https://stac-extensions.github.io/eo/v1.1.0/schema.json",
#     "https://stac-extensions.github.io/projection/v2.0.0/schema.json",
#     "https://stac-extensions.github.io/raster/v1.1.0/schema.json",
#     "https://stac-extensions.github.io/storage/v2.0.0/schema.json"
# ]
#
# stac_extensions_item = [
#     "https://stac-extensions.github.io/eo/v1.1.0/schema.json",
#     "https://stac-extensions.github.io/projection/v2.0.0/schema.json",
#     "https://stac-extensions.github.io/raster/v1.1.0/schema.json",
#     "https://stac-extensions.github.io/storage/v2.0.0/schema.json",
#     "https://stac-extensions.github.io/sentinel-5p/v0.2.0/schema.json"
# ]
#
# items_list = list(items)
#
# catalog = pystac.Catalog(id="s5p-bp-stac-no2-v2",
#                          description="Root catalog for S5P NO2 STAC data.",
#                          title="S5P NO2 data v2",
#                          stac_extensions=stac_extensions_catalog
#                          )
#
#
# def get_bbox_and_footprint(ds: xr.Dataset) -> tuple:
#     minx, miny, maxx, maxy = ds.rio.bounds()
#     bbox = [minx, miny, maxx, maxy]
#     footprint = Polygon([
#         [minx, miny],
#         [minx, maxy],
#         [maxx, maxy],
#         [maxx, miny],
#     ])
#     return bbox, mapping(footprint)
#
# bbox, footprint = get_bbox_and_footprint(ds)
#
# collection = Collection(
#     id="s5p-bp-stac-no2-v2",
#     title="Sentinel-5P NO2 Collection v2",
#     description="Sentinel-5P NO2  data (Aug-Dec 2023)",
#     stac_extensions=stac_extensions_collection,
#     license="proprietary",
#     extent=Extent(
#         spatial=SpatialExtent(bbox),
#         temporal=TemporalExtent(intervals=[(                                                        #type: ignore
#             pd.to_datetime(ds.time.min().values).to_pydatetime().replace(tzinfo=timezone.utc),
#             pd.to_datetime(ds.time.max().values).to_pydatetime().replace(tzinfo=timezone.utc)
#         )])
#     )
# )
#
# collection.add_asset(
#     "thumbnail",
#     Asset(
#         href="https://services.terrascope.be/collectioncatalogue/images/quicklooks/S5P_NO2_TD.png",
#         media_type="image/png",
#         title="terrascope-s5p-l3-no2-td-v2 thumbnail",
#         roles=["thumbnail"]
#     )
# )
#
# collection.summaries = Summaries(
#     summaries={
#         "datetime": {
#             "min": pd.to_datetime(ds.time.min().values).isoformat(),
#             "max": pd.to_datetime(ds.time.max().values).isoformat()
#         },
#         "platform": [items_list[0].properties.get("platform")],
#         "constellation": [items_list[0].properties.get("constellation")],
#         "instruments": [items_list[0].properties.get("instruments")],
#         "eo:cloud_cover": [items_list[0].properties.get("eo:cloud_cover")],
#         "eo:bands": [Band.create(
#             name="NO2",
#             description="NO2",
#             common_name="NO2"
#         ).to_dict()],
#         "eo:bands": [Band.create(
#             name="NO2_WEIGHT",
#             description="NO2_WEIGHT",
#             common_name="NO2_WEIGHT"
#         )],
#         "proj:epsg": [int(ds.cf.rio.crs.to_epsg())],
#         "proj:shape": list(ds.cf.rio.shape),
#         "proj:transform": list(ds.cf.rio.transform())
#     }
# )
#
# collection.extra_fields["item_assets"] = {
#     "NO2": {
#         "type": "image/tiff; application=geotiff",
#         "title": "NO2",
#         "description": "NO2",
#         "roles": ["data"]
#     }
# }
#
# collection.extra_fields["item_assets"] = {
#     "NO2_WEIGHT": {
#         "type": "image/tiff; application=geotiff",
#         "title": "NO2_WEIGHT",
#         "description": "NO2_WEIGHT",
#         "roles": ["data"]
#     }
# }
#
# start_time = pd.to_datetime(ds.time.min().values).to_pydatetime().replace(tzinfo=timezone.utc)
# end_time = pd.to_datetime(ds.time.max().values).to_pydatetime().replace(tzinfo=timezone.utc)
# temporal_extent = [
#     (start_time.isoformat(), end_time.isoformat())
# ]
#
# datacube_ext = {"cube:dimensions": {
#     "x": {
#       "type": "spatial",
#       "axis": "x",
#       "extent": [bbox[0], bbox[2]],
#       "reference_system": 4326
#     },
#     "y": {
#       "type": "spatial",
#       "axis": "y",
#       "extent": [bbox[1], bbox[3]],
#       "reference_system": 4326
#     },
#     "time": {
#       "type": "temporal",
#       "extent": temporal_extent,
#       "step": "P5D"
#     },
#     "band": {
#         "type": "bands",
#         "values": ["NO2"]
#     },
#     "band": {
#         "type": "bands",
#         "values": ["NO2_WEIGHT"]
#     }
#   },
# }
# collection.extra_fields.update(datacube_ext)
#
# new_items = []
# for old_item in items:
#     new_item = Item(
#         id=old_item.id,
#         geometry=old_item.geometry,
#         bbox=old_item.bbox,
#         datetime=old_item.datetime,
#         properties={
#             k: v
#             for k, v in old_item.properties.items()
#             if k not in ["eo:bands", "proj:code"]
#         },
#     )
#
#     for key, asset in old_item.assets.items():
#         if key == "NO2":
#             new_asset = Asset(
#                 href=asset.href,
#                 media_type=asset.media_type,
#                 roles=asset.roles,
#                 title=asset.title,
#                 description=asset.description,
#             )
#             new_item.add_asset("NO2", new_asset)
#
#             # Attach projection extension correctly
#             proj = ProjectionExtension.ext(new_asset, add_if_missing=True)
#             # Fix the projection extension to use correct field names for ODC STAC compatibility
#             # Convert 'EPSG:4326' format to numeric EPSG code
#             proj_code = asset.extra_fields.get('proj:code', '')
#             if proj_code.startswith('EPSG:'):
#                 proj.epsg = int(proj_code.split(':')[1])
#
#             proj.shape = asset.extra_fields.get('proj:shape')
#             proj.transform = asset.extra_fields.get('proj:transform')
#
#     # Normalize other properties
#     # if new_item.properties.get("license") == "CC-BY 4.0":
#     #     new_item.properties["license"] = "CC-BY-4.0"
#     if isinstance(new_item.properties.get("instruments"), str):
#         new_item.properties["instruments"] = [new_item.properties["instruments"]]
#
#     new_item.properties["updated"] = datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%S.%fZ")
#
#     collection.add_item(new_item)
#     new_items.append(new_item)
#
# catalog.add_child(collection)
#
# catalog.normalize_hrefs("./s5p-l3-no2-v2")
#
# catalog.normalize_and_save(local_folder, catalog_type="SELF_CONTAINED") # type: ignore
# print(f"Catalog saved to: {local_folder}")
# print(f"Number of items in collection: {len(list(collection.get_all_items()))}")

# %% [markdown]
# **Workspace BB**: Save json to Workspace BB or devcluster object storage.

# %% [markdown]
# Definitions for workspace

# %%
# get this info from here: https://workspace-api.develop.eoepca.org/workspaces/ws-eric, can also be retrieved programatically by following example "05 Workspace Management"
owner = "eric"
password = "changeme"
ws_name = "ws-eric"

# is this info really needed?
realm = "eoepca"
base_domain = "develop.eoepca.org" #"apx.develop.eoepca.org"
keycloak_endpoint = f"https://iam-auth.{base_domain}"
workspace_api_endpoint = f'https://workspace-api.{base_domain}/workspaces'
token_endpoint = f"{keycloak_endpoint}/realms/{realm}/protocol/openid-connect/token"
minio_endpoint = "https://minio.develop.eoepca.org"

# %% [markdown]
# Define functions to interact with workspace.

# %%
# do these functions need to be defined for only using the workspace?
def iam_token(username, password):
    headers = {
        "Cache-Control": "no-cache",
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {
        "scope": "roles",
        "grant_type": "password",
        "username": username,
        "password": password,
        "client_id": "demo",
        "client_secret": "demo"
    }    
    response = requests.post(token_endpoint, headers=headers, data=data)
    if response.ok:
        return response.json()["access_token"]
    else:
        print(response)
        return None

def access_ws(ws_name, token):
    headers = {
        'Authorization': 'bearer ' + token
    }
    url = f"{workspace_api_endpoint}/{ws_name}"
    print(f"HTTP GET {url}")
    response = requests.get(url, headers=headers)
    print(response)
    #print(response.text)
    return response

# %% [markdown]
# Prepare workspace

# %%
while True:
    response = access_ws(ws_name, iam_token(owner, password))
    if response.status_code == 200:
        try:
            workspace_data = response.json()
            print(workspace_data.get("status"))
            if workspace_data.get("status") == "ready":
                break
        except ValueError:
            print("not ready yet")

    print("...")
    time.sleep(20)
# Out:
# HTTP GET https://workspace-api.develop.eoepca.org/workspaces/ws-eric
# <Response [200]>
# ready

# %% [markdown]
# Retrieve relevant information sor storage.

# %%
response1 = access_ws(ws_name, iam_token(owner, password))
assert response1.status_code == 200 # this sometimes gives 401, upon next execution 200 again.
print(f"✅workspace ownership checked and can retrieve workspace details")
#workspace_data
# Out:
# HTTP GET https://workspace-api.develop.eoepca.org/workspaces/ws-eric
# <Response [200]>
# ✅workspace ownership checked and can retrieve workspace details

# %%
bucket_name = workspace_data["storage"]["credentials"]["bucketname"]
s3_access = workspace_data["storage"]["credentials"]["access"]
s3_secret = workspace_data["storage"]["credentials"]["secret"]
s3_endpoint = workspace_data["storage"]["credentials"]["endpoint"]

# %% [markdown]
# Connect to s3.

# %%
session = boto3.session.Session()
s3resource = session.resource('s3', aws_access_key_id=s3_access, aws_secret_access_key=s3_secret, endpoint_url=minio_endpoint)

# %%
s3_folder_prefix = f"end2end/{local_folder}/"

# %% [markdown]
# Recursively upload all files (the catalog, collection and items)

# %%
for root, dirs, files in os.walk(local_folder):
    for file in files:
        local_path = os.path.join(root, file)
        relative_path = os.path.relpath(local_path, local_folder)
        s3_key = os.path.join(s3_folder_prefix, relative_path).replace("\\", "/")

        try:
            object = s3resource.Object(bucket_name, s3_key)
            with open(local_path, 'rb') as data:
                result = object.put(Body=data)

            res = result.get('ResponseMetadata')
            if res.get('HTTPStatusCode') == 200:
                print(f"✅ Uploaded: {s3_key}")
            else:
                print(f"❌ Failed: {s3_key}")
        except Exception as e:
            print(f"🚨 Error uploading {s3_key}: {e}")
# Out:
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/catalog.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/collection.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230902_V200/S5P_OFFL_L3_NO2_TD_20230902_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231222_V200/S5P_OFFL_L3_NO2_TD_20231222_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230908_V200/S5P_OFFL_L3_NO2_TD_20230908_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231214_V200/S5P_OFFL_L3_NO2_TD_20231214_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231028_V200/S5P_OFFL_L3_NO2_TD_20231028_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230812_V200/S5P_OFFL_L3_NO2_TD_20230812_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230831_V200/S5P_OFFL_L3_NO2_TD_20230831_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230914_V200/S5P_OFFL_L3_NO2_TD_20230914_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231124_V200/S5P_OFFL_L3_NO2_TD_20231124_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231116_V200/S5P_OFFL_L3_NO2_TD_20231116_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230920_V200/S5P_OFFL_L3_NO2_TD_20230920_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230803_V200/S5P_OFFL_L3_NO2_TD_20230803_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231227_V200/S5P_OFFL_L3_NO2_TD_20231227_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230915_V200/S5P_OFFL_L3_NO2_TD_20230915_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231104_V200/S5P_OFFL_L3_NO2_TD_20231104_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230805_V200/S5P_OFFL_L3_NO2_TD_20230805_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230822_V200/S5P_OFFL_L3_NO2_TD_20230822_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230929_V200/S5P_OFFL_L3_NO2_TD_20230929_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231206_V200/S5P_OFFL_L3_NO2_TD_20231206_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231126_V200/S5P_OFFL_L3_NO2_TD_20231126_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231216_V200/S5P_OFFL_L3_NO2_TD_20231216_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231122_V200/S5P_OFFL_L3_NO2_TD_20231122_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230925_V200/S5P_OFFL_L3_NO2_TD_20230925_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231117_V200/S5P_OFFL_L3_NO2_TD_20231117_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230806_V200/S5P_OFFL_L3_NO2_TD_20230806_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230906_V200/S5P_OFFL_L3_NO2_TD_20230906_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231014_V200/S5P_OFFL_L3_NO2_TD_20231014_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231022_V200/S5P_OFFL_L3_NO2_TD_20231022_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230818_V200/S5P_OFFL_L3_NO2_TD_20230818_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231130_V200/S5P_OFFL_L3_NO2_TD_20231130_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231019_V200/S5P_OFFL_L3_NO2_TD_20231019_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231208_V200/S5P_OFFL_L3_NO2_TD_20231208_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231221_V200/S5P_OFFL_L3_NO2_TD_20231221_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230904_V200/S5P_OFFL_L3_NO2_TD_20230904_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231211_V200/S5P_OFFL_L3_NO2_TD_20231211_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230909_V200/S5P_OFFL_L3_NO2_TD_20230909_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231129_V200/S5P_OFFL_L3_NO2_TD_20231129_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230927_V200/S5P_OFFL_L3_NO2_TD_20230927_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230926_V200/S5P_OFFL_L3_NO2_TD_20230926_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231204_V200/S5P_OFFL_L3_NO2_TD_20231204_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231230_V200/S5P_OFFL_L3_NO2_TD_20231230_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231229_V200/S5P_OFFL_L3_NO2_TD_20231229_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230911_V200/S5P_OFFL_L3_NO2_TD_20230911_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231018_V200/S5P_OFFL_L3_NO2_TD_20231018_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231213_V200/S5P_OFFL_L3_NO2_TD_20231213_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231224_V200/S5P_OFFL_L3_NO2_TD_20231224_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231108_V200/S5P_OFFL_L3_NO2_TD_20231108_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231128_V200/S5P_OFFL_L3_NO2_TD_20231128_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230912_V200/S5P_OFFL_L3_NO2_TD_20230912_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230815_V200/S5P_OFFL_L3_NO2_TD_20230815_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230820_V200/S5P_OFFL_L3_NO2_TD_20230820_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231101_V200/S5P_OFFL_L3_NO2_TD_20231101_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231011_V200/S5P_OFFL_L3_NO2_TD_20231011_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231017_V200/S5P_OFFL_L3_NO2_TD_20231017_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231013_V200/S5P_OFFL_L3_NO2_TD_20231013_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231109_V200/S5P_OFFL_L3_NO2_TD_20231109_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231006_V200/S5P_OFFL_L3_NO2_TD_20231006_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231203_V200/S5P_OFFL_L3_NO2_TD_20231203_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231030_V200/S5P_OFFL_L3_NO2_TD_20231030_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231118_V200/S5P_OFFL_L3_NO2_TD_20231118_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231207_V200/S5P_OFFL_L3_NO2_TD_20231207_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231001_V200/S5P_OFFL_L3_NO2_TD_20231001_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231009_V200/S5P_OFFL_L3_NO2_TD_20231009_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231020_V200/S5P_OFFL_L3_NO2_TD_20231020_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231005_V200/S5P_OFFL_L3_NO2_TD_20231005_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230905_V200/S5P_OFFL_L3_NO2_TD_20230905_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231226_V200/S5P_OFFL_L3_NO2_TD_20231226_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230821_V200/S5P_OFFL_L3_NO2_TD_20230821_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231209_V200/S5P_OFFL_L3_NO2_TD_20231209_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230901_V200/S5P_OFFL_L3_NO2_TD_20230901_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231024_V200/S5P_OFFL_L3_NO2_TD_20231024_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231219_V200/S5P_OFFL_L3_NO2_TD_20231219_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231228_V200/S5P_OFFL_L3_NO2_TD_20231228_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230807_V200/S5P_OFFL_L3_NO2_TD_20230807_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230923_V200/S5P_OFFL_L3_NO2_TD_20230923_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230809_V200/S5P_OFFL_L3_NO2_TD_20230809_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231026_V200/S5P_OFFL_L3_NO2_TD_20231026_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231205_V200/S5P_OFFL_L3_NO2_TD_20231205_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231107_V200/S5P_OFFL_L3_NO2_TD_20231107_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230919_V200/S5P_OFFL_L3_NO2_TD_20230919_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230817_V200/S5P_OFFL_L3_NO2_TD_20230817_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231223_V200/S5P_OFFL_L3_NO2_TD_20231223_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230907_V200/S5P_OFFL_L3_NO2_TD_20230907_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230829_V200/S5P_OFFL_L3_NO2_TD_20230829_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231218_V200/S5P_OFFL_L3_NO2_TD_20231218_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231215_V200/S5P_OFFL_L3_NO2_TD_20231215_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231021_V200/S5P_OFFL_L3_NO2_TD_20231021_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231025_V200/S5P_OFFL_L3_NO2_TD_20231025_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230801_V200/S5P_OFFL_L3_NO2_TD_20230801_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231111_V200/S5P_OFFL_L3_NO2_TD_20231111_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231031_V200/S5P_OFFL_L3_NO2_TD_20231031_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231123_V200/S5P_OFFL_L3_NO2_TD_20231123_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231004_V200/S5P_OFFL_L3_NO2_TD_20231004_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231010_V200/S5P_OFFL_L3_NO2_TD_20231010_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230802_V200/S5P_OFFL_L3_NO2_TD_20230802_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230824_V200/S5P_OFFL_L3_NO2_TD_20230824_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231225_V200/S5P_OFFL_L3_NO2_TD_20231225_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231121_V200/S5P_OFFL_L3_NO2_TD_20231121_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231113_V200/S5P_OFFL_L3_NO2_TD_20231113_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230930_V200/S5P_OFFL_L3_NO2_TD_20230930_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230814_V200/S5P_OFFL_L3_NO2_TD_20230814_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230813_V200/S5P_OFFL_L3_NO2_TD_20230813_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231023_V200/S5P_OFFL_L3_NO2_TD_20231023_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231015_V200/S5P_OFFL_L3_NO2_TD_20231015_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230924_V200/S5P_OFFL_L3_NO2_TD_20230924_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231012_V200/S5P_OFFL_L3_NO2_TD_20231012_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231003_V200/S5P_OFFL_L3_NO2_TD_20231003_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231029_V200/S5P_OFFL_L3_NO2_TD_20231029_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230913_V200/S5P_OFFL_L3_NO2_TD_20230913_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231105_V200/S5P_OFFL_L3_NO2_TD_20231105_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231115_V200/S5P_OFFL_L3_NO2_TD_20231115_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231016_V200/S5P_OFFL_L3_NO2_TD_20231016_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230808_V200/S5P_OFFL_L3_NO2_TD_20230808_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231231_V200/S5P_OFFL_L3_NO2_TD_20231231_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231002_V200/S5P_OFFL_L3_NO2_TD_20231002_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231217_V200/S5P_OFFL_L3_NO2_TD_20231217_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230910_V200/S5P_OFFL_L3_NO2_TD_20230910_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231120_V200/S5P_OFFL_L3_NO2_TD_20231120_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231110_V200/S5P_OFFL_L3_NO2_TD_20231110_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230916_V200/S5P_OFFL_L3_NO2_TD_20230916_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231102_V200/S5P_OFFL_L3_NO2_TD_20231102_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230921_V200/S5P_OFFL_L3_NO2_TD_20230921_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230811_V200/S5P_OFFL_L3_NO2_TD_20230811_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230827_V200/S5P_OFFL_L3_NO2_TD_20230827_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230825_V200/S5P_OFFL_L3_NO2_TD_20230825_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230819_V200/S5P_OFFL_L3_NO2_TD_20230819_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231103_V200/S5P_OFFL_L3_NO2_TD_20231103_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231112_V200/S5P_OFFL_L3_NO2_TD_20231112_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231202_V200/S5P_OFFL_L3_NO2_TD_20231202_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231007_V200/S5P_OFFL_L3_NO2_TD_20231007_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231027_V200/S5P_OFFL_L3_NO2_TD_20231027_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231119_V200/S5P_OFFL_L3_NO2_TD_20231119_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231125_V200/S5P_OFFL_L3_NO2_TD_20231125_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230816_V200/S5P_OFFL_L3_NO2_TD_20230816_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230804_V200/S5P_OFFL_L3_NO2_TD_20230804_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230918_V200/S5P_OFFL_L3_NO2_TD_20230918_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230810_V200/S5P_OFFL_L3_NO2_TD_20230810_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230928_V200/S5P_OFFL_L3_NO2_TD_20230928_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231008_V200/S5P_OFFL_L3_NO2_TD_20231008_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231201_V200/S5P_OFFL_L3_NO2_TD_20231201_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230922_V200/S5P_OFFL_L3_NO2_TD_20230922_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231127_V200/S5P_OFFL_L3_NO2_TD_20231127_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231220_V200/S5P_OFFL_L3_NO2_TD_20231220_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230828_V200/S5P_OFFL_L3_NO2_TD_20230828_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231106_V200/S5P_OFFL_L3_NO2_TD_20231106_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230826_V200/S5P_OFFL_L3_NO2_TD_20230826_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231210_V200/S5P_OFFL_L3_NO2_TD_20231210_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231212_V200/S5P_OFFL_L3_NO2_TD_20231212_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230917_V200/S5P_OFFL_L3_NO2_TD_20230917_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20231114_V200/S5P_OFFL_L3_NO2_TD_20231114_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230823_V200/S5P_OFFL_L3_NO2_TD_20230823_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230903_V200/S5P_OFFL_L3_NO2_TD_20230903_V200.json
# ✅ Uploaded: end2end/s5p-no2-stac-catalog/terrascope-s5p-l3-no2-td-v2/S5P_OFFL_L3_NO2_TD_20230830_V200/S5P_OFFL_L3_NO2_TD_20230830_V200.json

# %% [markdown]
# Check that files are available here: https://ws-eric.develop.eoepca.org/files/ws-eric/end2end/

# %% [markdown]
# **Registration BB**: Have Registration BB - Harvester add the catalogue to EOEPCA STAC API

# %%
#  https://github.com/EOEPCA/demo/blob/main/demoroot/notebooks/06%20Resource%20Registration%20Harvester.ipynb
from requests import Session
from requests.auth import HTTPBasicAuth
import json

# Setup connection to Flowable API
flowable_base_url = "https://registration-harvester-api.develop.eoepca.org/flowable-rest"
flowable_rest_user = "eoepca"
flowable_rest_pw = "eoepca"
flowable_session = Session()
flowable_session.auth = HTTPBasicAuth(flowable_rest_user, flowable_rest_pw)

# %%
url = f"{flowable_base_url}/service/repository/process-definitions"
print(f"GET {url}")
response = flowable_session.get(url)
processes = response.json()["data"]
if len(processes) == 0:
    print("No workflow definitions")
else:
    for idx, process in enumerate(processes, 1):
        print("%-2s %-28s version: %-5s id: %s" % (idx, process['name'], process['version'], process['id']))
        if process["name"] == "STAC Publish":
            stac_processId = process["id"]
# Out:
# GET https://registration-harvester-api.develop.eoepca.org/flowable-rest/service/repository/process-definitions
# 1  STAC Publish                 version: 1     id: stacPublish:1:201803f1-7840-11f0-b011-7ed8fc866c09

# %%
# Workflow input variable
variables = [
    {
        "name": "stac_catalog_source",
        "value": f"s3://{s3_access}/{s3_folder_prefix}catalog.json" # "s3://ws-eric/end2end/s5p-bp-stac-catalog/catalog.json"
    },
    {
        "name": "s3_endpoint_url",
        "value": s3_endpoint
    },
    {
        "name": "s3_access_key",
        "value": s3_access
    },
    {
        "name": "s3_secret_key",
        "value": s3_secret 
    }
]
print(json.dumps(variables, indent=4))

# Create HTTP request to start the workflow
body = {}
body["processDefinitionId"] = stac_processId # "stacPublish:1:201803f1-7840-11f0-b011-7ed8fc866c09"
body["variables"] = variables
response = flowable_session.post(url=f"{flowable_base_url}/service/runtime/process-instances", json=body)
print(response.status_code)
print(f'Created process instance at {response.json()["url"]}')
# Out:
# [
#     {
#         "name": "stac_catalog_source",
#         "value": "s3://ws-eric/end2end/s5p-no2-stac-catalog/catalog.json"
#     },
#     {
#         "name": "s3_endpoint_url",
#         "value": "https://minio.develop.eoepca.org"
#     },
#     {
#         "name": "s3_access_key",
#         "value": "ws-eric"
#     },
#     {
#         "name": "s3_secret_key",
#         "value": "aQMtPaEaDgbMeTbILmd2ruXWkO2FRdOVSGgFWtinGALCaCz0rEaiZHgrVx27DHeC"
#     }
# ]
# 201
# Created process instance at https://registration-harvester-api.develop.eoepca.org/flowable-rest/service/runtime/process-instances/4074e5a7-9f78-11f0-9120-d2eb55003a74

# %% [markdown]
# Check the STAC Catalogue here: **Data Access**
# https://radiantearth.github.io/stac-browser/#/external/eoapi.develop.eoepca.org/stac/collections/terrascope-s5p-l3-no2-td-v2
#
#
# and here: **Data Cube Access**
# https://datacube-access.develop.eoepca.org/collections

# %% [markdown]
# Try to access

# %% [markdown]
# ## Naive download - From Stephaan

# %%
resp = requests.get(
    asset_url
)

print(resp, resp.headers, resp.content[:100], sep="\n")
# Out:
# <Response [200]>
# {'Date': 'Mon, 08 Sep 2025 09:29:00 GMT', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '756', 'Keep-Alive': 'timeout=15, max=99', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'}
# b'\n\t<html>\n\t\t<head>\n\t\t\t<style>\n\t\t\t\tbody {\n          margin: 0;\n        }\n\n        .container {\n       '

# %% [markdown]
# So that seemed to work (`200 Ok` status), but the response is actually a HTML page to log in.

# %% [markdown]
# ## Download with appropriate auth headers
#
# Loosely based on Terrascope docs on download with authentication.
#
# - https://docs.terrascope.be/Developers/WebServices/TerraCatalogue/ProductDownload.html#authentication
# - https://github.com/VITObelgium/notebook-samples/blob/master/terrascope-samples/Terrascope/Beginner/Terrascope_data_download.ipynb
#
#
# Instead of using the discouraged OIDC Password Grant, we'll use the OIDC Device Code Grant,
# leveraging some utilities from the openeo package to do the heavy lifting.
#
# ### Get access token

# %%
import openeo.rest.auth.oidc

# %%
issuer = "https://sso.terrascope.be/auth/realms/terrascope"
client_id = "public"

provider = openeo.rest.auth.oidc.OidcProviderInfo(issuer=issuer)
client_info = openeo.rest.auth.oidc.OidcClientInfo(client_id=client_id, provider=provider)  
authenticator = openeo.rest.auth.oidc.OidcDeviceAuthenticator(client_info=client_info)

# %%
tokens = authenticator.get_tokens()
# Out:
# Visit <a href="https://sso.terrascope.be/auth/realms/terrascope/device?user_code=CQOQ-CDWD" title="Authenticate at https://sso.terrascope.be/auth/realms/terrascope/device?user_code=CQOQ-CDWD" target="_blank" rel="noopener noreferrer">https://sso.terrascope.be/auth/realms/terrascope/device?user_code=CQOQ-CDWD</a> <a href="#" onclick="navigator.clipboard.writeText('https://sso.terrascope.be/auth/realms/terrascope/device?user_code=CQOQ-CDWD');return false;" title="Copy authentication URL to clipboard">&#128203;</a> to authenticate.
# ✅ Authorized successfully

# %% [markdown]
# ### Do download
#
# With access token, try again to do the download.
#
# Additionally we just do a partial (range request) download as we're just testing:

# %%
resp = requests.get(
    asset_url,
    headers={
        "Authorization": f"Bearer {tokens.access_token}",
        "Range": "bytes=0-100",
    }
)
print(resp, resp.headers, resp.content[:100], sep="\n")
# Out:
# <Response [206]>
# {'Date': 'Mon, 08 Sep 2025 09:30:38 GMT', 'Vary': 'Authorization', 'Last-Modified': 'Sat, 12 Aug 2023 07:24:13 GMT', 'ETag': '"8046a89-602b4b754a1cb"', 'Accept-Ranges': 'bytes', 'Content-Length': '101', 'Content-Range': 'bytes 0-100/134507145', 'Keep-Alive': 'timeout=15, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'image/tiff', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'}
# b'II*\x00\xc0\x00\x00\x00GDAL_STRUCTURAL_METADATA_SIZE=000140 bytes\nLAYOUT=IFDS_BEFORE_DATA\nBLOCK_ORDER=ROW_MAJOR\nBLO'

# %% [markdown]
# Looks like we got Tiff data here.
