# %% [markdown]
# # Application Package development and testing
# ## Water Bodies detection
#
# Scenario: Alice implements the Application Package
# Note: the full repository on the **OGC EO Application Package Hands-on**, with the three scenarios, is available at: https://github.com/Terradue/ogc-eo-application-package-hands-on.

# %% [markdown]
# ## Background
# This Application Package takes as input Copernicus Sentinel-2 data and detects water bodies by applying the *Otsu* thresholding technique on the Normalized Difference Water Index (NDWI).
#
# The NDWI is calculated with:
#
# $$
# NDWI = { (green - nir) \over (green + nir) }
# $$
#
# Typically, NDWI values of water bodies are larger than 0.2 and built-up features have positive values between 0 and 0.2. Vegetation has much smaller NDWI values, which results in distinguishing vegetation from water bodies easier.
#
# The NDWI values correspond to the following ranges:
#
# | Range       | Description                            |
# | ----------- | -------------------------------------- |
# | 0,2 - 1     | Water surface                          |
# | 0.0 - 0,2   | Flooding, humidity                     |
# | -0,3 - 0.0  | Moderate drought, non-aqueous surfaces |
# | -1 - -0.3   | Drought, non-aqueous surfaces          |
#
# To ease the determination of the water surface/non water surface, the Ostu thresholding technique is used.
#
# In the simplest form, the Otsu algorithm returns a single intensity threshold that separate pixels into two classes, foreground and background. This threshold is determined by minimizing intra-class intensity variance, or equivalently, by maximizing inter-class variance:
#
# ![image](https://upload.wikimedia.org/wikipedia/commons/3/34/Otsu%27s_Method_Visualization.gif)

# %% [markdown]
# ## Application Workflow
# The Water Bodies detection steps are depicted below:
# ``` mermaid
# graph TB
#   A[STAC Items] --> B
#   A[STAC Items] --> C
# subgraph Process STAC item
#   B["crop(green)"] --> D[Normalized difference];
#   C["crop(nir)"] --> D[Normalized difference];
#   D --> E[Otsu threshold]
# end
#   E --> F[Create STAC]
# ```
#
# The application takes a list of Sentinel-2 STAC items references and then crops the radiometric bands `green` and `NIR` with a user-defined area of interest (AOI). Each cropped band is then used to calculate the `NDWI` and subsequently the Otsu threashold is applied to it, generating the water bodies output mask. The final step of the workflow consists on generating the STAC catalog and items for the generated results.
#
# Alice organizes the Application Package to include a macro workflow that reads the list of Sentinel-2 STAC items references, the AOI and the EPSG code. The workflow steps include i) a sub-workflow for the detection of the water bodies and ii) a step to create the STAC catalog of the generated output product(s)
#
# ![image](FOSS4Gworkshop_07AppPackage/docs/water_bodies.png "water-bodies")
#
# The sub-workflow applies the  `crop`, `Normalized difference`, `Otsu threshold` steps:
#
# ![image](FOSS4Gworkshop_07AppPackage/docs/detect_water_body.png "detect-water-body")
#
# ## Input Sentinel-2 acquisitions
# The development and test dataset is made of two Sentinel-2 acquisitions:
#
# | Acquisitions 	|Image 1                    	|Image 2                    	|
# |--------------	|---------------------------	|---------------------------	|
# | Date         	|2021-07-13                 	|2022-05-24                 	|
# | URL          	| [S2B_10TFK_20210713_0_L2A](https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_10TFK_20210713_0_L2A) 	| [S2A_10TFK_20220524_0_L2A](https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20220524_0_L2A) 	|
# | Quicklook    	| ![image](FOSS4Gworkshop_07AppPackage/docs/img_20210713.jpg) 	| ![image](FOSS4Gworkshop_07AppPackage/docs/img_20220504.jpg) 	|

# %% [markdown]
# ## Environments creation
#
# Each `Command Line Tool` step (`crop`, `Normalized difference`, `Otsu threshold` and `Create STAC`) runs a Python script in a dedicated environment / container.
# To generate the environments, open a new `Terminal` and execute the commands below (either one by one or all at once).
#
# **Note**: This configuration step takes around five minutes to complete.

# %%
# Node "CROP" environment
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_crop gdal click pystac
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/sh: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         Supported by @QuantStack
#
#         GitHub:  https://github.com/QuantStack/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
# Getting  conda-forge linux-64
# Getting  conda-forge noarch
# Getting  pkgs/main linux-64
# Getting  pkgs/main noarch
# Getting  pkgs/r linux-64
# Getting  pkgs/r noarch
# Getting  terradue linux-64
# Getting  terradue noarch
# Getting  eoepca linux-64
# Getting  eoepca noarch
# Getting  r linux-64
# Getting  r noarch
#
# Looking for: ['gdal', 'click', 'pystac']
#
# 363404 packages in https://conda.anaconda.org/conda-forge/linux-64
# 138105 packages in https://conda.anaconda.org/conda-forge/noarch
# 32123 packages in https://repo.anaconda.com/pkgs/main/linux-64
# 4749 packages in https://repo.anaconda.com/pkgs/main/noarch
# 8445 packages in https://repo.anaconda.com/pkgs/r/linux-64
# 9493 packages in https://repo.anaconda.com/pkgs/r/noarch
# 457 packages in https://conda.anaconda.org/terradue/linux-64
# 90 packages in https://conda.anaconda.org/terradue/noarch
# 0 packages in https://conda.anaconda.org/eoepca/linux-64
# 45 packages in https://conda.anaconda.org/eoepca/noarch
# 8440 packages in https://conda.anaconda.org/r/linux-64
# 9493 packages in https://conda.anaconda.org/r/noarch
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/env_crop
#
#   added / updated specs:
#     - click
#     - gdal
#     - pystac
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB  defaults
#     blosc-1.21.4               |       h0f2a231_0          48 KB  conda-forge
#     boost-cpp-1.78.0           |       h6582d0a_3        15.2 MB  conda-forge
#     cairo-1.16.0               |    hbbf8b49_1016         1.1 MB  conda-forge
#     click-8.1.3                |  py311h38be061_1         196 KB  conda-forge
#     curl-8.1.2                 |       h409715c_0          89 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB  defaults
#     fonts-anaconda-1           |       h8fa9717_0           3 KB  defaults
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB  defaults
#     gdal-3.7.0                 |  py311h281082f_2         1.6 MB  conda-forge
#     geotiff-1.7.1              |       h22adcc9_9         251 KB  conda-forge
#     intel-openmp-2023.1.0      |   hdb19cb5_46305        17.1 MB  defaults
#     json-c-0.16                |       h5eee18b_0          77 KB  defaults
#     kealib-1.5.1               |       h3845be2_3         169 KB  conda-forge
#     libarchive-3.6.2           |       h039dbb9_1         824 KB  conda-forge
#     libcurl-8.1.2              |       h409715c_0         364 KB  conda-forge
#     libedit-3.1.20221030       |       h5eee18b_0         181 KB  defaults
#     libev-4.33                 |       h7f8727e_1         111 KB  defaults
#     libffi-3.4.4               |       h6a678d5_0         142 KB  defaults
#     libgcc-ng-13.1.0           |       he5830b7_0         758 KB  conda-forge
#     libgdal-3.7.0              |       h5418a03_2        10.2 MB  conda-forge
#     libgfortran-ng-13.1.0      |       h69a702a_0          23 KB  conda-forge
#     libgfortran5-13.1.0        |       h15d22d2_0         1.4 MB  conda-forge
#     libgomp-13.1.0             |       he5830b7_0         409 KB  conda-forge
#     libhwloc-2.9.1             |   cpu_h1633a84_5         2.5 MB  conda-forge
#     libnetcdf-4.9.2            |nompi_h0f3d0bb_105         821 KB  conda-forge
#     libnsl-2.0.0               |       h5eee18b_0          31 KB  defaults
#     libpng-1.6.39              |       h5eee18b_0         304 KB  defaults
#     libpq-15.3                 |       hbcd7760_1         2.4 MB  conda-forge
#     libspatialite-5.0.1        |      hca56755_27         3.0 MB  conda-forge
#     libssh2-1.11.0             |       h0841786_0         265 KB  conda-forge
#     libstdcxx-ng-13.1.0        |       hfd8a6a1_0         3.7 MB  conda-forge
#     libxml2-2.11.4             |       h0d562d8_0         688 KB  conda-forge
#     lzo-2.10                   |    h516909a_1000         314 KB  conda-forge
#     mkl-2023.1.0               |   h6d00ec8_46342       171.5 MB  defaults
#     mkl-service-2.4.0          |  py311h5eee18b_1          54 KB  defaults
#     mkl_fft-1.3.6              |  py311ha02d727_1         217 KB  defaults
#     mkl_random-1.2.2           |  py311ha02d727_1         291 KB  defaults
#     nspr-4.35                  |       h6a678d5_0         244 KB  defaults
#     nss-3.89.1                 |       h6a678d5_0         2.1 MB  defaults
#     numpy-1.24.3               |  py311h08b1b3b_1          11 KB  defaults
#     numpy-base-1.24.3          |  py311hf175353_1         7.2 MB  defaults
#     openssl-3.1.1              |       hd590300_1         2.5 MB  conda-forge
#     pixman-0.40.0              |       h7f8727e_1         373 KB  defaults
#     poppler-23.05.0            |       hd18248d_1        14.7 MB  conda-forge
#     postgresql-15.3            |       hd458b1d_1         4.9 MB  conda-forge
#     proj-9.2.1                 |       ha643af7_0         2.8 MB  conda-forge
#     pystac-1.7.3               |     pyhd8ed1ab_0          97 KB  conda-forge
#     python-3.11.3              |h2755cc3_0_cpython        29.6 MB  conda-forge
#     python_abi-3.11            |          3_cp311           6 KB  conda-forge
#     tbb-2021.9.0               |       hf52228f_0         1.5 MB  conda-forge
#     tzcode-2023c               |       h0b41bf4_0          67 KB  conda-forge
#     xerces-c-3.2.4             |       h8d71039_2         1.6 MB  conda-forge
#     xorg-libice-1.1.1          |       hd590300_0          57 KB  conda-forge
#     xorg-libsm-1.2.4           |       h7391055_0          27 KB  conda-forge
#     xorg-xproto-7.0.31         |    h27cfd23_1007          73 KB  defaults
#     xz-5.4.2                   |       h5eee18b_0         642 KB  defaults
#     zstd-1.5.5                 |       hc292b87_0         647 KB  defaults
#     ------------------------------------------------------------
#                                            Total:       305.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   blosc              conda-forge/linux-64::blosc-1.21.4-h0f2a231_0
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.78.0-h6582d0a_3
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.19.1-hd590300_0
#   ca-certificates    conda-forge/linux-64::ca-certificates-2023.5.7-hbcca054_0
#   cairo              conda-forge/linux-64::cairo-1.16.0-hbbf8b49_1016
#   cfitsio            conda-forge/linux-64::cfitsio-4.2.0-hd9d235c_0
#   click              conda-forge/linux-64::click-8.1.3-py311h38be061_1
#   curl               conda-forge/linux-64::curl-8.1.2-h409715c_0
#   expat              conda-forge/linux-64::expat-2.5.0-hcb278e6_1
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-hca18f0e_1
#   freexl             conda-forge/linux-64::freexl-1.0.6-h166bdaf_1
#   gdal               conda-forge/linux-64::gdal-3.7.0-py311h281082f_2
#   geos               conda-forge/linux-64::geos-3.11.2-hcb278e6_0
#   geotiff            conda-forge/linux-64::geotiff-1.7.1-h22adcc9_9
#   gettext            conda-forge/linux-64::gettext-0.21.1-h27087fc_0
#   giflib             conda-forge/linux-64::giflib-5.2.1-h0b41bf4_3
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h501b40f_6
#   hdf5               conda-forge/linux-64::hdf5-1.14.0-nompi_hb72d44e_103
#   icu                conda-forge/linux-64::icu-72.1-hcb278e6_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2023.1.0-hdb19cb5_46305
#   json-c             pkgs/main/linux-64::json-c-0.16-h5eee18b_0
#   kealib             conda-forge/linux-64::kealib-1.5.1-h3845be2_3
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   krb5               conda-forge/linux-64::krb5-1.20.1-h81ceb04_0
#   lcms2              conda-forge/linux-64::lcms2-2.15-haa2dc70_1
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libaec             conda-forge/linux-64::libaec-1.0.6-hcb278e6_1
#   libarchive         conda-forge/linux-64::libarchive-3.6.2-h039dbb9_1
#   libcurl            conda-forge/linux-64::libcurl-8.1.2-h409715c_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.18-h0b41bf4_0
#   libedit            pkgs/main/linux-64::libedit-3.1.20221030-h5eee18b_0
#   libev              pkgs/main/linux-64::libev-4.33-h7f8727e_1
#   libexpat           conda-forge/linux-64::libexpat-2.5.0-hcb278e6_1
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_0
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.1.0-he5830b7_0
#   libgdal            conda-forge/linux-64::libgdal-3.7.0-h5418a03_2
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.1.0-h69a702a_0
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.1.0-h15d22d2_0
#   libglib            conda-forge/linux-64::libglib-2.76.3-hebfc3b9_0
#   libgomp            conda-forge/linux-64::libgomp-13.1.0-he5830b7_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.9.1-cpu_h1633a84_5
#   libiconv           conda-forge/linux-64::libiconv-1.17-h166bdaf_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-2.1.5.1-h0b41bf4_0
#   libkml             conda-forge/linux-64::libkml-1.3.0-h37653c0_1015
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.9.2-nompi_h0f3d0bb_105
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.52.0-h61bc06f_0
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   libpq              conda-forge/linux-64::libpq-15.3-hbcd7760_1
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-h0d5128d_13
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-hca56755_27
#   libsqlite          conda-forge/linux-64::libsqlite-3.42.0-h2797004_0
#   libssh2            conda-forge/linux-64::libssh2-1.11.0-h0841786_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-13.1.0-hfd8a6a1_0
#   libtiff            conda-forge/linux-64::libtiff-4.5.0-ha587672_6
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.3.0-h0b41bf4_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   libxml2            conda-forge/linux-64::libxml2-2.11.4-h0d562d8_0
#   libzip             conda-forge/linux-64::libzip-1.9.2-hc929e4a_1
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.4-hcb278e6_0
#   lzo                conda-forge/linux-64::lzo-2.10-h516909a_1000
#   mkl                pkgs/main/linux-64::mkl-2023.1.0-h6d00ec8_46342
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py311h5eee18b_1
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.6-py311ha02d727_1
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py311ha02d727_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   nspr               pkgs/main/linux-64::nspr-4.35-h6a678d5_0
#   nss                pkgs/main/linux-64::nss-3.89.1-h6a678d5_0
#   numpy              pkgs/main/linux-64::numpy-1.24.3-py311h08b1b3b_1
#   numpy-base         pkgs/main/linux-64::numpy-base-1.24.3-py311hf175353_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.0-hfec8fc6_2
#   openssl            conda-forge/linux-64::openssl-3.1.1-hd590300_1
#   pcre2              conda-forge/linux-64::pcre2-10.40-hc3806b6_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   poppler            conda-forge/linux-64::poppler-23.05.0-hd18248d_1
#   poppler-data       conda-forge/noarch::poppler-data-0.4.12-hd8ed1ab_0
#   postgresql         conda-forge/linux-64::postgresql-15.3-hd458b1d_1
#   proj               conda-forge/linux-64::proj-9.2.1-ha643af7_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pystac             conda-forge/noarch::pystac-1.7.3-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.11.3-h2755cc3_0_cpython
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   python_abi         conda-forge/linux-64::python_abi-3.11-3_cp311
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_1
#   snappy             conda-forge/linux-64::snappy-1.1.10-h9fff704_0
#   sqlite             conda-forge/linux-64::sqlite-3.42.0-h2c6b66d_0
#   tbb                conda-forge/linux-64::tbb-2021.9.0-hf52228f_0
#   tiledb             conda-forge/linux-64::tiledb-2.13.2-hd532e3d_0
#   tk                 pkgs/main/linux-64::tk-8.6.12-h1ccaba5_0
#   tzcode             conda-forge/linux-64::tzcode-2023c-h0b41bf4_0
#   tzdata             pkgs/main/noarch::tzdata-2023c-h04d1e81_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.4-h8d71039_2
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.1-hd590300_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.4-h7391055_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.4-h8ee46fc_1
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xproto        pkgs/main/linux-64::xorg-xproto-7.0.31-h27cfd23_1007
#   xz                 pkgs/main/linux-64::xz-5.4.2-h5eee18b_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-h166bdaf_4
#   zstd               pkgs/main/linux-64::zstd-1.5.5-hc292b87_0
#
#
#
# Downloading and Extracting Packages
# nspr-4.35            | 244 KB    | ##################################### | 100%
# xorg-xproto-7.0.31   | 73 KB     | ##################################### | 100%
# proj-9.2.1           | 2.8 MB    | ##################################### | 100%
# libspatialite-5.0.1  | 3.0 MB    | ##################################### | 100%
# click-8.1.3          | 196 KB    | ##################################### | 100%
# python-3.11.3        | 29.6 MB   | ##################################### | 100%
# libgomp-13.1.0       | 409 KB    | ##################################### | 100%
# cairo-1.16.0         | 1.1 MB    | ##################################### | 100%
# xorg-libsm-1.2.4     | 27 KB     | ##################################### | 100%
# json-c-0.16          | 77 KB     | ##################################### | 100%
# mkl-2023.1.0         | 171.5 MB  | ##################################### | 100%
# poppler-23.05.0      | 14.7 MB   | ##################################### | 100%
# xorg-libice-1.1.1    | 57 KB     | ##################################### | 100%
# libstdcxx-ng-13.1.0  | 3.7 MB    | ##################################### | 100%
# nss-3.89.1           | 2.1 MB    | ##################################### | 100%
# gdal-3.7.0           | 1.6 MB    | ##################################### | 100%
# openssl-3.1.1        | 2.5 MB    | ##################################### | 100%
# pixman-0.40.0        | 373 KB    | ##################################### | 100%
# boost-cpp-1.78.0     | 15.2 MB   | ##################################### | 100%
# pystac-1.7.3         | 97 KB     | ##################################### | 100%
# xerces-c-3.2.4       | 1.6 MB    | ##################################### | 100%
# lzo-2.10             | 314 KB    | ##################################### | 100%
# libpq-15.3           | 2.4 MB    | ##################################### | 100%
# curl-8.1.2           | 89 KB     | ##################################### | 100%
# blosc-1.21.4         | 48 KB     | ##################################### | 100%
# libedit-3.1.20221030 | 181 KB    | ##################################### | 100%
# numpy-base-1.24.3    | 7.2 MB    | ##################################### | 100%
# blas-1.0             | 6 KB      | ##################################### | 100%
# libgfortran5-13.1.0  | 1.4 MB    | ##################################### | 100%
# fonts-conda-ecosyste | 5 KB      | ##################################### | 100%
# intel-openmp-2023.1. | 17.1 MB   | ##################################### | 100%
# mkl-service-2.4.0    | 54 KB     | ##################################### | 100%
# geotiff-1.7.1        | 251 KB    | ##################################### | 100%
# kealib-1.5.1         | 169 KB    | ##################################### | 100%
# libpng-1.6.39        | 304 KB    | ##################################### | 100%
# libhwloc-2.9.1       | 2.5 MB    | ##################################### | 100%
# zstd-1.5.5           | 647 KB    | ##################################### | 100%
# tzcode-2023c         | 67 KB     | ##################################### | 100%
# libgcc-ng-13.1.0     | 758 KB    | ##################################### | 100%
# postgresql-15.3      | 4.9 MB    | ##################################### | 100%
# mkl_fft-1.3.6        | 217 KB    | ##################################### | 100%
# libffi-3.4.4         | 142 KB    | ##################################### | 100%
# xz-5.4.2             | 642 KB    | ##################################### | 100%
# fonts-anaconda-1     | 3 KB      | ##################################### | 100%
# mkl_random-1.2.2     | 291 KB    | ##################################### | 100%
# libssh2-1.11.0       | 265 KB    | ##################################### | 100%
# libev-4.33           | 111 KB    | ##################################### | 100%
# font-ttf-dejavu-sans | 335 KB    | ##################################### | 100%
# libxml2-2.11.4       | 688 KB    | ##################################### | 100%
# libnsl-2.0.0         | 31 KB     | ##################################### | 100%
# libnetcdf-4.9.2      | 821 KB    | ##################################### | 100%
# libarchive-3.6.2     | 824 KB    | ##################################### | 100%
# python_abi-3.11      | 6 KB      | ##################################### | 100%
# numpy-1.24.3         | 11 KB     | ##################################### | 100%
# tbb-2021.9.0         | 1.5 MB    | ##################################### | 100%
# libgdal-3.7.0        | 10.2 MB   | ##################################### | 100%
# libgfortran-ng-13.1. | 23 KB     | ##################################### | 100%
# libcurl-8.1.2        | 364 KB    | ##################################### | 100%
# Preparing transaction: failed
#
# CondaError: Unable to create prefix directory '/srv/conda/envs/env_crop'.
# Check that you have sufficient permissions.

# %%
# Node "NORMALISED_DIFFERENCE" environment
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_norm_diff click gdal
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/sh: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         Supported by @QuantStack
#
#         GitHub:  https://github.com/QuantStack/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
# Getting  conda-forge linux-64
# Getting  conda-forge noarch
# Getting  pkgs/main linux-64
# Getting  pkgs/main noarch
# Getting  pkgs/r linux-64
# Getting  pkgs/r noarch
# Getting  terradue linux-64
# Getting  terradue noarch
# Getting  eoepca noarch
# Getting  eoepca linux-64
# Getting  r linux-64
# Getting  r noarch
#
# Looking for: ['click', 'gdal']
#
# 363404 packages in https://conda.anaconda.org/conda-forge/linux-64
# 138105 packages in https://conda.anaconda.org/conda-forge/noarch
# 32123 packages in https://repo.anaconda.com/pkgs/main/linux-64
# 4749 packages in https://repo.anaconda.com/pkgs/main/noarch
# 8445 packages in https://repo.anaconda.com/pkgs/r/linux-64
# 9493 packages in https://repo.anaconda.com/pkgs/r/noarch
# 457 packages in https://conda.anaconda.org/terradue/linux-64
# 90 packages in https://conda.anaconda.org/terradue/noarch
# 0 packages in https://conda.anaconda.org/eoepca/linux-64
# 45 packages in https://conda.anaconda.org/eoepca/noarch
# 8440 packages in https://conda.anaconda.org/r/linux-64
# 9493 packages in https://conda.anaconda.org/r/noarch
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/env_norm_diff
#
#   added / updated specs:
#     - click
#     - gdal
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   blosc              conda-forge/linux-64::blosc-1.21.4-h0f2a231_0
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.78.0-h6582d0a_3
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.19.1-hd590300_0
#   ca-certificates    conda-forge/linux-64::ca-certificates-2023.5.7-hbcca054_0
#   cairo              conda-forge/linux-64::cairo-1.16.0-hbbf8b49_1016
#   cfitsio            conda-forge/linux-64::cfitsio-4.2.0-hd9d235c_0
#   click              conda-forge/linux-64::click-8.1.3-py311h38be061_1
#   curl               conda-forge/linux-64::curl-8.1.2-h409715c_0
#   expat              conda-forge/linux-64::expat-2.5.0-hcb278e6_1
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-hca18f0e_1
#   freexl             conda-forge/linux-64::freexl-1.0.6-h166bdaf_1
#   gdal               conda-forge/linux-64::gdal-3.7.0-py311h281082f_2
#   geos               conda-forge/linux-64::geos-3.11.2-hcb278e6_0
#   geotiff            conda-forge/linux-64::geotiff-1.7.1-h22adcc9_9
#   gettext            conda-forge/linux-64::gettext-0.21.1-h27087fc_0
#   giflib             conda-forge/linux-64::giflib-5.2.1-h0b41bf4_3
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h501b40f_6
#   hdf5               conda-forge/linux-64::hdf5-1.14.0-nompi_hb72d44e_103
#   icu                conda-forge/linux-64::icu-72.1-hcb278e6_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2023.1.0-hdb19cb5_46305
#   json-c             pkgs/main/linux-64::json-c-0.16-h5eee18b_0
#   kealib             conda-forge/linux-64::kealib-1.5.1-h3845be2_3
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   krb5               conda-forge/linux-64::krb5-1.20.1-h81ceb04_0
#   lcms2              conda-forge/linux-64::lcms2-2.15-haa2dc70_1
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libaec             conda-forge/linux-64::libaec-1.0.6-hcb278e6_1
#   libarchive         conda-forge/linux-64::libarchive-3.6.2-h039dbb9_1
#   libcurl            conda-forge/linux-64::libcurl-8.1.2-h409715c_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.18-h0b41bf4_0
#   libedit            pkgs/main/linux-64::libedit-3.1.20221030-h5eee18b_0
#   libev              pkgs/main/linux-64::libev-4.33-h7f8727e_1
#   libexpat           conda-forge/linux-64::libexpat-2.5.0-hcb278e6_1
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_0
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.1.0-he5830b7_0
#   libgdal            conda-forge/linux-64::libgdal-3.7.0-h5418a03_2
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.1.0-h69a702a_0
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.1.0-h15d22d2_0
#   libglib            conda-forge/linux-64::libglib-2.76.3-hebfc3b9_0
#   libgomp            conda-forge/linux-64::libgomp-13.1.0-he5830b7_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.9.1-cpu_h1633a84_5
#   libiconv           conda-forge/linux-64::libiconv-1.17-h166bdaf_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-2.1.5.1-h0b41bf4_0
#   libkml             conda-forge/linux-64::libkml-1.3.0-h37653c0_1015
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.9.2-nompi_h0f3d0bb_105
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.52.0-h61bc06f_0
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   libpq              conda-forge/linux-64::libpq-15.3-hbcd7760_1
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-h0d5128d_13
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-hca56755_27
#   libsqlite          conda-forge/linux-64::libsqlite-3.42.0-h2797004_0
#   libssh2            conda-forge/linux-64::libssh2-1.11.0-h0841786_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-13.1.0-hfd8a6a1_0
#   libtiff            conda-forge/linux-64::libtiff-4.5.0-ha587672_6
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.3.0-h0b41bf4_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   libxml2            conda-forge/linux-64::libxml2-2.11.4-h0d562d8_0
#   libzip             conda-forge/linux-64::libzip-1.9.2-hc929e4a_1
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.4-hcb278e6_0
#   lzo                conda-forge/linux-64::lzo-2.10-h516909a_1000
#   mkl                pkgs/main/linux-64::mkl-2023.1.0-h6d00ec8_46342
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py311h5eee18b_1
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.6-py311ha02d727_1
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py311ha02d727_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   nspr               pkgs/main/linux-64::nspr-4.35-h6a678d5_0
#   nss                pkgs/main/linux-64::nss-3.89.1-h6a678d5_0
#   numpy              pkgs/main/linux-64::numpy-1.24.3-py311h08b1b3b_1
#   numpy-base         pkgs/main/linux-64::numpy-base-1.24.3-py311hf175353_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.0-hfec8fc6_2
#   openssl            conda-forge/linux-64::openssl-3.1.1-hd590300_1
#   pcre2              conda-forge/linux-64::pcre2-10.40-hc3806b6_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   poppler            conda-forge/linux-64::poppler-23.05.0-hd18248d_1
#   poppler-data       conda-forge/noarch::poppler-data-0.4.12-hd8ed1ab_0
#   postgresql         conda-forge/linux-64::postgresql-15.3-hd458b1d_1
#   proj               conda-forge/linux-64::proj-9.2.1-ha643af7_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   python             conda-forge/linux-64::python-3.11.3-h2755cc3_0_cpython
#   python_abi         conda-forge/linux-64::python_abi-3.11-3_cp311
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   snappy             conda-forge/linux-64::snappy-1.1.10-h9fff704_0
#   sqlite             conda-forge/linux-64::sqlite-3.42.0-h2c6b66d_0
#   tbb                conda-forge/linux-64::tbb-2021.9.0-hf52228f_0
#   tiledb             conda-forge/linux-64::tiledb-2.13.2-hd532e3d_0
#   tk                 pkgs/main/linux-64::tk-8.6.12-h1ccaba5_0
#   tzcode             conda-forge/linux-64::tzcode-2023c-h0b41bf4_0
#   tzdata             pkgs/main/noarch::tzdata-2023c-h04d1e81_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.4-h8d71039_2
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.1-hd590300_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.4-h7391055_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.4-h8ee46fc_1
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xproto        pkgs/main/linux-64::xorg-xproto-7.0.31-h27cfd23_1007
#   xz                 pkgs/main/linux-64::xz-5.4.2-h5eee18b_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-h166bdaf_4
#   zstd               pkgs/main/linux-64::zstd-1.5.5-hc292b87_0
#
#
# Preparing transaction: failed
#
# CondaError: Unable to create prefix directory '/srv/conda/envs/env_norm_diff'.
# Check that you have sufficient permissions.

# %%
# Node "OTSU" environment
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_otsu gdal scikit-image click
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/sh: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         Supported by @QuantStack
#
#         GitHub:  https://github.com/QuantStack/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
# Getting  conda-forge linux-64
# Getting  conda-forge noarch
# Getting  pkgs/main linux-64
# Getting  pkgs/main noarch
# Getting  pkgs/r linux-64
# Getting  pkgs/r noarch
# Getting  terradue linux-64
# Getting  terradue noarch
# Getting  eoepca linux-64
# Getting  eoepca noarch
# Getting  r linux-64
# Getting  r noarch
#
# Looking for: ['gdal', 'scikit-image', 'click']
#
# 363404 packages in https://conda.anaconda.org/conda-forge/linux-64
# 138105 packages in https://conda.anaconda.org/conda-forge/noarch
# 32123 packages in https://repo.anaconda.com/pkgs/main/linux-64
# 4749 packages in https://repo.anaconda.com/pkgs/main/noarch
# 8445 packages in https://repo.anaconda.com/pkgs/r/linux-64
# 9493 packages in https://repo.anaconda.com/pkgs/r/noarch
# 457 packages in https://conda.anaconda.org/terradue/linux-64
# 90 packages in https://conda.anaconda.org/terradue/noarch
# 0 packages in https://conda.anaconda.org/eoepca/linux-64
# 45 packages in https://conda.anaconda.org/eoepca/noarch
# 8440 packages in https://conda.anaconda.org/r/linux-64
# 9493 packages in https://conda.anaconda.org/r/noarch
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/env_otsu
#
#   added / updated specs:
#     - click
#     - gdal
#     - scikit-image
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brunsli-0.1                |       h2531618_0         164 KB  defaults
#     c-blosc2-2.9.2             |       hb4ffafa_0         298 KB  conda-forge
#     certifi-2023.5.7           |  py311h06a4308_0         153 KB  defaults
#     charls-2.4.2               |       h59595ed_0         147 KB  conda-forge
#     charset-normalizer-3.1.0   |     pyhd8ed1ab_0          44 KB  conda-forge
#     cloudpickle-2.2.1          |  py311h06a4308_0          51 KB  defaults
#     cytoolz-0.12.0             |  py311hd4cff14_1         416 KB  conda-forge
#     dask-core-2023.5.1         |     pyhd8ed1ab_0         827 KB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     fsspec-2023.5.0            |     pyh1a96a4e_0         113 KB  conda-forge
#     imagecodecs-2023.1.23      |  py311hd374d05_2         1.6 MB  conda-forge
#     imageio-2.28.1             |     pyh24c5eb1_0         3.1 MB  conda-forge
#     importlib-metadata-6.6.0   |     pyha770c72_0          25 KB  conda-forge
#     importlib_metadata-6.6.0   |       hd8ed1ab_0           9 KB  conda-forge
#     libavif-0.11.1             |       h8182462_2         100 KB  conda-forge
#     libblas-3.9.0              |1_h86c2bf4_netlib         199 KB  conda-forge
#     libcblas-3.9.0             |5_h92ddd45_netlib          54 KB  conda-forge
#     liblapack-3.9.0            |5_h92ddd45_netlib         3.0 MB  conda-forge
#     locket-1.0.0               |  py311h06a4308_0          13 KB  defaults
#     pillow-9.5.0               |  py311h0b84326_1        44.5 MB  conda-forge
#     platformdirs-3.5.1         |     pyhd8ed1ab_0          18 KB  conda-forge
#     pooch-1.7.0                |     pyha770c72_3          50 KB  conda-forge
#     pywavelets-1.4.1           |  py311h5eee18b_0         3.5 MB  defaults
#     pyyaml-6.0                 |  py311hd4cff14_5         202 KB  conda-forge
#     requests-2.31.0            |     pyhd8ed1ab_0          55 KB  conda-forge
#     scikit-image-0.20.0        |  py311h2872171_1        10.3 MB  conda-forge
#     scipy-1.10.1               |  py311h64a7726_3        15.0 MB  conda-forge
#     toolz-0.12.0               |  py311h06a4308_0         135 KB  defaults
#     typing-extensions-4.6.3    |       hd8ed1ab_0          10 KB  conda-forge
#     typing_extensions-4.6.3    |     pyha770c72_0          34 KB  conda-forge
#     urllib3-2.0.2              |     pyhd8ed1ab_0          95 KB  conda-forge
#     zlib-ng-2.0.7              |       h5eee18b_0         100 KB  defaults
#     ------------------------------------------------------------
#                                            Total:        85.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   aom                conda-forge/linux-64::aom-3.5.0-h27087fc_0
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   blosc              conda-forge/linux-64::blosc-1.21.4-h0f2a231_0
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.78.0-h6582d0a_3
#   brotli             conda-forge/linux-64::brotli-1.0.9-h166bdaf_8
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.0.9-h166bdaf_8
#   brunsli            pkgs/main/linux-64::brunsli-0.1-h2531618_0
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.19.1-hd590300_0
#   c-blosc2           conda-forge/linux-64::c-blosc2-2.9.2-hb4ffafa_0
#   ca-certificates    conda-forge/linux-64::ca-certificates-2023.5.7-hbcca054_0
#   cairo              conda-forge/linux-64::cairo-1.16.0-hbbf8b49_1016
#   certifi            pkgs/main/linux-64::certifi-2023.5.7-py311h06a4308_0
#   cfitsio            conda-forge/linux-64::cfitsio-4.2.0-hd9d235c_0
#   charls             conda-forge/linux-64::charls-2.4.2-h59595ed_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.1.0-pyhd8ed1ab_0
#   click              conda-forge/linux-64::click-8.1.3-py311h38be061_1
#   cloudpickle        pkgs/main/linux-64::cloudpickle-2.2.1-py311h06a4308_0
#   curl               conda-forge/linux-64::curl-8.1.2-h409715c_0
#   cytoolz            conda-forge/linux-64::cytoolz-0.12.0-py311hd4cff14_1
#   dask-core          conda-forge/noarch::dask-core-2023.5.1-pyhd8ed1ab_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   expat              conda-forge/linux-64::expat-2.5.0-hcb278e6_1
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-hca18f0e_1
#   freexl             conda-forge/linux-64::freexl-1.0.6-h166bdaf_1
#   fsspec             conda-forge/noarch::fsspec-2023.5.0-pyh1a96a4e_0
#   gdal               conda-forge/linux-64::gdal-3.7.0-py311h281082f_2
#   geos               conda-forge/linux-64::geos-3.11.2-hcb278e6_0
#   geotiff            conda-forge/linux-64::geotiff-1.7.1-h22adcc9_9
#   gettext            conda-forge/linux-64::gettext-0.21.1-h27087fc_0
#   giflib             conda-forge/linux-64::giflib-5.2.1-h0b41bf4_3
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h501b40f_6
#   hdf5               conda-forge/linux-64::hdf5-1.14.0-nompi_hb72d44e_103
#   icu                conda-forge/linux-64::icu-72.1-hcb278e6_0
#   idna               pkgs/main/linux-64::idna-3.4-py311h06a4308_0
#   imagecodecs        conda-forge/linux-64::imagecodecs-2023.1.23-py311hd374d05_2
#   imageio            conda-forge/noarch::imageio-2.28.1-pyh24c5eb1_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-6.6.0-pyha770c72_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-6.6.0-hd8ed1ab_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2023.1.0-hdb19cb5_46305
#   json-c             pkgs/main/linux-64::json-c-0.16-h5eee18b_0
#   jxrlib             conda-forge/linux-64::jxrlib-1.1-h7f98852_2
#   kealib             conda-forge/linux-64::kealib-1.5.1-h3845be2_3
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   krb5               conda-forge/linux-64::krb5-1.20.1-h81ceb04_0
#   lazy_loader        conda-forge/noarch::lazy_loader-0.2-pyhd8ed1ab_0
#   lcms2              conda-forge/linux-64::lcms2-2.15-haa2dc70_1
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libaec             conda-forge/linux-64::libaec-1.0.6-hcb278e6_1
#   libarchive         conda-forge/linux-64::libarchive-3.6.2-h039dbb9_1
#   libavif            conda-forge/linux-64::libavif-0.11.1-h8182462_2
#   libblas            conda-forge/linux-64::libblas-3.9.0-1_h86c2bf4_netlib
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.0.9-h166bdaf_8
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.0.9-h166bdaf_8
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.0.9-h166bdaf_8
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-5_h92ddd45_netlib
#   libcurl            conda-forge/linux-64::libcurl-8.1.2-h409715c_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.18-h0b41bf4_0
#   libedit            pkgs/main/linux-64::libedit-3.1.20221030-h5eee18b_0
#   libev              pkgs/main/linux-64::libev-4.33-h7f8727e_1
#   libexpat           conda-forge/linux-64::libexpat-2.5.0-hcb278e6_1
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_0
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.1.0-he5830b7_0
#   libgdal            conda-forge/linux-64::libgdal-3.7.0-h5418a03_2
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.1.0-h69a702a_0
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.1.0-h15d22d2_0
#   libglib            conda-forge/linux-64::libglib-2.76.3-hebfc3b9_0
#   libgomp            conda-forge/linux-64::libgomp-13.1.0-he5830b7_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.9.1-cpu_h1633a84_5
#   libiconv           conda-forge/linux-64::libiconv-1.17-h166bdaf_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-2.1.5.1-h0b41bf4_0
#   libkml             conda-forge/linux-64::libkml-1.3.0-h37653c0_1015
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-5_h92ddd45_netlib
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.9.2-nompi_h0f3d0bb_105
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.52.0-h61bc06f_0
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   libpq              conda-forge/linux-64::libpq-15.3-hbcd7760_1
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-h0d5128d_13
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-hca56755_27
#   libsqlite          conda-forge/linux-64::libsqlite-3.42.0-h2797004_0
#   libssh2            conda-forge/linux-64::libssh2-1.11.0-h0841786_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-13.1.0-hfd8a6a1_0
#   libtiff            conda-forge/linux-64::libtiff-4.5.0-ha587672_6
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.3.0-h0b41bf4_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   libxml2            conda-forge/linux-64::libxml2-2.11.4-h0d562d8_0
#   libzip             conda-forge/linux-64::libzip-1.9.2-hc929e4a_1
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4
#   libzopfli          conda-forge/linux-64::libzopfli-1.0.3-h9c3ff4c_0
#   locket             pkgs/main/linux-64::locket-1.0.0-py311h06a4308_0
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.4-hcb278e6_0
#   lzo                conda-forge/linux-64::lzo-2.10-h516909a_1000
#   mkl                pkgs/main/linux-64::mkl-2023.1.0-h6d00ec8_46342
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py311h5eee18b_1
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.6-py311ha02d727_1
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py311ha02d727_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   networkx           conda-forge/noarch::networkx-3.1-pyhd8ed1ab_0
#   nspr               pkgs/main/linux-64::nspr-4.35-h6a678d5_0
#   nss                pkgs/main/linux-64::nss-3.89.1-h6a678d5_0
#   numpy              pkgs/main/linux-64::numpy-1.24.3-py311h08b1b3b_1
#   numpy-base         pkgs/main/linux-64::numpy-base-1.24.3-py311hf175353_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.0-hfec8fc6_2
#   openssl            conda-forge/linux-64::openssl-3.1.1-hd590300_1
#   packaging          conda-forge/noarch::packaging-23.1-pyhd8ed1ab_0
#   partd              conda-forge/noarch::partd-1.4.0-pyhd8ed1ab_0
#   pcre2              conda-forge/linux-64::pcre2-10.40-hc3806b6_0
#   pillow             conda-forge/linux-64::pillow-9.5.0-py311h0b84326_1
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   platformdirs       conda-forge/noarch::platformdirs-3.5.1-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.7.0-pyha770c72_3
#   poppler            conda-forge/linux-64::poppler-23.05.0-hd18248d_1
#   poppler-data       conda-forge/noarch::poppler-data-0.4.12-hd8ed1ab_0
#   postgresql         conda-forge/linux-64::postgresql-15.3-hd458b1d_1
#   proj               conda-forge/linux-64::proj-9.2.1-ha643af7_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py311h06a4308_0
#   python             conda-forge/linux-64::python-3.11.3-h2755cc3_0_cpython
#   python_abi         conda-forge/linux-64::python_abi-3.11-3_cp311
#   pywavelets         pkgs/main/linux-64::pywavelets-1.4.1-py311h5eee18b_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0-py311hd4cff14_5
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   requests           conda-forge/noarch::requests-2.31.0-pyhd8ed1ab_0
#   scikit-image       conda-forge/linux-64::scikit-image-0.20.0-py311h2872171_1
#   scipy              conda-forge/linux-64::scipy-1.10.1-py311h64a7726_3
#   snappy             conda-forge/linux-64::snappy-1.1.10-h9fff704_0
#   sqlite             conda-forge/linux-64::sqlite-3.42.0-h2c6b66d_0
#   tbb                conda-forge/linux-64::tbb-2021.9.0-hf52228f_0
#   tifffile           conda-forge/noarch::tifffile-2023.4.12-pyhd8ed1ab_0
#   tiledb             conda-forge/linux-64::tiledb-2.13.2-hd532e3d_0
#   tk                 pkgs/main/linux-64::tk-8.6.12-h1ccaba5_0
#   toolz              pkgs/main/linux-64::toolz-0.12.0-py311h06a4308_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.6.3-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.6.3-pyha770c72_0
#   tzcode             conda-forge/linux-64::tzcode-2023c-h0b41bf4_0
#   tzdata             pkgs/main/noarch::tzdata-2023c-h04d1e81_0
#   urllib3            conda-forge/noarch::urllib3-2.0.2-pyhd8ed1ab_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.4-h8d71039_2
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.1-hd590300_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.4-h7391055_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.4-h8ee46fc_1
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xproto        pkgs/main/linux-64::xorg-xproto-7.0.31-h27cfd23_1007
#   xz                 pkgs/main/linux-64::xz-5.4.2-h5eee18b_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   zfp                conda-forge/linux-64::zfp-1.0.0-h27087fc_3
#   zipp               conda-forge/noarch::zipp-3.15.0-pyhd8ed1ab_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-h166bdaf_4
#   zlib-ng            pkgs/main/linux-64::zlib-ng-2.0.7-h5eee18b_0
#   zstd               pkgs/main/linux-64::zstd-1.5.5-hc292b87_0
#
#
#
# Downloading and Extracting Packages
# pyyaml-6.0           | 202 KB    | ##################################### | 100%
# zlib-ng-2.0.7        | 100 KB    | ##################################### | 100%
# typing-extensions-4. | 10 KB     | ##################################### | 100%
# scipy-1.10.1         | 15.0 MB   | ##################################### | 100%
# importlib-metadata-6 | 25 KB     | ##################################### | 100%
# imagecodecs-2023.1.2 | 1.6 MB    | ##################################### | 100%
# charls-2.4.2         | 147 KB    | ##################################### | 100%
# imageio-2.28.1       | 3.1 MB    | ##################################### | 100%
# c-blosc2-2.9.2       | 298 KB    | ##################################### | 100%
# fsspec-2023.5.0      | 113 KB    | ##################################### | 100%
# pillow-9.5.0         | 44.5 MB   | ##################################### | 100%
# requests-2.31.0      | 55 KB     | ##################################### | 100%
# dask-core-2023.5.1   | 827 KB    | ##################################### | 100%
# typing_extensions-4. | 34 KB     | ##################################### | 100%
# locket-1.0.0         | 13 KB     | ##################################### | 100%
# liblapack-3.9.0      | 3.0 MB    | ##################################### | 100%
# toolz-0.12.0         | 135 KB    | ##################################### | 100%
# pooch-1.7.0          | 50 KB     | ##################################### | 100%
# certifi-2023.5.7     | 153 KB    | ##################################### | 100%
# brunsli-0.1          | 164 KB    | ##################################### | 100%
# cloudpickle-2.2.1    | 51 KB     | ##################################### | 100%
# charset-normalizer-3 | 44 KB     | ##################################### | 100%
# platformdirs-3.5.1   | 18 KB     | ##################################### | 100%
# importlib_metadata-6 | 9 KB      | ##################################### | 100%
# pywavelets-1.4.1     | 3.5 MB    | ##################################### | 100%
# cytoolz-0.12.0       | 416 KB    | ##################################### | 100%
# urllib3-2.0.2        | 95 KB     | ##################################### | 100%
# libcblas-3.9.0       | 54 KB     | ##################################### | 100%
# scikit-image-0.20.0  | 10.3 MB   | ##################################### | 100%
# libblas-3.9.0        | 199 KB    | ##################################### | 100%
# libavif-0.11.1       | 100 KB    | ##################################### | 100%
# dav1d-1.2.1          | 742 KB    | ##################################### | 100%
# Preparing transaction: failed
#
# CondaError: Unable to create prefix directory '/srv/conda/envs/env_otsu'.
# Check that you have sufficient permissions.

# %%
# Node "STAC" environment
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_stac click pystac python=3.9 pip && \
    /srv/conda/envs/env_stac/bin/pip install rio_stac
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/sh: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         Supported by @QuantStack
#
#         GitHub:  https://github.com/QuantStack/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
# Getting  conda-forge linux-64
# Getting  conda-forge noarch
# Getting  pkgs/main linux-64
# Getting  pkgs/main noarch
# Getting  pkgs/r linux-64
# Getting  pkgs/r noarch
# Getting  terradue linux-64
# Getting  terradue noarch
# Getting  eoepca linux-64
# Getting  eoepca noarch
# Getting  r linux-64
# Getting  r noarch
#
# Looking for: ['click', 'pystac', 'python 3.9.*', 'pip']
#
# 363404 packages in https://conda.anaconda.org/conda-forge/linux-64
# 138105 packages in https://conda.anaconda.org/conda-forge/noarch
# 32123 packages in https://repo.anaconda.com/pkgs/main/linux-64
# 4749 packages in https://repo.anaconda.com/pkgs/main/noarch
# 8445 packages in https://repo.anaconda.com/pkgs/r/linux-64
# 9493 packages in https://repo.anaconda.com/pkgs/r/noarch
# 457 packages in https://conda.anaconda.org/terradue/linux-64
# 90 packages in https://conda.anaconda.org/terradue/noarch
# 0 packages in https://conda.anaconda.org/eoepca/linux-64
# 45 packages in https://conda.anaconda.org/eoepca/noarch
# 8440 packages in https://conda.anaconda.org/r/linux-64
# 9493 packages in https://conda.anaconda.org/r/noarch
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/env_stac
#
#   added / updated specs:
#     - click
#     - pip
#     - pystac
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1u             |       hd590300_0         1.9 MB  conda-forge
#     python-3.9.16              |       h7a1cb2a_2        25.1 MB  defaults
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     setuptools-67.8.0          |   py39h06a4308_0         1.0 MB  defaults
#     ------------------------------------------------------------
#                                            Total:        28.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   ca-certificates    conda-forge/linux-64::ca-certificates-2023.5.7-hbcca054_0
#   click              conda-forge/linux-64::click-8.1.3-py39hf3d152e_1
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_0
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.1.0-he5830b7_0
#   libgomp            conda-forge/linux-64::libgomp-13.1.0-he5830b7_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.42.0-h2797004_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-13.1.0-hfd8a6a1_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            conda-forge/linux-64::openssl-1.1.1u-hd590300_0
#   pip                conda-forge/noarch::pip-23.1.2-pyhd8ed1ab_0
#   pystac             conda-forge/noarch::pystac-1.7.3-pyhd8ed1ab_0
#   python             pkgs/main/linux-64::python-3.9.16-h7a1cb2a_2
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   python_abi         conda-forge/linux-64::python_abi-3.9-2_cp39
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   setuptools         pkgs/main/linux-64::setuptools-67.8.0-py39h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_1
#   sqlite             conda-forge/linux-64::sqlite-3.42.0-h2c6b66d_0
#   tk                 pkgs/main/linux-64::tk-8.6.12-h1ccaba5_0
#   tzdata             pkgs/main/noarch::tzdata-2023c-h04d1e81_0
#   wheel              conda-forge/noarch::wheel-0.40.0-pyhd8ed1ab_0
#   xz                 pkgs/main/linux-64::xz-5.4.2-h5eee18b_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-h166bdaf_4
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1u       | 1.9 MB    | ##################################### | 100%
# setuptools-67.8.0    | 1.0 MB    | ##################################### | 100%
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# python-3.9.16        | 25.1 MB   | ##################################### | 100%
# Preparing transaction: failed
#
# CondaError: Unable to create prefix directory '/srv/conda/envs/env_stac'.
# Check that you have sufficient permissions.

# %%
# Clean unnecessary packages
# !mamba clean --all -f -y
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/sh: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         Supported by @QuantStack
#
#         GitHub:  https://github.com/QuantStack/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
# Remove all contents from the following package caches?
#   - /workspace/.conda/pkgs

# %% [markdown]
# ## Dockers creation

# %%
import os
os.chdir('FOSS4Gworkshop_07AppPackage')

# %%
# !docker build -t simonevaccari/crop:0.1.0 --no-cache -f water-bodies/command-line-tools/crop/Dockerfile .
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# WARN[0000] "/" is not a shared mount, this could cause issues or missing mounts with rootless containers
# STEP 1/13: FROM docker.io/mambaorg/micromamba:latest
# Trying to pull docker.io/mambaorg/micromamba:latest...
# Getting image source signatures
# Copying blob 9e3ea8720c6d [==>--------------------------------] 2.7MiB / 29.9MiB
# Copying blob 4f4fb700ef54 [======================================] 32.0b / 32.0b
# Copying blob a7aee41143c3 [====================================] 283.0b / 283.0b
# Copying blob ee8f42978de7 [====================================] 522.0b / 522.0b
# Copying blob abcf63bffa78 [===>------------------------------] 620.9KiB / 5.4MiB
# Copying blob bdd19a82bedd [================================] 112.5KiB / 112.5KiB
# Copying blob 9e3ea8720c6d [=======>---------------------------] 6.6MiB / 29.9MiB
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 [===========================>--------] 4.2MiB / 5.4MiB
# Copying blob bdd19a82bedd done
# Copying blob 9e3ea8720c6d [===========>----------------------] 10.9MiB / 29.9MiB
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 [====================================] 5.4MiB / 5.4MiB
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 [--------------------------------------] 0.0b / 0.0b
# Copying blob 9e3ea8720c6d [================>-----------------] 15.1MiB / 29.9MiB
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc [====================================] 641.0b / 641.0b
# Copying blob 9e3ea8720c6d [=====================>------------] 19.5MiB / 29.9MiB
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f [====================================] 4.4KiB / 4.4KiB
# Copying blob c23a47b89258 [====================================] 683.0b / 683.0b
# Copying blob 9e3ea8720c6d [==========================>-------] 23.4MiB / 29.9MiB
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 9e3ea8720c6d [==============================>---] 26.9MiB / 29.9MiB
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 [====================================] 342.0b / 342.0b
# Copying blob 9e3ea8720c6d [==================================] 29.9MiB / 29.9MiB
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying blob 9e3ea8720c6d done
# Copying blob 4f4fb700ef54 done
# Copying blob a7aee41143c3 done
# Copying blob ee8f42978de7 done
# Copying blob abcf63bffa78 done
# Copying blob bdd19a82bedd done
# Copying blob 4f4fb700ef54 skipped: already exists
# Copying blob 0de1223208cc done
# Copying blob 7949e3ce010f done
# Copying blob c23a47b89258 done
# Copying blob 6f086382ad30 done
# Copying config bcfdda4930 [====================================] 6.1KiB / 6.1KiB
# Copying config bcfdda4930 done
# Copying config bcfdda4930 done
# Writing manifest to image destination
# Storing signatures
# STEP 2/13: USER root
# WARN[0005] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 945fd5bb82b
# STEP 3/13: ENV USERNAME=mambauser
# WARN[0005] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 1a0a81206e6
# STEP 4/13: ENV PATH=/srv/conda/envs/env_crop/bin:$PATH
# WARN[0005] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 348db805917
# STEP 5/13: RUN apt-get update -y  && apt-get upgrade -y  && apt-get install -y --no-install-recommends         ca-certificates         curl sudo git gcc build-essential
# Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
# Get:2 http://deb.debian.org/debian-security bullseye-security InRelease [48.4 kB]
# Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183 kB]
# Get:5 http://deb.debian.org/debian-security bullseye-security/main amd64 Packages [245 kB]
# Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Packages [14.8 kB]
# Fetched 8650 kB in 16s (526 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Calculating upgrade...
# The following packages will be upgraded:
#   libssl1.1
# 1 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Need to get 1559 kB of archives.
# After this operation, 4096 B disk space will be freed.
# Get:1 http://deb.debian.org/debian-security bullseye-security/main amd64 libssl1.1 amd64 1.1.1n-0+deb11u5 [1559 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 1559 kB in 0s (35.8 MB/s)
# (Reading database ... 6664 files and directories currently installed.)
# Preparing to unpack .../libssl1.1_1.1.1n-0+deb11u5_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1n-0+deb11u5) over (1.1.1n-0+deb11u4) ...
# Setting up libssl1.1:amd64 (1.1.1n-0+deb11u5) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.32.1 /usr/local/share/perl/5.32.1 /usr/lib/x86_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
# Processing triggers for libc-bin (2.31-13+deb11u6) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu bzip2 cpp cpp-10 dpkg-dev
#   g++ g++-10 gcc-10 git-man libasan6 libatomic1 libbinutils libbrotli1
#   libc-dev-bin libc6-dev libcc1-0 libcrypt-dev libctf-nobfd0 libctf0
#   libcurl3-gnutls libcurl4 libdpkg-perl liberror-perl libexpat1 libgcc-10-dev
#   libgdbm-compat4 libgdbm6 libgomp1 libisl23 libitm1 libldap-2.4-2 liblsan0
#   libmpc3 libmpfr6 libnghttp2-14 libnsl-dev libperl5.32 libpsl5 libquadmath0
#   librtmp1 libsasl2-2 libsasl2-modules-db libssh2-1 libstdc++-10-dev
#   libtirpc-dev libtsan0 libubsan1 linux-libc-dev make openssl patch perl
#   perl-modules-5.32 xz-utils
# Suggested packages:
#   binutils-doc bzip2-doc cpp-doc gcc-10-locales debian-keyring g++-multilib
#   g++-10-multilib gcc-10-doc gcc-multilib manpages-dev autoconf automake
#   libtool flex bison gdb gcc-doc gcc-10-multilib gettext-base git-daemon-run
#   | git-daemon-sysvinit git-doc git-el git-email git-gui gitk gitweb git-cvs
#   git-mediawiki git-svn glibc-doc gnupg sensible-utils bzr gdbm-l10n
#   libstdc++-10-doc make-doc ed diffutils-doc perl-doc
#   libterm-readline-gnu-perl | libterm-readline-perl-perl
#   libtap-harness-archive-perl
# Recommended packages:
#   fakeroot gnupg libalgorithm-merge-perl less ssh-client manpages manpages-dev
#   libc-devtools libfile-fcntllock-perl liblocale-gettext-perl libldap-common
#   publicsuffix libsasl2-modules netbase
# The following NEW packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu build-essential bzip2
#   ca-certificates cpp cpp-10 curl dpkg-dev g++ g++-10 gcc gcc-10 git git-man
#   libasan6 libatomic1 libbinutils libbrotli1 libc-dev-bin libc6-dev libcc1-0
#   libcrypt-dev libctf-nobfd0 libctf0 libcurl3-gnutls libcurl4 libdpkg-perl
#   liberror-perl libexpat1 libgcc-10-dev libgdbm-compat4 libgdbm6 libgomp1
#   libisl23 libitm1 libldap-2.4-2 liblsan0 libmpc3 libmpfr6 libnghttp2-14
#   libnsl-dev libperl5.32 libpsl5 libquadmath0 librtmp1 libsasl2-2
#   libsasl2-modules-db libssh2-1 libstdc++-10-dev libtirpc-dev libtsan0
#   libubsan1 linux-libc-dev make openssl patch perl perl-modules-5.32 sudo
#   xz-utils
# 0 upgraded, 62 newly installed, 0 to remove and 0 not upgraded.
# Need to get 80.7 MB of archives.
# After this operation, 325 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian bullseye/main amd64 perl-modules-5.32 all 5.32.1-4+deb11u2 [2823 kB]
# Get:2 http://deb.debian.org/debian bullseye/main amd64 libgdbm6 amd64 1.19-2 [64.9 kB]
# Get:3 http://deb.debian.org/debian bullseye/main amd64 libgdbm-compat4 amd64 1.19-2 [44.7 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 libperl5.32 amd64 5.32.1-4+deb11u2 [4106 kB]
# Get:5 http://deb.debian.org/debian bullseye/main amd64 perl amd64 5.32.1-4+deb11u2 [293 kB]
# Get:6 http://deb.debian.org/debian bullseye/main amd64 bzip2 amd64 1.0.8-4 [49.3 kB]
# Get:7 http://deb.debian.org/debian-security bullseye-security/main amd64 openssl amd64 1.1.1n-0+deb11u5 [854 kB]
# Get:8 http://deb.debian.org/debian bullseye/main amd64 ca-certificates all 20210119 [158 kB]
# Get:9 http://deb.debian.org/debian bullseye/main amd64 xz-utils amd64 5.2.5-2.1~deb11u1 [220 kB]
# Get:10 http://deb.debian.org/debian bullseye/main amd64 binutils-common amd64 2.35.2-2 [2220 kB]
# Get:11 http://deb.debian.org/debian bullseye/main amd64 libbinutils amd64 2.35.2-2 [570 kB]
# Get:12 http://deb.debian.org/debian bullseye/main amd64 libctf-nobfd0 amd64 2.35.2-2 [110 kB]
# Get:13 http://deb.debian.org/debian bullseye/main amd64 libctf0 amd64 2.35.2-2 [53.2 kB]
# Get:14 http://deb.debian.org/debian bullseye/main amd64 binutils-x86-64-linux-gnu amd64 2.35.2-2 [1809 kB]
# Get:15 http://deb.debian.org/debian bullseye/main amd64 binutils amd64 2.35.2-2 [61.2 kB]
# Get:16 http://deb.debian.org/debian bullseye/main amd64 libc-dev-bin amd64 2.31-13+deb11u6 [276 kB]
# Get:17 http://deb.debian.org/debian-security bullseye-security/main amd64 linux-libc-dev amd64 5.10.179-1 [1618 kB]
# Get:18 http://deb.debian.org/debian bullseye/main amd64 libcrypt-dev amd64 1:4.4.18-4 [104 kB]
# Get:19 http://deb.debian.org/debian bullseye/main amd64 libtirpc-dev amd64 1.3.1-1+deb11u1 [191 kB]
# Get:20 http://deb.debian.org/debian bullseye/main amd64 libnsl-dev amd64 1.3.0-2 [66.4 kB]
# Get:21 http://deb.debian.org/debian bullseye/main amd64 libc6-dev amd64 2.31-13+deb11u6 [2360 kB]
# Get:22 http://deb.debian.org/debian bullseye/main amd64 libisl23 amd64 0.23-1 [676 kB]
# Get:23 http://deb.debian.org/debian bullseye/main amd64 libmpfr6 amd64 4.1.0-3 [2012 kB]
# Get:24 http://deb.debian.org/debian bullseye/main amd64 libmpc3 amd64 1.2.0-1 [45.0 kB]
# Get:25 http://deb.debian.org/debian bullseye/main amd64 cpp-10 amd64 10.2.1-6 [8528 kB]
# Get:26 http://deb.debian.org/debian bullseye/main amd64 cpp amd64 4:10.2.1-1 [19.7 kB]
# Get:27 http://deb.debian.org/debian bullseye/main amd64 libcc1-0 amd64 10.2.1-6 [47.0 kB]
# Get:28 http://deb.debian.org/debian bullseye/main amd64 libgomp1 amd64 10.2.1-6 [99.9 kB]
# Get:29 http://deb.debian.org/debian bullseye/main amd64 libitm1 amd64 10.2.1-6 [25.8 kB]
# Get:30 http://deb.debian.org/debian bullseye/main amd64 libatomic1 amd64 10.2.1-6 [9008 B]
# Get:31 http://deb.debian.org/debian bullseye/main amd64 libasan6 amd64 10.2.1-6 [2065 kB]
# Get:32 http://deb.debian.org/debian bullseye/main amd64 liblsan0 amd64 10.2.1-6 [828 kB]
# Get:33 http://deb.debian.org/debian bullseye/main amd64 libtsan0 amd64 10.2.1-6 [2000 kB]
# Get:34 http://deb.debian.org/debian bullseye/main amd64 libubsan1 amd64 10.2.1-6 [777 kB]
# Get:35 http://deb.debian.org/debian bullseye/main amd64 libquadmath0 amd64 10.2.1-6 [145 kB]
# Get:36 http://deb.debian.org/debian bullseye/main amd64 libgcc-10-dev amd64 10.2.1-6 [2328 kB]
# Get:37 http://deb.debian.org/debian bullseye/main amd64 gcc-10 amd64 10.2.1-6 [17.0 MB]
# Get:38 http://deb.debian.org/debian bullseye/main amd64 gcc amd64 4:10.2.1-1 [5192 B]
# Get:39 http://deb.debian.org/debian bullseye/main amd64 libstdc++-10-dev amd64 10.2.1-6 [1741 kB]
# Get:40 http://deb.debian.org/debian bullseye/main amd64 g++-10 amd64 10.2.1-6 [9380 kB]
# Get:41 http://deb.debian.org/debian bullseye/main amd64 g++ amd64 4:10.2.1-1 [1644 B]
# Get:42 http://deb.debian.org/debian bullseye/main amd64 make amd64 4.3-4.1 [396 kB]
# Get:43 http://deb.debian.org/debian bullseye/main amd64 libdpkg-perl all 1.20.12 [1551 kB]
# Get:44 http://deb.debian.org/debian bullseye/main amd64 patch amd64 2.7.6-7 [128 kB]
# Get:45 http://deb.debian.org/debian bullseye/main amd64 dpkg-dev all 1.20.12 [2312 kB]
# Get:46 http://deb.debian.org/debian bullseye/main amd64 build-essential amd64 12.9 [7704 B]
# Get:47 http://deb.debian.org/debian bullseye/main amd64 libbrotli1 amd64 1.0.9-2+b2 [279 kB]
# Get:48 http://deb.debian.org/debian bullseye/main amd64 libsasl2-modules-db amd64 2.1.27+dfsg-2.1+deb11u1 [69.1 kB]
# Get:49 http://deb.debian.org/debian bullseye/main amd64 libsasl2-2 amd64 2.1.27+dfsg-2.1+deb11u1 [106 kB]
# Get:50 http://deb.debian.org/debian bullseye/main amd64 libldap-2.4-2 amd64 2.4.57+dfsg-3+deb11u1 [232 kB]
# Get:51 http://deb.debian.org/debian bullseye/main amd64 libnghttp2-14 amd64 1.43.0-1 [77.1 kB]
# Get:52 http://deb.debian.org/debian bullseye/main amd64 libpsl5 amd64 0.21.0-1.2 [57.3 kB]
# Get:53 http://deb.debian.org/debian bullseye/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-2+b2 [60.8 kB]
# Get:54 http://deb.debian.org/debian bullseye/main amd64 libssh2-1 amd64 1.9.0-2 [156 kB]
# Get:55 http://deb.debian.org/debian bullseye/main amd64 libcurl4 amd64 7.74.0-1.3+deb11u7 [346 kB]
# Get:56 http://deb.debian.org/debian bullseye/main amd64 curl amd64 7.74.0-1.3+deb11u7 [270 kB]
# Get:57 http://deb.debian.org/debian bullseye/main amd64 libcurl3-gnutls amd64 7.74.0-1.3+deb11u7 [343 kB]
# Get:58 http://deb.debian.org/debian bullseye/main amd64 libexpat1 amd64 2.2.10-2+deb11u5 [98.2 kB]
# Get:59 http://deb.debian.org/debian bullseye/main amd64 liberror-perl all 0.17029-1 [31.0 kB]
# Get:60 http://deb.debian.org/debian bullseye/main amd64 git-man all 1:2.30.2-1+deb11u2 [1828 kB]
# Get:61 http://deb.debian.org/debian bullseye/main amd64 git amd64 1:2.30.2-1+deb11u2 [5518 kB]
# Get:62 http://deb.debian.org/debian bullseye/main amd64 sudo amd64 1.9.5p2-3+deb11u1 [1061 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 80.7 MB in 1s (68.7 MB/s)
# Selecting previously unselected package perl-modules-5.32.
# (Reading database ... 6664 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.32_5.32.1-4+deb11u2_all.deb ...
# Unpacking perl-modules-5.32 (5.32.1-4+deb11u2) ...
# Selecting previously unselected package libgdbm6:amd64.
# Preparing to unpack .../01-libgdbm6_1.19-2_amd64.deb ...
# Unpacking libgdbm6:amd64 (1.19-2) ...
# Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.19-2_amd64.deb ...
# Unpacking libgdbm-compat4:amd64 (1.19-2) ...
# Selecting previously unselected package libperl5.32:amd64.
# Preparing to unpack .../03-libperl5.32_5.32.1-4+deb11u2_amd64.deb ...
# Unpacking libperl5.32:amd64 (5.32.1-4+deb11u2) ...
# Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.32.1-4+deb11u2_amd64.deb ...
# Unpacking perl (5.32.1-4+deb11u2) ...
# Selecting previously unselected package bzip2.
# Preparing to unpack .../05-bzip2_1.0.8-4_amd64.deb ...
# Unpacking bzip2 (1.0.8-4) ...
# Selecting previously unselected package openssl.
# Preparing to unpack .../06-openssl_1.1.1n-0+deb11u5_amd64.deb ...
# Unpacking openssl (1.1.1n-0+deb11u5) ...
# Selecting previously unselected package ca-certificates.
# Preparing to unpack .../07-ca-certificates_20210119_all.deb ...
# Unpacking ca-certificates (20210119) ...
# Selecting previously unselected package xz-utils.
# Preparing to unpack .../08-xz-utils_5.2.5-2.1~deb11u1_amd64.deb ...
# Unpacking xz-utils (5.2.5-2.1~deb11u1) ...
# Selecting previously unselected package binutils-common:amd64.
# Preparing to unpack .../09-binutils-common_2.35.2-2_amd64.deb ...
# Unpacking binutils-common:amd64 (2.35.2-2) ...
# Selecting previously unselected package libbinutils:amd64.
# Preparing to unpack .../10-libbinutils_2.35.2-2_amd64.deb ...
# Unpacking libbinutils:amd64 (2.35.2-2) ...
# Selecting previously unselected package libctf-nobfd0:amd64.
# Preparing to unpack .../11-libctf-nobfd0_2.35.2-2_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.35.2-2) ...
# Selecting previously unselected package libctf0:amd64.
# Preparing to unpack .../12-libctf0_2.35.2-2_amd64.deb ...
# Unpacking libctf0:amd64 (2.35.2-2) ...
# Selecting previously unselected package binutils-x86-64-linux-gnu.
# Preparing to unpack .../13-binutils-x86-64-linux-gnu_2.35.2-2_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.35.2-2) ...
# Selecting previously unselected package binutils.
# Preparing to unpack .../14-binutils_2.35.2-2_amd64.deb ...
# Unpacking binutils (2.35.2-2) ...
# Selecting previously unselected package libc-dev-bin.
# Preparing to unpack .../15-libc-dev-bin_2.31-13+deb11u6_amd64.deb ...
# Unpacking libc-dev-bin (2.31-13+deb11u6) ...
# Selecting previously unselected package linux-libc-dev:amd64.
# Preparing to unpack .../16-linux-libc-dev_5.10.179-1_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (5.10.179-1) ...
# Selecting previously unselected package libcrypt-dev:amd64.
# Preparing to unpack .../17-libcrypt-dev_1%3a4.4.18-4_amd64.deb ...
# Unpacking libcrypt-dev:amd64 (1:4.4.18-4) ...
# Selecting previously unselected package libtirpc-dev:amd64.
# Preparing to unpack .../18-libtirpc-dev_1.3.1-1+deb11u1_amd64.deb ...
# Unpacking libtirpc-dev:amd64 (1.3.1-1+deb11u1) ...
# Selecting previously unselected package libnsl-dev:amd64.
# Preparing to unpack .../19-libnsl-dev_1.3.0-2_amd64.deb ...
# Unpacking libnsl-dev:amd64 (1.3.0-2) ...
# Selecting previously unselected package libc6-dev:amd64.
# Preparing to unpack .../20-libc6-dev_2.31-13+deb11u6_amd64.deb ...
# Unpacking libc6-dev:amd64 (2.31-13+deb11u6) ...
# Selecting previously unselected package libisl23:amd64.
# Preparing to unpack .../21-libisl23_0.23-1_amd64.deb ...
# Unpacking libisl23:amd64 (0.23-1) ...
# Selecting previously unselected package libmpfr6:amd64.
# Preparing to unpack .../22-libmpfr6_4.1.0-3_amd64.deb ...
# Unpacking libmpfr6:amd64 (4.1.0-3) ...
# Selecting previously unselected package libmpc3:amd64.
# Preparing to unpack .../23-libmpc3_1.2.0-1_amd64.deb ...
# Unpacking libmpc3:amd64 (1.2.0-1) ...
# Selecting previously unselected package cpp-10.
# Preparing to unpack .../24-cpp-10_10.2.1-6_amd64.deb ...
# Unpacking cpp-10 (10.2.1-6) ...
# Selecting previously unselected package cpp.
# Preparing to unpack .../25-cpp_4%3a10.2.1-1_amd64.deb ...
# Unpacking cpp (4:10.2.1-1) ...
# Selecting previously unselected package libcc1-0:amd64.
# Preparing to unpack .../26-libcc1-0_10.2.1-6_amd64.deb ...
# Unpacking libcc1-0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../27-libgomp1_10.2.1-6_amd64.deb ...
# Unpacking libgomp1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libitm1:amd64.
# Preparing to unpack .../28-libitm1_10.2.1-6_amd64.deb ...
# Unpacking libitm1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../29-libatomic1_10.2.1-6_amd64.deb ...
# Unpacking libatomic1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libasan6:amd64.
# Preparing to unpack .../30-libasan6_10.2.1-6_amd64.deb ...
# Unpacking libasan6:amd64 (10.2.1-6) ...
# Selecting previously unselected package liblsan0:amd64.
# Preparing to unpack .../31-liblsan0_10.2.1-6_amd64.deb ...
# Unpacking liblsan0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libtsan0:amd64.
# Preparing to unpack .../32-libtsan0_10.2.1-6_amd64.deb ...
# Unpacking libtsan0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libubsan1:amd64.
# Preparing to unpack .../33-libubsan1_10.2.1-6_amd64.deb ...
# Unpacking libubsan1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libquadmath0:amd64.
# Preparing to unpack .../34-libquadmath0_10.2.1-6_amd64.deb ...
# Unpacking libquadmath0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libgcc-10-dev:amd64.
# Preparing to unpack .../35-libgcc-10-dev_10.2.1-6_amd64.deb ...
# Unpacking libgcc-10-dev:amd64 (10.2.1-6) ...
# Selecting previously unselected package gcc-10.
# Preparing to unpack .../36-gcc-10_10.2.1-6_amd64.deb ...
# Unpacking gcc-10 (10.2.1-6) ...
# Selecting previously unselected package gcc.
# Preparing to unpack .../37-gcc_4%3a10.2.1-1_amd64.deb ...
# Unpacking gcc (4:10.2.1-1) ...
# Selecting previously unselected package libstdc++-10-dev:amd64.
# Preparing to unpack .../38-libstdc++-10-dev_10.2.1-6_amd64.deb ...
# Unpacking libstdc++-10-dev:amd64 (10.2.1-6) ...
# Selecting previously unselected package g++-10.
# Preparing to unpack .../39-g++-10_10.2.1-6_amd64.deb ...
# Unpacking g++-10 (10.2.1-6) ...
# Selecting previously unselected package g++.
# Preparing to unpack .../40-g++_4%3a10.2.1-1_amd64.deb ...
# Unpacking g++ (4:10.2.1-1) ...
# Selecting previously unselected package make.
# Preparing to unpack .../41-make_4.3-4.1_amd64.deb ...
# Unpacking make (4.3-4.1) ...
# Selecting previously unselected package libdpkg-perl.
# Preparing to unpack .../42-libdpkg-perl_1.20.12_all.deb ...
# Unpacking libdpkg-perl (1.20.12) ...
# Selecting previously unselected package patch.
# Preparing to unpack .../43-patch_2.7.6-7_amd64.deb ...
# Unpacking patch (2.7.6-7) ...
# Selecting previously unselected package dpkg-dev.
# Preparing to unpack .../44-dpkg-dev_1.20.12_all.deb ...
# Unpacking dpkg-dev (1.20.12) ...
# Selecting previously unselected package build-essential.
# Preparing to unpack .../45-build-essential_12.9_amd64.deb ...
# Unpacking build-essential (12.9) ...
# Selecting previously unselected package libbrotli1:amd64.
# Preparing to unpack .../46-libbrotli1_1.0.9-2+b2_amd64.deb ...
# Unpacking libbrotli1:amd64 (1.0.9-2+b2) ...
# Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../47-libsasl2-modules-db_2.1.27+dfsg-2.1+deb11u1_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../48-libsasl2-2_2.1.27+dfsg-2.1+deb11u1_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../49-libldap-2.4-2_2.4.57+dfsg-3+deb11u1_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
# Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../50-libnghttp2-14_1.43.0-1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.43.0-1) ...
# Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../51-libpsl5_0.21.0-1.2_amd64.deb ...
# Unpacking libpsl5:amd64 (0.21.0-1.2) ...
# Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../52-librtmp1_2.4+20151223.gitfa8646d.1-2+b2_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
# Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../53-libssh2-1_1.9.0-2_amd64.deb ...
# Unpacking libssh2-1:amd64 (1.9.0-2) ...
# Selecting previously unselected package libcurl4:amd64.
# Preparing to unpack .../54-libcurl4_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking libcurl4:amd64 (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package curl.
# Preparing to unpack .../55-curl_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking curl (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../56-libcurl3-gnutls_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../57-libexpat1_2.2.10-2+deb11u5_amd64.deb ...
# Unpacking libexpat1:amd64 (2.2.10-2+deb11u5) ...
# Selecting previously unselected package liberror-perl.
# Preparing to unpack .../58-liberror-perl_0.17029-1_all.deb ...
# Unpacking liberror-perl (0.17029-1) ...
# Selecting previously unselected package git-man.
# Preparing to unpack .../59-git-man_1%3a2.30.2-1+deb11u2_all.deb ...
# Unpacking git-man (1:2.30.2-1+deb11u2) ...
# Selecting previously unselected package git.
# Preparing to unpack .../60-git_1%3a2.30.2-1+deb11u2_amd64.deb ...
# Unpacking git (1:2.30.2-1+deb11u2) ...
# Selecting previously unselected package sudo.
# Preparing to unpack .../61-sudo_1.9.5p2-3+deb11u1_amd64.deb ...
# Unpacking sudo (1.9.5p2-3+deb11u1) ...
# Setting up libexpat1:amd64 (2.2.10-2+deb11u5) ...
# Setting up libpsl5:amd64 (0.21.0-1.2) ...
# Setting up perl-modules-5.32 (5.32.1-4+deb11u2) ...
# Setting up libbrotli1:amd64 (1.0.9-2+b2) ...
# Setting up binutils-common:amd64 (2.35.2-2) ...
# Setting up libnghttp2-14:amd64 (1.43.0-1) ...
# Setting up linux-libc-dev:amd64 (5.10.179-1) ...
# Setting up libctf-nobfd0:amd64 (2.35.2-2) ...
# Setting up libgomp1:amd64 (10.2.1-6) ...
# Setting up bzip2 (1.0.8-4) ...
# Setting up libasan6:amd64 (10.2.1-6) ...
# Setting up libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Setting up libtirpc-dev:amd64 (1.3.1-1+deb11u1) ...
# Setting up make (4.3-4.1) ...
# Setting up libmpfr6:amd64 (4.1.0-3) ...
# Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
# Setting up xz-utils (5.2.5-2.1~deb11u1) ...
# update-alternatives: using /usr/bin/xz to provide /usr/bin/lzma (lzma) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzma.1.gz because associated file /usr/share/man/man1/xz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/unlzma.1.gz because associated file /usr/share/man/man1/unxz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcat.1.gz because associated file /usr/share/man/man1/xzcat.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzmore.1.gz because associated file /usr/share/man/man1/xzmore.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzless.1.gz because associated file /usr/share/man/man1/xzless.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzdiff.1.gz because associated file /usr/share/man/man1/xzdiff.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcmp.1.gz because associated file /usr/share/man/man1/xzcmp.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzgrep.1.gz because associated file /usr/share/man/man1/xzgrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzegrep.1.gz because associated file /usr/share/man/man1/xzegrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzfgrep.1.gz because associated file /usr/share/man/man1/xzfgrep.1.gz (of link group lzma) doesn't exist
# Setting up libquadmath0:amd64 (10.2.1-6) ...
# Setting up libmpc3:amd64 (1.2.0-1) ...
# Setting up libatomic1:amd64 (10.2.1-6) ...
# Setting up patch (2.7.6-7) ...
# Setting up sudo (1.9.5p2-3+deb11u1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Setting up libubsan1:amd64 (10.2.1-6) ...
# Setting up libnsl-dev:amd64 (1.3.0-2) ...
# Setting up libcrypt-dev:amd64 (1:4.4.18-4) ...
# Setting up git-man (1:2.30.2-1+deb11u2) ...
# Setting up libssh2-1:amd64 (1.9.0-2) ...
# Setting up libbinutils:amd64 (2.35.2-2) ...
# Setting up libisl23:amd64 (0.23-1) ...
# Setting up libc-dev-bin (2.31-13+deb11u6) ...
# Setting up openssl (1.1.1n-0+deb11u5) ...
# Setting up libcc1-0:amd64 (10.2.1-6) ...
# Setting up liblsan0:amd64 (10.2.1-6) ...
# Setting up cpp-10 (10.2.1-6) ...
# Setting up libitm1:amd64 (10.2.1-6) ...
# Setting up libgdbm6:amd64 (1.19-2) ...
# Setting up libtsan0:amd64 (10.2.1-6) ...
# Setting up libctf0:amd64 (2.35.2-2) ...
# Setting up libgcc-10-dev:amd64 (10.2.1-6) ...
# Setting up libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
# Setting up libcurl3-gnutls:amd64 (7.74.0-1.3+deb11u7) ...
# Setting up ca-certificates (20210119) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# Updating certificates in /etc/ssl/certs...
# 129 added, 0 removed; done.
# Setting up libgdbm-compat4:amd64 (1.19-2) ...
# Setting up libperl5.32:amd64 (5.32.1-4+deb11u2) ...
# Setting up cpp (4:10.2.1-1) ...
# Setting up libcurl4:amd64 (7.74.0-1.3+deb11u7) ...
# Setting up libc6-dev:amd64 (2.31-13+deb11u6) ...
# Setting up curl (7.74.0-1.3+deb11u7) ...
# Setting up binutils-x86-64-linux-gnu (2.35.2-2) ...
# Setting up libstdc++-10-dev:amd64 (10.2.1-6) ...
# Setting up binutils (2.35.2-2) ...
# Setting up perl (5.32.1-4+deb11u2) ...
# Setting up gcc-10 (10.2.1-6) ...
# Setting up libdpkg-perl (1.20.12) ...
# Setting up g++-10 (10.2.1-6) ...
# Setting up gcc (4:10.2.1-1) ...
# Setting up dpkg-dev (1.20.12) ...
# Setting up liberror-perl (0.17029-1) ...
# Setting up git (1:2.30.2-1+deb11u2) ...
# Setting up g++ (4:10.2.1-1) ...
# update-alternatives: using /usr/bin/g++ to provide /usr/bin/c++ (c++) in auto mode
# Setting up build-essential (12.9) ...
# Processing triggers for libc-bin (2.31-13+deb11u6) ...
# Processing triggers for ca-certificates (20210119) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
# done.
# WARN[0048] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> cc338374bf2
# STEP 6/13: RUN echo $USERNAME ALL=\(root\) NOPASSWD:ALL > /etc/sudoers.d/$USERNAME     && chmod 0440 /etc/sudoers.d/$USERNAME
# WARN[0060] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 961ca013944
# STEP 7/13: RUN mkdir -p /srv/conda && chown -R mambauser:1000 /srv/conda/
# WARN[0064] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> b5741f08c12
# STEP 8/13: RUN mkdir -p /workspaces/command-line-tools/crop
# WARN[0068] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 1fdacba2917
# STEP 9/13: RUN chown -R 1000:1000 /workspaces/command-line-tools/crop
# WARN[0073] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> eaa1ff818fb
# STEP 10/13: USER mambauser
# WARN[0077] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> ed47649f1b5
# STEP 11/13: RUN micromamba create -r /srv/conda -n env_crop -c conda-forge gdal click pystac
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
#
# Transaction
#
#   Prefix: /srv/conda/envs/env_crop
#
#   Updating specs:
#
#    - gdal
#    - click
#    - pystac
#
#
#   Package                           Version  Build                Channel          Size
# ─────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                       0.1  conda_forge          conda-forge       3kB
#   + _openmp_mutex                       4.5  2_gnu                conda-forge      24kB
#   + blosc                            1.21.4  h0f2a231_0           conda-forge      49kB
#   + boost-cpp                        1.78.0  h6582d0a_3           conda-forge      16MB
#   + bzip2                             1.0.8  h7f98852_4           conda-forge     496kB
#   + c-ares                           1.19.1  hd590300_0           conda-forge     113kB
#   + ca-certificates                2023.5.7  hbcca054_0           conda-forge     148kB
#   + cairo                            1.16.0  hbbf8b49_1016        conda-forge       1MB
#   + cfitsio                           4.2.0  hd9d235c_0           conda-forge     848kB
#   + click                             8.1.3  unix_pyhd8ed1ab_2    conda-forge      76kB
#   + curl                              8.1.2  h409715c_0           conda-forge      91kB
#   + expat                             2.5.0  hcb278e6_1           conda-forge     137kB
#   + font-ttf-dejavu-sans-mono          2.37  hab24e00_0           conda-forge     397kB
#   + font-ttf-inconsolata              3.000  h77eed37_0           conda-forge      97kB
#   + font-ttf-source-code-pro          2.038  h77eed37_0           conda-forge     701kB
#   + font-ttf-ubuntu                    0.83  hab24e00_0           conda-forge       2MB
#   + fontconfig                       2.14.2  h14ed4e7_0           conda-forge     272kB
#   + fonts-conda-ecosystem                 1  0                    conda-forge       4kB
#   + fonts-conda-forge                     1  0                    conda-forge       4kB
#   + freetype                         2.12.1  hca18f0e_1           conda-forge     626kB
#   + freexl                            1.0.6  h166bdaf_1           conda-forge      50kB
#   + gdal                              3.7.0  py311h281082f_2      conda-forge       2MB
#   + geos                             3.11.2  hcb278e6_0           conda-forge       2MB
#   + geotiff                           1.7.1  h22adcc9_9           conda-forge     257kB
#   + gettext                          0.21.1  h27087fc_0           conda-forge       4MB
#   + giflib                            5.2.1  h0b41bf4_3           conda-forge      77kB
#   + hdf4                             4.2.15  h501b40f_6           conda-forge     758kB
#   + hdf5                             1.14.0  nompi_hb72d44e_103   conda-forge       4MB
#   + icu                                72.1  hcb278e6_0           conda-forge      12MB
#   + json-c                             0.16  hc379101_0           conda-forge     281kB
#   + kealib                            1.5.1  h3845be2_3           conda-forge     173kB
#   + keyutils                          1.6.1  h166bdaf_0           conda-forge     118kB
#   + krb5                             1.20.1  h81ceb04_0           conda-forge       1MB
#   + lcms2                              2.15  haa2dc70_1           conda-forge     242kB
#   + ld_impl_linux-64                   2.40  h41732ed_0           conda-forge     705kB
#   + lerc                              4.0.0  h27087fc_0           conda-forge     282kB
#   + libaec                            1.0.6  hcb278e6_1           conda-forge      34kB
#   + libarchive                        3.6.2  h039dbb9_1           conda-forge     844kB
#   + libblas                           3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libcblas                          3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libcurl                           8.1.2  h409715c_0           conda-forge     373kB
#   + libdeflate                         1.18  h0b41bf4_0           conda-forge      65kB
#   + libedit                    3.1.20191231  he28a2e2_2           conda-forge     124kB
#   + libev                              4.33  h516909a_1           conda-forge     106kB
#   + libexpat                          2.5.0  hcb278e6_1           conda-forge      78kB
#   + libffi                            3.4.2  h7f98852_5           conda-forge      58kB
#   + libgcc-ng                        13.1.0  he5830b7_0           conda-forge     776kB
#   + libgdal                           3.7.0  h5418a03_2           conda-forge      11MB
#   + libgfortran-ng                   13.1.0  h69a702a_0           conda-forge      23kB
#   + libgfortran5                     13.1.0  h15d22d2_0           conda-forge       1MB
#   + libglib                          2.76.3  hebfc3b9_0           conda-forge       3MB
#   + libgomp                          13.1.0  he5830b7_0           conda-forge     419kB
#   + libiconv                           1.17  h166bdaf_0           conda-forge       1MB
#   + libjpeg-turbo                   2.1.5.1  h0b41bf4_0           conda-forge     491kB
#   + libkml                            1.3.0  h37653c0_1015        conda-forge     625kB
#   + liblapack                         3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libnetcdf                         4.9.2  nompi_h0f3d0bb_105   conda-forge     841kB
#   + libnghttp2                       1.52.0  h61bc06f_0           conda-forge     622kB
#   + libnsl                            2.0.0  h7f98852_0           conda-forge      31kB
#   + libopenblas                      0.3.23  pthreads_h80387f5_0  conda-forge       5MB
#   + libpng                           1.6.39  h753d276_0           conda-forge     283kB
#   + libpq                              15.3  hbcd7760_1           conda-forge       3MB
#   + librttopo                         1.1.0  h0d5128d_13          conda-forge     234kB
#   + libspatialite                     5.0.1  hca56755_27          conda-forge       3MB
#   + libsqlite                        3.42.0  h2797004_0           conda-forge     829kB
#   + libssh2                          1.11.0  h0841786_0           conda-forge     271kB
#   + libstdcxx-ng                     13.1.0  hfd8a6a1_0           conda-forge       4MB
#   + libtiff                           4.5.0  ha587672_6           conda-forge     407kB
#   + libuuid                          2.38.1  h0b41bf4_0           conda-forge      34kB
#   + libwebp-base                      1.3.0  h0b41bf4_0           conda-forge     357kB
#   + libxcb                             1.15  h0b41bf4_0           conda-forge     384kB
#   + libxml2                          2.11.4  h0d562d8_0           conda-forge     704kB
#   + libzip                            1.9.2  hc929e4a_1           conda-forge      99kB
#   + libzlib                          1.2.13  h166bdaf_4           conda-forge      66kB
#   + lz4-c                             1.9.4  hcb278e6_0           conda-forge     143kB
#   + lzo                                2.10  h516909a_1000        conda-forge     321kB
#   + ncurses                             6.3  h27087fc_1           conda-forge       1MB
#   + nspr                               4.35  h27087fc_0           conda-forge     227kB
#   + nss                                3.89  he45b914_0           conda-forge       2MB
#   + numpy                            1.24.3  py311h64a7726_0      conda-forge       8MB
#   + openjpeg                          2.5.0  hfec8fc6_2           conda-forge     352kB
#   + openssl                           3.1.1  hd590300_1           conda-forge       3MB
#   + pcre2                             10.40  hc3806b6_0           conda-forge       2MB
#   + pip                              23.1.2  pyhd8ed1ab_0         conda-forge       1MB
#   + pixman                           0.40.0  h36c2ea0_0           conda-forge     643kB
#   + poppler                         23.05.0  hd18248d_1           conda-forge      15MB
#   + poppler-data                     0.4.12  hd8ed1ab_0           conda-forge       2MB
#   + postgresql                         15.3  hd458b1d_1           conda-forge       5MB
#   + proj                              9.2.1  ha643af7_0           conda-forge       3MB
#   + pthread-stubs                       0.4  h36c2ea0_1001        conda-forge       6kB
#   + pystac                            1.7.3  pyhd8ed1ab_0         conda-forge      99kB
#   + python                           3.11.3  h2755cc3_0_cpython   conda-forge      31MB
#   + python-dateutil                   2.8.2  pyhd8ed1ab_0         conda-forge     246kB
#   + python_abi                         3.11  3_cp311              conda-forge       6kB
#   + readline                            8.2  h8228510_1           conda-forge     281kB
#   + setuptools                       67.7.2  pyhd8ed1ab_0         conda-forge     583kB
#   + six                              1.16.0  pyh6c4a22f_0         conda-forge      14kB
#   + snappy                           1.1.10  h9fff704_0           conda-forge      39kB
#   + sqlite                           3.42.0  h2c6b66d_0           conda-forge     818kB
#   + tiledb                           2.13.2  hd532e3d_0           conda-forge       5MB
#   + tk                               8.6.12  h27826a3_0           conda-forge       3MB
#   + tzcode                            2023c  h0b41bf4_0           conda-forge      69kB
#   + tzdata                            2023c  h71feb2d_0           conda-forge     118kB
#   + wheel                            0.40.0  pyhd8ed1ab_0         conda-forge      56kB
#   + xerces-c                          3.2.4  h8d71039_2           conda-forge       2MB
#   + xorg-kbproto                      1.0.7  h7f98852_1002        conda-forge      27kB
#   + xorg-libice                       1.1.1  hd590300_0           conda-forge      58kB
#   + xorg-libsm                        1.2.4  h7391055_0           conda-forge      27kB
#   + xorg-libx11                       1.8.4  h8ee46fc_1           conda-forge     833kB
#   + xorg-libxau                      1.0.11  hd590300_0           conda-forge      14kB
#   + xorg-libxdmcp                     1.1.3  h7f98852_0           conda-forge      19kB
#   + xorg-libxext                      1.3.4  h0b41bf4_2           conda-forge      50kB
#   + xorg-libxrender                  0.9.10  h7f98852_1003        conda-forge      33kB
#   + xorg-renderproto                 0.11.1  h7f98852_1002        conda-forge      10kB
#   + xorg-xextproto                    7.3.0  h0b41bf4_1003        conda-forge      30kB
#   + xorg-xproto                      7.0.31  h7f98852_1007        conda-forge      75kB
#   + xz                                5.2.6  h166bdaf_0           conda-forge     418kB
#   + zlib                             1.2.13  h166bdaf_4           conda-forge      94kB
#   + zstd                              1.5.2  h3eb15da_6           conda-forge     420kB
#
#   Summary:
#
#   Install: 119 packages
#
#   Total download: 181MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#
# Confirm changes: [Y/n]
# Transaction starting
# Linking font-ttf-dejavu-sans-mono-2.37-hab24e00_0
# Linking font-ttf-ubuntu-0.83-hab24e00_0
# Linking font-ttf-inconsolata-3.000-h77eed37_0
# Linking font-ttf-source-code-pro-2.038-h77eed37_0
# Linking tzdata-2023c-h71feb2d_0
# Linking poppler-data-0.4.12-hd8ed1ab_0
# Linking fonts-conda-forge-1-0
# Linking fonts-conda-ecosystem-1-0
# Linking _libgcc_mutex-0.1-conda_forge
# Linking libstdcxx-ng-13.1.0-hfd8a6a1_0
# Linking ld_impl_linux-64-2.40-h41732ed_0
# Linking ca-certificates-2023.5.7-hbcca054_0
# Linking libgfortran5-13.1.0-h15d22d2_0
# Linking python_abi-3.11-3_cp311
# Linking libgomp-13.1.0-he5830b7_0
# Linking libgfortran-ng-13.1.0-h69a702a_0
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-ng-13.1.0-he5830b7_0
# Linking xorg-xproto-7.0.31-h7f98852_1007
# Linking xorg-kbproto-1.0.7-h7f98852_1002
# Linking xorg-renderproto-0.11.1-h7f98852_1002
# Linking lzo-2.10-h516909a_1000
# Linking xorg-libxdmcp-1.1.3-h7f98852_0
# Linking pthread-stubs-0.4-h36c2ea0_1001
# Linking libopenblas-0.3.23-pthreads_h80387f5_0
# Linking tzcode-2023c-h0b41bf4_0
# Linking xorg-xextproto-7.3.0-h0b41bf4_1003
# Linking xorg-libice-1.1.1-hd590300_0
# Linking libaec-1.0.6-hcb278e6_1
# Linking lz4-c-1.9.4-hcb278e6_0
# Linking giflib-5.2.1-h0b41bf4_3
# Linking libev-4.33-h516909a_1
# Linking c-ares-1.19.1-hd590300_0
# Linking freexl-1.0.6-h166bdaf_1
# Linking xorg-libxau-1.0.11-hd590300_0
# Linking pixman-0.40.0-h36c2ea0_0
# Linking keyutils-1.6.1-h166bdaf_0
# Linking openssl-3.1.1-hd590300_1
# Linking libffi-3.4.2-h7f98852_5
# Linking bzip2-1.0.8-h7f98852_4
# Linking ncurses-6.3-h27087fc_1
# Linking libnsl-2.0.0-h7f98852_0
# Linking nspr-4.35-h27087fc_0
# Linking gettext-0.21.1-h27087fc_0
# Linking snappy-1.1.10-h9fff704_0
# Linking libwebp-base-1.3.0-h0b41bf4_0
# Linking libuuid-2.38.1-h0b41bf4_0
# Linking libjpeg-turbo-2.1.5.1-h0b41bf4_0
# Linking libexpat-2.5.0-hcb278e6_1
# Linking libdeflate-1.18-h0b41bf4_0
# Linking icu-72.1-hcb278e6_0
# Linking geos-3.11.2-hcb278e6_0
# Linking xz-5.2.6-h166bdaf_0
# Linking libzlib-1.2.13-h166bdaf_4
# Linking libiconv-1.17-h166bdaf_0
# Linking lerc-4.0.0-h27087fc_0
# Linking json-c-0.16-hc379101_0
# Linking libblas-3.9.0-17_linux64_openblas
# Linking libxcb-1.15-h0b41bf4_0
# Linking libedit-3.1.20191231-he28a2e2_2
# Linking readline-8.2-h8228510_1
# Linking xorg-libsm-1.2.4-h7391055_0
# Linking expat-2.5.0-hcb278e6_1
# Linking librttopo-1.1.0-h0d5128d_13
# Linking libzip-1.9.2-hc929e4a_1
# Linking libssh2-1.11.0-h0841786_0
# Linking zstd-1.5.2-h3eb15da_6
# Linking tk-8.6.12-h27826a3_0
# Linking zlib-1.2.13-h166bdaf_4
# Linking hdf4-4.2.15-h501b40f_6
# Linking libnghttp2-1.52.0-h61bc06f_0
# Linking libsqlite-3.42.0-h2797004_0
# Linking libpng-1.6.39-h753d276_0
# Linking pcre2-10.40-hc3806b6_0
# Linking libxml2-2.11.4-h0d562d8_0
# Linking libcblas-3.9.0-17_linux64_openblas
# Linking liblapack-3.9.0-17_linux64_openblas
# Linking xorg-libx11-1.8.4-h8ee46fc_1
# Linking krb5-1.20.1-h81ceb04_0
# Linking libtiff-4.5.0-ha587672_6
# Linking boost-cpp-1.78.0-h6582d0a_3
# Linking blosc-1.21.4-h0f2a231_0
# Linking sqlite-3.42.0-h2c6b66d_0
# Linking python-3.11.3-h2755cc3_0_cpython
# Linking nss-3.89-he45b914_0
# Linking freetype-2.12.1-hca18f0e_1
# Linking libglib-2.76.3-hebfc3b9_0
# Linking libarchive-3.6.2-h039dbb9_1
# Linking xorg-libxext-1.3.4-h0b41bf4_2
# Linking xorg-libxrender-0.9.10-h7f98852_1003
# Linking libpq-15.3-hbcd7760_1
# Linking libcurl-8.1.2-h409715c_0
# Linking openjpeg-2.5.0-hfec8fc6_2
# Linking lcms2-2.15-haa2dc70_1
# Linking libkml-1.3.0-h37653c0_1015
# Linking fontconfig-2.14.2-h14ed4e7_0
# Linking postgresql-15.3-hd458b1d_1
# Linking hdf5-1.14.0-nompi_hb72d44e_103
# Linking curl-8.1.2-h409715c_0
# Linking xerces-c-3.2.4-h8d71039_2
# Linking proj-9.2.1-ha643af7_0
# Linking cfitsio-4.2.0-hd9d235c_0
# Linking cairo-1.16.0-hbbf8b49_1016
# Linking kealib-1.5.1-h3845be2_3
# Linking libnetcdf-4.9.2-nompi_h0f3d0bb_105
# Linking tiledb-2.13.2-hd532e3d_0
# Linking geotiff-1.7.1-h22adcc9_9
# Linking libspatialite-5.0.1-hca56755_27
# Linking poppler-23.05.0-hd18248d_1
# Linking libgdal-3.7.0-h5418a03_2
# Linking wheel-0.40.0-pyhd8ed1ab_0
# Linking setuptools-67.7.2-pyhd8ed1ab_0
# Linking pip-23.1.2-pyhd8ed1ab_0
# Linking six-1.16.0-pyh6c4a22f_0
# Linking click-8.1.3-unix_pyhd8ed1ab_2
# Linking python-dateutil-2.8.2-pyhd8ed1ab_0
# Linking pystac-1.7.3-pyhd8ed1ab_0
# Linking numpy-1.24.3-py311h64a7726_0
# Linking gdal-3.7.0-py311h281082f_2
#
# Transaction finished
#
# To activate this environment, use:
#
#     micromamba activate env_crop
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -n env_crop mycommand
#
# WARN[0130] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 62b5c506007
# STEP 12/13: ADD water-bodies/command-line-tools/crop/app.py /workspaces/command-line-tools/crop/app.py
# WARN[0211] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 3b2bf73bb0a
# STEP 13/13: WORKDIR /home/mambauser
# COMMIT simonevaccari/crop:0.1.0
# WARN[0241] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 1fa483aa563
# Successfully tagged localhost/simonevaccari/crop:0.1.0
# 1fa483aa5638b8869076a26ec129166ff0775e4449a9fb83c9bd18973d232968

# %%
# !docker build -t simonevaccari/norm_diff:0.1.0 --no-cache -f water-bodies/command-line-tools/norm_diff/Dockerfile .
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# STEP 1/13: FROM docker.io/mambaorg/micromamba:latest
# STEP 2/13: USER root
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> ffb422349d8
# STEP 3/13: ENV USERNAME=mambauser
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 238f9e75d1c
# STEP 4/13: ENV PATH=/srv/conda/envs/env_norm_diff/bin:$PATH
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> c39ab02236e
# STEP 5/13: RUN apt-get update -y  && apt-get upgrade -y  && apt-get install -y --no-install-recommends         ca-certificates         curl sudo git gcc build-essential
# Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
# Get:2 http://deb.debian.org/debian-security bullseye-security InRelease [48.4 kB]
# Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183 kB]
# Get:5 http://deb.debian.org/debian-security bullseye-security/main amd64 Packages [245 kB]
# Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Packages [14.8 kB]
# Fetched 8650 kB in 2s (4640 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Calculating upgrade...
# The following packages will be upgraded:
#   libssl1.1
# 1 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Need to get 1559 kB of archives.
# After this operation, 4096 B disk space will be freed.
# Get:1 http://deb.debian.org/debian-security bullseye-security/main amd64 libssl1.1 amd64 1.1.1n-0+deb11u5 [1559 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 1559 kB in 0s (26.0 MB/s)
# (Reading database ... 6664 files and directories currently installed.)
# Preparing to unpack .../libssl1.1_1.1.1n-0+deb11u5_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1n-0+deb11u5) over (1.1.1n-0+deb11u4) ...
# Setting up libssl1.1:amd64 (1.1.1n-0+deb11u5) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.32.1 /usr/local/share/perl/5.32.1 /usr/lib/x86_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
# Processing triggers for libc-bin (2.31-13+deb11u6) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu bzip2 cpp cpp-10 dpkg-dev
#   g++ g++-10 gcc-10 git-man libasan6 libatomic1 libbinutils libbrotli1
#   libc-dev-bin libc6-dev libcc1-0 libcrypt-dev libctf-nobfd0 libctf0
#   libcurl3-gnutls libcurl4 libdpkg-perl liberror-perl libexpat1 libgcc-10-dev
#   libgdbm-compat4 libgdbm6 libgomp1 libisl23 libitm1 libldap-2.4-2 liblsan0
#   libmpc3 libmpfr6 libnghttp2-14 libnsl-dev libperl5.32 libpsl5 libquadmath0
#   librtmp1 libsasl2-2 libsasl2-modules-db libssh2-1 libstdc++-10-dev
#   libtirpc-dev libtsan0 libubsan1 linux-libc-dev make openssl patch perl
#   perl-modules-5.32 xz-utils
# Suggested packages:
#   binutils-doc bzip2-doc cpp-doc gcc-10-locales debian-keyring g++-multilib
#   g++-10-multilib gcc-10-doc gcc-multilib manpages-dev autoconf automake
#   libtool flex bison gdb gcc-doc gcc-10-multilib gettext-base git-daemon-run
#   | git-daemon-sysvinit git-doc git-el git-email git-gui gitk gitweb git-cvs
#   git-mediawiki git-svn glibc-doc gnupg sensible-utils bzr gdbm-l10n
#   libstdc++-10-doc make-doc ed diffutils-doc perl-doc
#   libterm-readline-gnu-perl | libterm-readline-perl-perl
#   libtap-harness-archive-perl
# Recommended packages:
#   fakeroot gnupg libalgorithm-merge-perl less ssh-client manpages manpages-dev
#   libc-devtools libfile-fcntllock-perl liblocale-gettext-perl libldap-common
#   publicsuffix libsasl2-modules netbase
# The following NEW packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu build-essential bzip2
#   ca-certificates cpp cpp-10 curl dpkg-dev g++ g++-10 gcc gcc-10 git git-man
#   libasan6 libatomic1 libbinutils libbrotli1 libc-dev-bin libc6-dev libcc1-0
#   libcrypt-dev libctf-nobfd0 libctf0 libcurl3-gnutls libcurl4 libdpkg-perl
#   liberror-perl libexpat1 libgcc-10-dev libgdbm-compat4 libgdbm6 libgomp1
#   libisl23 libitm1 libldap-2.4-2 liblsan0 libmpc3 libmpfr6 libnghttp2-14
#   libnsl-dev libperl5.32 libpsl5 libquadmath0 librtmp1 libsasl2-2
#   libsasl2-modules-db libssh2-1 libstdc++-10-dev libtirpc-dev libtsan0
#   libubsan1 linux-libc-dev make openssl patch perl perl-modules-5.32 sudo
#   xz-utils
# 0 upgraded, 62 newly installed, 0 to remove and 0 not upgraded.
# Need to get 80.7 MB of archives.
# After this operation, 325 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian bullseye/main amd64 perl-modules-5.32 all 5.32.1-4+deb11u2 [2823 kB]
# Get:2 http://deb.debian.org/debian bullseye/main amd64 libgdbm6 amd64 1.19-2 [64.9 kB]
# Get:3 http://deb.debian.org/debian bullseye/main amd64 libgdbm-compat4 amd64 1.19-2 [44.7 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 libperl5.32 amd64 5.32.1-4+deb11u2 [4106 kB]
# Get:5 http://deb.debian.org/debian bullseye/main amd64 perl amd64 5.32.1-4+deb11u2 [293 kB]
# Get:6 http://deb.debian.org/debian bullseye/main amd64 bzip2 amd64 1.0.8-4 [49.3 kB]
# Get:7 http://deb.debian.org/debian-security bullseye-security/main amd64 openssl amd64 1.1.1n-0+deb11u5 [854 kB]
# Get:8 http://deb.debian.org/debian bullseye/main amd64 ca-certificates all 20210119 [158 kB]
# Get:9 http://deb.debian.org/debian bullseye/main amd64 xz-utils amd64 5.2.5-2.1~deb11u1 [220 kB]
# Get:10 http://deb.debian.org/debian bullseye/main amd64 binutils-common amd64 2.35.2-2 [2220 kB]
# Get:11 http://deb.debian.org/debian bullseye/main amd64 libbinutils amd64 2.35.2-2 [570 kB]
# Get:12 http://deb.debian.org/debian bullseye/main amd64 libctf-nobfd0 amd64 2.35.2-2 [110 kB]
# Get:13 http://deb.debian.org/debian bullseye/main amd64 libctf0 amd64 2.35.2-2 [53.2 kB]
# Get:14 http://deb.debian.org/debian bullseye/main amd64 binutils-x86-64-linux-gnu amd64 2.35.2-2 [1809 kB]
# Get:15 http://deb.debian.org/debian bullseye/main amd64 binutils amd64 2.35.2-2 [61.2 kB]
# Get:16 http://deb.debian.org/debian bullseye/main amd64 libc-dev-bin amd64 2.31-13+deb11u6 [276 kB]
# Get:17 http://deb.debian.org/debian-security bullseye-security/main amd64 linux-libc-dev amd64 5.10.179-1 [1618 kB]
# Get:18 http://deb.debian.org/debian bullseye/main amd64 libcrypt-dev amd64 1:4.4.18-4 [104 kB]
# Get:19 http://deb.debian.org/debian bullseye/main amd64 libtirpc-dev amd64 1.3.1-1+deb11u1 [191 kB]
# Get:20 http://deb.debian.org/debian bullseye/main amd64 libnsl-dev amd64 1.3.0-2 [66.4 kB]
# Get:21 http://deb.debian.org/debian bullseye/main amd64 libc6-dev amd64 2.31-13+deb11u6 [2360 kB]
# Get:22 http://deb.debian.org/debian bullseye/main amd64 libisl23 amd64 0.23-1 [676 kB]
# Get:23 http://deb.debian.org/debian bullseye/main amd64 libmpfr6 amd64 4.1.0-3 [2012 kB]
# Get:24 http://deb.debian.org/debian bullseye/main amd64 libmpc3 amd64 1.2.0-1 [45.0 kB]
# Get:25 http://deb.debian.org/debian bullseye/main amd64 cpp-10 amd64 10.2.1-6 [8528 kB]
# Get:26 http://deb.debian.org/debian bullseye/main amd64 cpp amd64 4:10.2.1-1 [19.7 kB]
# Get:27 http://deb.debian.org/debian bullseye/main amd64 libcc1-0 amd64 10.2.1-6 [47.0 kB]
# Get:28 http://deb.debian.org/debian bullseye/main amd64 libgomp1 amd64 10.2.1-6 [99.9 kB]
# Get:29 http://deb.debian.org/debian bullseye/main amd64 libitm1 amd64 10.2.1-6 [25.8 kB]
# Get:30 http://deb.debian.org/debian bullseye/main amd64 libatomic1 amd64 10.2.1-6 [9008 B]
# Get:31 http://deb.debian.org/debian bullseye/main amd64 libasan6 amd64 10.2.1-6 [2065 kB]
# Get:32 http://deb.debian.org/debian bullseye/main amd64 liblsan0 amd64 10.2.1-6 [828 kB]
# Get:33 http://deb.debian.org/debian bullseye/main amd64 libtsan0 amd64 10.2.1-6 [2000 kB]
# Get:34 http://deb.debian.org/debian bullseye/main amd64 libubsan1 amd64 10.2.1-6 [777 kB]
# Get:35 http://deb.debian.org/debian bullseye/main amd64 libquadmath0 amd64 10.2.1-6 [145 kB]
# Get:36 http://deb.debian.org/debian bullseye/main amd64 libgcc-10-dev amd64 10.2.1-6 [2328 kB]
# Get:37 http://deb.debian.org/debian bullseye/main amd64 gcc-10 amd64 10.2.1-6 [17.0 MB]
# Get:38 http://deb.debian.org/debian bullseye/main amd64 gcc amd64 4:10.2.1-1 [5192 B]
# Get:39 http://deb.debian.org/debian bullseye/main amd64 libstdc++-10-dev amd64 10.2.1-6 [1741 kB]
# Get:40 http://deb.debian.org/debian bullseye/main amd64 g++-10 amd64 10.2.1-6 [9380 kB]
# Get:41 http://deb.debian.org/debian bullseye/main amd64 g++ amd64 4:10.2.1-1 [1644 B]
# Get:42 http://deb.debian.org/debian bullseye/main amd64 make amd64 4.3-4.1 [396 kB]
# Get:43 http://deb.debian.org/debian bullseye/main amd64 libdpkg-perl all 1.20.12 [1551 kB]
# Get:44 http://deb.debian.org/debian bullseye/main amd64 patch amd64 2.7.6-7 [128 kB]
# Get:45 http://deb.debian.org/debian bullseye/main amd64 dpkg-dev all 1.20.12 [2312 kB]
# Get:46 http://deb.debian.org/debian bullseye/main amd64 build-essential amd64 12.9 [7704 B]
# Get:47 http://deb.debian.org/debian bullseye/main amd64 libbrotli1 amd64 1.0.9-2+b2 [279 kB]
# Get:48 http://deb.debian.org/debian bullseye/main amd64 libsasl2-modules-db amd64 2.1.27+dfsg-2.1+deb11u1 [69.1 kB]
# Get:49 http://deb.debian.org/debian bullseye/main amd64 libsasl2-2 amd64 2.1.27+dfsg-2.1+deb11u1 [106 kB]
# Get:50 http://deb.debian.org/debian bullseye/main amd64 libldap-2.4-2 amd64 2.4.57+dfsg-3+deb11u1 [232 kB]
# Get:51 http://deb.debian.org/debian bullseye/main amd64 libnghttp2-14 amd64 1.43.0-1 [77.1 kB]
# Get:52 http://deb.debian.org/debian bullseye/main amd64 libpsl5 amd64 0.21.0-1.2 [57.3 kB]
# Get:53 http://deb.debian.org/debian bullseye/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-2+b2 [60.8 kB]
# Get:54 http://deb.debian.org/debian bullseye/main amd64 libssh2-1 amd64 1.9.0-2 [156 kB]
# Get:55 http://deb.debian.org/debian bullseye/main amd64 libcurl4 amd64 7.74.0-1.3+deb11u7 [346 kB]
# Get:56 http://deb.debian.org/debian bullseye/main amd64 curl amd64 7.74.0-1.3+deb11u7 [270 kB]
# Get:57 http://deb.debian.org/debian bullseye/main amd64 libcurl3-gnutls amd64 7.74.0-1.3+deb11u7 [343 kB]
# Get:58 http://deb.debian.org/debian bullseye/main amd64 libexpat1 amd64 2.2.10-2+deb11u5 [98.2 kB]
# Get:59 http://deb.debian.org/debian bullseye/main amd64 liberror-perl all 0.17029-1 [31.0 kB]
# Get:60 http://deb.debian.org/debian bullseye/main amd64 git-man all 1:2.30.2-1+deb11u2 [1828 kB]
# Get:61 http://deb.debian.org/debian bullseye/main amd64 git amd64 1:2.30.2-1+deb11u2 [5518 kB]
# Get:62 http://deb.debian.org/debian bullseye/main amd64 sudo amd64 1.9.5p2-3+deb11u1 [1061 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 80.7 MB in 1s (66.6 MB/s)
# Selecting previously unselected package perl-modules-5.32.
# (Reading database ... 6664 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.32_5.32.1-4+deb11u2_all.deb ...
# Unpacking perl-modules-5.32 (5.32.1-4+deb11u2) ...
# Selecting previously unselected package libgdbm6:amd64.
# Preparing to unpack .../01-libgdbm6_1.19-2_amd64.deb ...
# Unpacking libgdbm6:amd64 (1.19-2) ...
# Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.19-2_amd64.deb ...
# Unpacking libgdbm-compat4:amd64 (1.19-2) ...
# Selecting previously unselected package libperl5.32:amd64.
# Preparing to unpack .../03-libperl5.32_5.32.1-4+deb11u2_amd64.deb ...
# Unpacking libperl5.32:amd64 (5.32.1-4+deb11u2) ...
# Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.32.1-4+deb11u2_amd64.deb ...
# Unpacking perl (5.32.1-4+deb11u2) ...
# Selecting previously unselected package bzip2.
# Preparing to unpack .../05-bzip2_1.0.8-4_amd64.deb ...
# Unpacking bzip2 (1.0.8-4) ...
# Selecting previously unselected package openssl.
# Preparing to unpack .../06-openssl_1.1.1n-0+deb11u5_amd64.deb ...
# Unpacking openssl (1.1.1n-0+deb11u5) ...
# Selecting previously unselected package ca-certificates.
# Preparing to unpack .../07-ca-certificates_20210119_all.deb ...
# Unpacking ca-certificates (20210119) ...
# Selecting previously unselected package xz-utils.
# Preparing to unpack .../08-xz-utils_5.2.5-2.1~deb11u1_amd64.deb ...
# Unpacking xz-utils (5.2.5-2.1~deb11u1) ...
# Selecting previously unselected package binutils-common:amd64.
# Preparing to unpack .../09-binutils-common_2.35.2-2_amd64.deb ...
# Unpacking binutils-common:amd64 (2.35.2-2) ...
# Selecting previously unselected package libbinutils:amd64.
# Preparing to unpack .../10-libbinutils_2.35.2-2_amd64.deb ...
# Unpacking libbinutils:amd64 (2.35.2-2) ...
# Selecting previously unselected package libctf-nobfd0:amd64.
# Preparing to unpack .../11-libctf-nobfd0_2.35.2-2_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.35.2-2) ...
# Selecting previously unselected package libctf0:amd64.
# Preparing to unpack .../12-libctf0_2.35.2-2_amd64.deb ...
# Unpacking libctf0:amd64 (2.35.2-2) ...
# Selecting previously unselected package binutils-x86-64-linux-gnu.
# Preparing to unpack .../13-binutils-x86-64-linux-gnu_2.35.2-2_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.35.2-2) ...
# Selecting previously unselected package binutils.
# Preparing to unpack .../14-binutils_2.35.2-2_amd64.deb ...
# Unpacking binutils (2.35.2-2) ...
# Selecting previously unselected package libc-dev-bin.
# Preparing to unpack .../15-libc-dev-bin_2.31-13+deb11u6_amd64.deb ...
# Unpacking libc-dev-bin (2.31-13+deb11u6) ...
# Selecting previously unselected package linux-libc-dev:amd64.
# Preparing to unpack .../16-linux-libc-dev_5.10.179-1_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (5.10.179-1) ...
# Selecting previously unselected package libcrypt-dev:amd64.
# Preparing to unpack .../17-libcrypt-dev_1%3a4.4.18-4_amd64.deb ...
# Unpacking libcrypt-dev:amd64 (1:4.4.18-4) ...
# Selecting previously unselected package libtirpc-dev:amd64.
# Preparing to unpack .../18-libtirpc-dev_1.3.1-1+deb11u1_amd64.deb ...
# Unpacking libtirpc-dev:amd64 (1.3.1-1+deb11u1) ...
# Selecting previously unselected package libnsl-dev:amd64.
# Preparing to unpack .../19-libnsl-dev_1.3.0-2_amd64.deb ...
# Unpacking libnsl-dev:amd64 (1.3.0-2) ...
# Selecting previously unselected package libc6-dev:amd64.
# Preparing to unpack .../20-libc6-dev_2.31-13+deb11u6_amd64.deb ...
# Unpacking libc6-dev:amd64 (2.31-13+deb11u6) ...
# Selecting previously unselected package libisl23:amd64.
# Preparing to unpack .../21-libisl23_0.23-1_amd64.deb ...
# Unpacking libisl23:amd64 (0.23-1) ...
# Selecting previously unselected package libmpfr6:amd64.
# Preparing to unpack .../22-libmpfr6_4.1.0-3_amd64.deb ...
# Unpacking libmpfr6:amd64 (4.1.0-3) ...
# Selecting previously unselected package libmpc3:amd64.
# Preparing to unpack .../23-libmpc3_1.2.0-1_amd64.deb ...
# Unpacking libmpc3:amd64 (1.2.0-1) ...
# Selecting previously unselected package cpp-10.
# Preparing to unpack .../24-cpp-10_10.2.1-6_amd64.deb ...
# Unpacking cpp-10 (10.2.1-6) ...
# Selecting previously unselected package cpp.
# Preparing to unpack .../25-cpp_4%3a10.2.1-1_amd64.deb ...
# Unpacking cpp (4:10.2.1-1) ...
# Selecting previously unselected package libcc1-0:amd64.
# Preparing to unpack .../26-libcc1-0_10.2.1-6_amd64.deb ...
# Unpacking libcc1-0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../27-libgomp1_10.2.1-6_amd64.deb ...
# Unpacking libgomp1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libitm1:amd64.
# Preparing to unpack .../28-libitm1_10.2.1-6_amd64.deb ...
# Unpacking libitm1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../29-libatomic1_10.2.1-6_amd64.deb ...
# Unpacking libatomic1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libasan6:amd64.
# Preparing to unpack .../30-libasan6_10.2.1-6_amd64.deb ...
# Unpacking libasan6:amd64 (10.2.1-6) ...
# Selecting previously unselected package liblsan0:amd64.
# Preparing to unpack .../31-liblsan0_10.2.1-6_amd64.deb ...
# Unpacking liblsan0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libtsan0:amd64.
# Preparing to unpack .../32-libtsan0_10.2.1-6_amd64.deb ...
# Unpacking libtsan0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libubsan1:amd64.
# Preparing to unpack .../33-libubsan1_10.2.1-6_amd64.deb ...
# Unpacking libubsan1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libquadmath0:amd64.
# Preparing to unpack .../34-libquadmath0_10.2.1-6_amd64.deb ...
# Unpacking libquadmath0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libgcc-10-dev:amd64.
# Preparing to unpack .../35-libgcc-10-dev_10.2.1-6_amd64.deb ...
# Unpacking libgcc-10-dev:amd64 (10.2.1-6) ...
# Selecting previously unselected package gcc-10.
# Preparing to unpack .../36-gcc-10_10.2.1-6_amd64.deb ...
# Unpacking gcc-10 (10.2.1-6) ...
# Selecting previously unselected package gcc.
# Preparing to unpack .../37-gcc_4%3a10.2.1-1_amd64.deb ...
# Unpacking gcc (4:10.2.1-1) ...
# Selecting previously unselected package libstdc++-10-dev:amd64.
# Preparing to unpack .../38-libstdc++-10-dev_10.2.1-6_amd64.deb ...
# Unpacking libstdc++-10-dev:amd64 (10.2.1-6) ...
# Selecting previously unselected package g++-10.
# Preparing to unpack .../39-g++-10_10.2.1-6_amd64.deb ...
# Unpacking g++-10 (10.2.1-6) ...
# Selecting previously unselected package g++.
# Preparing to unpack .../40-g++_4%3a10.2.1-1_amd64.deb ...
# Unpacking g++ (4:10.2.1-1) ...
# Selecting previously unselected package make.
# Preparing to unpack .../41-make_4.3-4.1_amd64.deb ...
# Unpacking make (4.3-4.1) ...
# Selecting previously unselected package libdpkg-perl.
# Preparing to unpack .../42-libdpkg-perl_1.20.12_all.deb ...
# Unpacking libdpkg-perl (1.20.12) ...
# Selecting previously unselected package patch.
# Preparing to unpack .../43-patch_2.7.6-7_amd64.deb ...
# Unpacking patch (2.7.6-7) ...
# Selecting previously unselected package dpkg-dev.
# Preparing to unpack .../44-dpkg-dev_1.20.12_all.deb ...
# Unpacking dpkg-dev (1.20.12) ...
# Selecting previously unselected package build-essential.
# Preparing to unpack .../45-build-essential_12.9_amd64.deb ...
# Unpacking build-essential (12.9) ...
# Selecting previously unselected package libbrotli1:amd64.
# Preparing to unpack .../46-libbrotli1_1.0.9-2+b2_amd64.deb ...
# Unpacking libbrotli1:amd64 (1.0.9-2+b2) ...
# Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../47-libsasl2-modules-db_2.1.27+dfsg-2.1+deb11u1_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../48-libsasl2-2_2.1.27+dfsg-2.1+deb11u1_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../49-libldap-2.4-2_2.4.57+dfsg-3+deb11u1_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
# Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../50-libnghttp2-14_1.43.0-1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.43.0-1) ...
# Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../51-libpsl5_0.21.0-1.2_amd64.deb ...
# Unpacking libpsl5:amd64 (0.21.0-1.2) ...
# Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../52-librtmp1_2.4+20151223.gitfa8646d.1-2+b2_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
# Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../53-libssh2-1_1.9.0-2_amd64.deb ...
# Unpacking libssh2-1:amd64 (1.9.0-2) ...
# Selecting previously unselected package libcurl4:amd64.
# Preparing to unpack .../54-libcurl4_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking libcurl4:amd64 (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package curl.
# Preparing to unpack .../55-curl_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking curl (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../56-libcurl3-gnutls_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../57-libexpat1_2.2.10-2+deb11u5_amd64.deb ...
# Unpacking libexpat1:amd64 (2.2.10-2+deb11u5) ...
# Selecting previously unselected package liberror-perl.
# Preparing to unpack .../58-liberror-perl_0.17029-1_all.deb ...
# Unpacking liberror-perl (0.17029-1) ...
# Selecting previously unselected package git-man.
# Preparing to unpack .../59-git-man_1%3a2.30.2-1+deb11u2_all.deb ...
# Unpacking git-man (1:2.30.2-1+deb11u2) ...
# Selecting previously unselected package git.
# Preparing to unpack .../60-git_1%3a2.30.2-1+deb11u2_amd64.deb ...
# Unpacking git (1:2.30.2-1+deb11u2) ...
# Selecting previously unselected package sudo.
# Preparing to unpack .../61-sudo_1.9.5p2-3+deb11u1_amd64.deb ...
# Unpacking sudo (1.9.5p2-3+deb11u1) ...
# Setting up libexpat1:amd64 (2.2.10-2+deb11u5) ...
# Setting up libpsl5:amd64 (0.21.0-1.2) ...
# Setting up perl-modules-5.32 (5.32.1-4+deb11u2) ...
# Setting up libbrotli1:amd64 (1.0.9-2+b2) ...
# Setting up binutils-common:amd64 (2.35.2-2) ...
# Setting up libnghttp2-14:amd64 (1.43.0-1) ...
# Setting up linux-libc-dev:amd64 (5.10.179-1) ...
# Setting up libctf-nobfd0:amd64 (2.35.2-2) ...
# Setting up libgomp1:amd64 (10.2.1-6) ...
# Setting up bzip2 (1.0.8-4) ...
# Setting up libasan6:amd64 (10.2.1-6) ...
# Setting up libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Setting up libtirpc-dev:amd64 (1.3.1-1+deb11u1) ...
# Setting up make (4.3-4.1) ...
# Setting up libmpfr6:amd64 (4.1.0-3) ...
# Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
# Setting up xz-utils (5.2.5-2.1~deb11u1) ...
# update-alternatives: using /usr/bin/xz to provide /usr/bin/lzma (lzma) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzma.1.gz because associated file /usr/share/man/man1/xz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/unlzma.1.gz because associated file /usr/share/man/man1/unxz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcat.1.gz because associated file /usr/share/man/man1/xzcat.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzmore.1.gz because associated file /usr/share/man/man1/xzmore.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzless.1.gz because associated file /usr/share/man/man1/xzless.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzdiff.1.gz because associated file /usr/share/man/man1/xzdiff.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcmp.1.gz because associated file /usr/share/man/man1/xzcmp.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzgrep.1.gz because associated file /usr/share/man/man1/xzgrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzegrep.1.gz because associated file /usr/share/man/man1/xzegrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzfgrep.1.gz because associated file /usr/share/man/man1/xzfgrep.1.gz (of link group lzma) doesn't exist
# Setting up libquadmath0:amd64 (10.2.1-6) ...
# Setting up libmpc3:amd64 (1.2.0-1) ...
# Setting up libatomic1:amd64 (10.2.1-6) ...
# Setting up patch (2.7.6-7) ...
# Setting up sudo (1.9.5p2-3+deb11u1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Setting up libubsan1:amd64 (10.2.1-6) ...
# Setting up libnsl-dev:amd64 (1.3.0-2) ...
# Setting up libcrypt-dev:amd64 (1:4.4.18-4) ...
# Setting up git-man (1:2.30.2-1+deb11u2) ...
# Setting up libssh2-1:amd64 (1.9.0-2) ...
# Setting up libbinutils:amd64 (2.35.2-2) ...
# Setting up libisl23:amd64 (0.23-1) ...
# Setting up libc-dev-bin (2.31-13+deb11u6) ...
# Setting up openssl (1.1.1n-0+deb11u5) ...
# Setting up libcc1-0:amd64 (10.2.1-6) ...
# Setting up liblsan0:amd64 (10.2.1-6) ...
# Setting up cpp-10 (10.2.1-6) ...
# Setting up libitm1:amd64 (10.2.1-6) ...
# Setting up libgdbm6:amd64 (1.19-2) ...
# Setting up libtsan0:amd64 (10.2.1-6) ...
# Setting up libctf0:amd64 (2.35.2-2) ...
# Setting up libgcc-10-dev:amd64 (10.2.1-6) ...
# Setting up libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
# Setting up libcurl3-gnutls:amd64 (7.74.0-1.3+deb11u7) ...
# Setting up ca-certificates (20210119) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# Updating certificates in /etc/ssl/certs...
# 129 added, 0 removed; done.
# Setting up libgdbm-compat4:amd64 (1.19-2) ...
# Setting up libperl5.32:amd64 (5.32.1-4+deb11u2) ...
# Setting up cpp (4:10.2.1-1) ...
# Setting up libcurl4:amd64 (7.74.0-1.3+deb11u7) ...
# Setting up libc6-dev:amd64 (2.31-13+deb11u6) ...
# Setting up curl (7.74.0-1.3+deb11u7) ...
# Setting up binutils-x86-64-linux-gnu (2.35.2-2) ...
# Setting up libstdc++-10-dev:amd64 (10.2.1-6) ...
# Setting up binutils (2.35.2-2) ...
# Setting up perl (5.32.1-4+deb11u2) ...
# Setting up gcc-10 (10.2.1-6) ...
# Setting up libdpkg-perl (1.20.12) ...
# Setting up g++-10 (10.2.1-6) ...
# Setting up gcc (4:10.2.1-1) ...
# Setting up dpkg-dev (1.20.12) ...
# Setting up liberror-perl (0.17029-1) ...
# Setting up git (1:2.30.2-1+deb11u2) ...
# Setting up g++ (4:10.2.1-1) ...
# update-alternatives: using /usr/bin/g++ to provide /usr/bin/c++ (c++) in auto mode
# Setting up build-essential (12.9) ...
# Processing triggers for libc-bin (2.31-13+deb11u6) ...
# Processing triggers for ca-certificates (20210119) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
# done.
# WARN[0029] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 8d55846ad50
# STEP 6/13: RUN echo $USERNAME ALL=\(root\) NOPASSWD:ALL > /etc/sudoers.d/$USERNAME     && chmod 0440 /etc/sudoers.d/$USERNAME
# WARN[0041] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 0fc7521fc8c
# STEP 7/13: RUN mkdir -p /srv/conda && chown -R mambauser:1000 /srv/conda/
# WARN[0045] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> a36078bb4b6
# STEP 8/13: RUN mkdir -p /workspaces/command-line-tools/norm_diff
# WARN[0049] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> dd6360237ed
# STEP 9/13: RUN chown -R 1000:1000 /workspaces/command-line-tools/norm_diff
# WARN[0054] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 6d238779db5
# STEP 10/13: USER mambauser
# WARN[0058] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> b3535a0faea
# STEP 11/13: RUN micromamba create -r /srv/conda -n env_norm_diff -c conda-forge gdal click
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
#
# Transaction
#
#   Prefix: /srv/conda/envs/env_norm_diff
#
#   Updating specs:
#
#    - gdal
#    - click
#
#
#   Package                           Version  Build                Channel          Size
# ─────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                       0.1  conda_forge          conda-forge       3kB
#   + _openmp_mutex                       4.5  2_gnu                conda-forge      24kB
#   + blosc                            1.21.4  h0f2a231_0           conda-forge      49kB
#   + boost-cpp                        1.78.0  h6582d0a_3           conda-forge      16MB
#   + bzip2                             1.0.8  h7f98852_4           conda-forge     496kB
#   + c-ares                           1.19.1  hd590300_0           conda-forge     113kB
#   + ca-certificates                2023.5.7  hbcca054_0           conda-forge     148kB
#   + cairo                            1.16.0  hbbf8b49_1016        conda-forge       1MB
#   + cfitsio                           4.2.0  hd9d235c_0           conda-forge     848kB
#   + click                             8.1.3  unix_pyhd8ed1ab_2    conda-forge      76kB
#   + curl                              8.1.2  h409715c_0           conda-forge      91kB
#   + expat                             2.5.0  hcb278e6_1           conda-forge     137kB
#   + font-ttf-dejavu-sans-mono          2.37  hab24e00_0           conda-forge     397kB
#   + font-ttf-inconsolata              3.000  h77eed37_0           conda-forge      97kB
#   + font-ttf-source-code-pro          2.038  h77eed37_0           conda-forge     701kB
#   + font-ttf-ubuntu                    0.83  hab24e00_0           conda-forge       2MB
#   + fontconfig                       2.14.2  h14ed4e7_0           conda-forge     272kB
#   + fonts-conda-ecosystem                 1  0                    conda-forge       4kB
#   + fonts-conda-forge                     1  0                    conda-forge       4kB
#   + freetype                         2.12.1  hca18f0e_1           conda-forge     626kB
#   + freexl                            1.0.6  h166bdaf_1           conda-forge      50kB
#   + gdal                              3.7.0  py311h281082f_2      conda-forge       2MB
#   + geos                             3.11.2  hcb278e6_0           conda-forge       2MB
#   + geotiff                           1.7.1  h22adcc9_9           conda-forge     257kB
#   + gettext                          0.21.1  h27087fc_0           conda-forge       4MB
#   + giflib                            5.2.1  h0b41bf4_3           conda-forge      77kB
#   + hdf4                             4.2.15  h501b40f_6           conda-forge     758kB
#   + hdf5                             1.14.0  nompi_hb72d44e_103   conda-forge       4MB
#   + icu                                72.1  hcb278e6_0           conda-forge      12MB
#   + json-c                             0.16  hc379101_0           conda-forge     281kB
#   + kealib                            1.5.1  h3845be2_3           conda-forge     173kB
#   + keyutils                          1.6.1  h166bdaf_0           conda-forge     118kB
#   + krb5                             1.20.1  h81ceb04_0           conda-forge       1MB
#   + lcms2                              2.15  haa2dc70_1           conda-forge     242kB
#   + ld_impl_linux-64                   2.40  h41732ed_0           conda-forge     705kB
#   + lerc                              4.0.0  h27087fc_0           conda-forge     282kB
#   + libaec                            1.0.6  hcb278e6_1           conda-forge      34kB
#   + libarchive                        3.6.2  h039dbb9_1           conda-forge     844kB
#   + libblas                           3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libcblas                          3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libcurl                           8.1.2  h409715c_0           conda-forge     373kB
#   + libdeflate                         1.18  h0b41bf4_0           conda-forge      65kB
#   + libedit                    3.1.20191231  he28a2e2_2           conda-forge     124kB
#   + libev                              4.33  h516909a_1           conda-forge     106kB
#   + libexpat                          2.5.0  hcb278e6_1           conda-forge      78kB
#   + libffi                            3.4.2  h7f98852_5           conda-forge      58kB
#   + libgcc-ng                        13.1.0  he5830b7_0           conda-forge     776kB
#   + libgdal                           3.7.0  h5418a03_2           conda-forge      11MB
#   + libgfortran-ng                   13.1.0  h69a702a_0           conda-forge      23kB
#   + libgfortran5                     13.1.0  h15d22d2_0           conda-forge       1MB
#   + libglib                          2.76.3  hebfc3b9_0           conda-forge       3MB
#   + libgomp                          13.1.0  he5830b7_0           conda-forge     419kB
#   + libiconv                           1.17  h166bdaf_0           conda-forge       1MB
#   + libjpeg-turbo                   2.1.5.1  h0b41bf4_0           conda-forge     491kB
#   + libkml                            1.3.0  h37653c0_1015        conda-forge     625kB
#   + liblapack                         3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libnetcdf                         4.9.2  nompi_h0f3d0bb_105   conda-forge     841kB
#   + libnghttp2                       1.52.0  h61bc06f_0           conda-forge     622kB
#   + libnsl                            2.0.0  h7f98852_0           conda-forge      31kB
#   + libopenblas                      0.3.23  pthreads_h80387f5_0  conda-forge       5MB
#   + libpng                           1.6.39  h753d276_0           conda-forge     283kB
#   + libpq                              15.3  hbcd7760_1           conda-forge       3MB
#   + librttopo                         1.1.0  h0d5128d_13          conda-forge     234kB
#   + libspatialite                     5.0.1  hca56755_27          conda-forge       3MB
#   + libsqlite                        3.42.0  h2797004_0           conda-forge     829kB
#   + libssh2                          1.11.0  h0841786_0           conda-forge     271kB
#   + libstdcxx-ng                     13.1.0  hfd8a6a1_0           conda-forge       4MB
#   + libtiff                           4.5.0  ha587672_6           conda-forge     407kB
#   + libuuid                          2.38.1  h0b41bf4_0           conda-forge      34kB
#   + libwebp-base                      1.3.0  h0b41bf4_0           conda-forge     357kB
#   + libxcb                             1.15  h0b41bf4_0           conda-forge     384kB
#   + libxml2                          2.11.4  h0d562d8_0           conda-forge     704kB
#   + libzip                            1.9.2  hc929e4a_1           conda-forge      99kB
#   + libzlib                          1.2.13  h166bdaf_4           conda-forge      66kB
#   + lz4-c                             1.9.4  hcb278e6_0           conda-forge     143kB
#   + lzo                                2.10  h516909a_1000        conda-forge     321kB
#   + ncurses                             6.3  h27087fc_1           conda-forge       1MB
#   + nspr                               4.35  h27087fc_0           conda-forge     227kB
#   + nss                                3.89  he45b914_0           conda-forge       2MB
#   + numpy                            1.24.3  py311h64a7726_0      conda-forge       8MB
#   + openjpeg                          2.5.0  hfec8fc6_2           conda-forge     352kB
#   + openssl                           3.1.1  hd590300_1           conda-forge       3MB
#   + pcre2                             10.40  hc3806b6_0           conda-forge       2MB
#   + pip                              23.1.2  pyhd8ed1ab_0         conda-forge       1MB
#   + pixman                           0.40.0  h36c2ea0_0           conda-forge     643kB
#   + poppler                         23.05.0  hd18248d_1           conda-forge      15MB
#   + poppler-data                     0.4.12  hd8ed1ab_0           conda-forge       2MB
#   + postgresql                         15.3  hd458b1d_1           conda-forge       5MB
#   + proj                              9.2.1  ha643af7_0           conda-forge       3MB
#   + pthread-stubs                       0.4  h36c2ea0_1001        conda-forge       6kB
#   + python                           3.11.3  h2755cc3_0_cpython   conda-forge      31MB
#   + python_abi                         3.11  3_cp311              conda-forge       6kB
#   + readline                            8.2  h8228510_1           conda-forge     281kB
#   + setuptools                       67.7.2  pyhd8ed1ab_0         conda-forge     583kB
#   + snappy                           1.1.10  h9fff704_0           conda-forge      39kB
#   + sqlite                           3.42.0  h2c6b66d_0           conda-forge     818kB
#   + tiledb                           2.13.2  hd532e3d_0           conda-forge       5MB
#   + tk                               8.6.12  h27826a3_0           conda-forge       3MB
#   + tzcode                            2023c  h0b41bf4_0           conda-forge      69kB
#   + tzdata                            2023c  h71feb2d_0           conda-forge     118kB
#   + wheel                            0.40.0  pyhd8ed1ab_0         conda-forge      56kB
#   + xerces-c                          3.2.4  h8d71039_2           conda-forge       2MB
#   + xorg-kbproto                      1.0.7  h7f98852_1002        conda-forge      27kB
#   + xorg-libice                       1.1.1  hd590300_0           conda-forge      58kB
#   + xorg-libsm                        1.2.4  h7391055_0           conda-forge      27kB
#   + xorg-libx11                       1.8.4  h8ee46fc_1           conda-forge     833kB
#   + xorg-libxau                      1.0.11  hd590300_0           conda-forge      14kB
#   + xorg-libxdmcp                     1.1.3  h7f98852_0           conda-forge      19kB
#   + xorg-libxext                      1.3.4  h0b41bf4_2           conda-forge      50kB
#   + xorg-libxrender                  0.9.10  h7f98852_1003        conda-forge      33kB
#   + xorg-renderproto                 0.11.1  h7f98852_1002        conda-forge      10kB
#   + xorg-xextproto                    7.3.0  h0b41bf4_1003        conda-forge      30kB
#   + xorg-xproto                      7.0.31  h7f98852_1007        conda-forge      75kB
#   + xz                                5.2.6  h166bdaf_0           conda-forge     418kB
#   + zlib                             1.2.13  h166bdaf_4           conda-forge      94kB
#   + zstd                              1.5.2  h3eb15da_6           conda-forge     420kB
#
#   Summary:
#
#   Install: 116 packages
#
#   Total download: 181MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#
# Confirm changes: [Y/n]
# Transaction starting
# Linking font-ttf-dejavu-sans-mono-2.37-hab24e00_0
# Linking font-ttf-ubuntu-0.83-hab24e00_0
# Linking font-ttf-inconsolata-3.000-h77eed37_0
# Linking font-ttf-source-code-pro-2.038-h77eed37_0
# Linking tzdata-2023c-h71feb2d_0
# Linking poppler-data-0.4.12-hd8ed1ab_0
# Linking fonts-conda-forge-1-0
# Linking fonts-conda-ecosystem-1-0
# Linking _libgcc_mutex-0.1-conda_forge
# Linking libstdcxx-ng-13.1.0-hfd8a6a1_0
# Linking ld_impl_linux-64-2.40-h41732ed_0
# Linking ca-certificates-2023.5.7-hbcca054_0
# Linking libgfortran5-13.1.0-h15d22d2_0
# Linking python_abi-3.11-3_cp311
# Linking libgomp-13.1.0-he5830b7_0
# Linking libgfortran-ng-13.1.0-h69a702a_0
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-ng-13.1.0-he5830b7_0
# Linking xorg-xproto-7.0.31-h7f98852_1007
# Linking xorg-kbproto-1.0.7-h7f98852_1002
# Linking xorg-renderproto-0.11.1-h7f98852_1002
# Linking lzo-2.10-h516909a_1000
# Linking xorg-libxdmcp-1.1.3-h7f98852_0
# Linking pthread-stubs-0.4-h36c2ea0_1001
# Linking libopenblas-0.3.23-pthreads_h80387f5_0
# Linking tzcode-2023c-h0b41bf4_0
# Linking xorg-xextproto-7.3.0-h0b41bf4_1003
# Linking xorg-libice-1.1.1-hd590300_0
# Linking libaec-1.0.6-hcb278e6_1
# Linking lz4-c-1.9.4-hcb278e6_0
# Linking giflib-5.2.1-h0b41bf4_3
# Linking libev-4.33-h516909a_1
# Linking c-ares-1.19.1-hd590300_0
# Linking freexl-1.0.6-h166bdaf_1
# Linking xorg-libxau-1.0.11-hd590300_0
# Linking pixman-0.40.0-h36c2ea0_0
# Linking keyutils-1.6.1-h166bdaf_0
# Linking openssl-3.1.1-hd590300_1
# Linking libffi-3.4.2-h7f98852_5
# Linking bzip2-1.0.8-h7f98852_4
# Linking ncurses-6.3-h27087fc_1
# Linking libnsl-2.0.0-h7f98852_0
# Linking nspr-4.35-h27087fc_0
# Linking gettext-0.21.1-h27087fc_0
# Linking snappy-1.1.10-h9fff704_0
# Linking libwebp-base-1.3.0-h0b41bf4_0
# Linking libuuid-2.38.1-h0b41bf4_0
# Linking libjpeg-turbo-2.1.5.1-h0b41bf4_0
# Linking libexpat-2.5.0-hcb278e6_1
# Linking libdeflate-1.18-h0b41bf4_0
# Linking icu-72.1-hcb278e6_0
# Linking geos-3.11.2-hcb278e6_0
# Linking xz-5.2.6-h166bdaf_0
# Linking libzlib-1.2.13-h166bdaf_4
# Linking libiconv-1.17-h166bdaf_0
# Linking lerc-4.0.0-h27087fc_0
# Linking json-c-0.16-hc379101_0
# Linking libblas-3.9.0-17_linux64_openblas
# Linking libxcb-1.15-h0b41bf4_0
# Linking libedit-3.1.20191231-he28a2e2_2
# Linking readline-8.2-h8228510_1
# Linking xorg-libsm-1.2.4-h7391055_0
# Linking expat-2.5.0-hcb278e6_1
# Linking librttopo-1.1.0-h0d5128d_13
# Linking libzip-1.9.2-hc929e4a_1
# Linking libssh2-1.11.0-h0841786_0
# Linking zstd-1.5.2-h3eb15da_6
# Linking tk-8.6.12-h27826a3_0
# Linking zlib-1.2.13-h166bdaf_4
# Linking hdf4-4.2.15-h501b40f_6
# Linking libnghttp2-1.52.0-h61bc06f_0
# Linking libsqlite-3.42.0-h2797004_0
# Linking libpng-1.6.39-h753d276_0
# Linking pcre2-10.40-hc3806b6_0
# Linking libxml2-2.11.4-h0d562d8_0
# Linking libcblas-3.9.0-17_linux64_openblas
# Linking liblapack-3.9.0-17_linux64_openblas
# Linking xorg-libx11-1.8.4-h8ee46fc_1
# Linking krb5-1.20.1-h81ceb04_0
# Linking libtiff-4.5.0-ha587672_6
# Linking boost-cpp-1.78.0-h6582d0a_3
# Linking blosc-1.21.4-h0f2a231_0
# Linking sqlite-3.42.0-h2c6b66d_0
# Linking python-3.11.3-h2755cc3_0_cpython
# Linking nss-3.89-he45b914_0
# Linking freetype-2.12.1-hca18f0e_1
# Linking libglib-2.76.3-hebfc3b9_0
# Linking libarchive-3.6.2-h039dbb9_1
# Linking xorg-libxext-1.3.4-h0b41bf4_2
# Linking xorg-libxrender-0.9.10-h7f98852_1003
# Linking libpq-15.3-hbcd7760_1
# Linking libcurl-8.1.2-h409715c_0
# Linking openjpeg-2.5.0-hfec8fc6_2
# Linking lcms2-2.15-haa2dc70_1
# Linking libkml-1.3.0-h37653c0_1015
# Linking fontconfig-2.14.2-h14ed4e7_0
# Linking postgresql-15.3-hd458b1d_1
# Linking hdf5-1.14.0-nompi_hb72d44e_103
# Linking curl-8.1.2-h409715c_0
# Linking xerces-c-3.2.4-h8d71039_2
# Linking proj-9.2.1-ha643af7_0
# Linking cfitsio-4.2.0-hd9d235c_0
# Linking cairo-1.16.0-hbbf8b49_1016
# Linking kealib-1.5.1-h3845be2_3
# Linking libnetcdf-4.9.2-nompi_h0f3d0bb_105
# Linking tiledb-2.13.2-hd532e3d_0
# Linking geotiff-1.7.1-h22adcc9_9
# Linking libspatialite-5.0.1-hca56755_27
# Linking poppler-23.05.0-hd18248d_1
# Linking libgdal-3.7.0-h5418a03_2
# Linking wheel-0.40.0-pyhd8ed1ab_0
# Linking setuptools-67.7.2-pyhd8ed1ab_0
# Linking pip-23.1.2-pyhd8ed1ab_0
# Linking click-8.1.3-unix_pyhd8ed1ab_2
# Linking numpy-1.24.3-py311h64a7726_0
# Linking gdal-3.7.0-py311h281082f_2
#
# Transaction finished
#
# To activate this environment, use:
#
#     micromamba activate env_norm_diff
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -n env_norm_diff mycommand
#
# WARN[0109] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> e7965b9134f
# STEP 12/13: ADD water-bodies/command-line-tools/norm_diff/app.py /workspaces/command-line-tools/norm_diff/app.py
# WARN[0184] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> c018120dde9
# STEP 13/13: WORKDIR /home/mambauser
# COMMIT simonevaccari/norm_diff:0.1.0
# WARN[0214] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 3f4f8923266
# Successfully tagged localhost/simonevaccari/norm_diff:0.1.0
# 3f4f8923266ce6868ee60b955f10fe48958df23b79b8d8171c0ab87a44b0ca8a

# %%
# !docker build -t simonevaccari/otsu:0.1.0 --no-cache -f water-bodies/command-line-tools/otsu/Dockerfile .
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# STEP 1/14: FROM docker.io/mambaorg/micromamba:latest
# STEP 2/14: USER root
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 2cbc9b9464a
# STEP 3/14: ENV USERNAME=mambauser
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> e52e4f2a4d5
# STEP 4/14: ENV PATH=/srv/conda/envs/env_otsu/bin:$PATH
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> a440dde9c69
# STEP 5/14: RUN apt-get update -y  && apt-get upgrade -y  && apt-get install -y --no-install-recommends         ca-certificates         curl sudo git gcc build-essential
# Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
# Get:2 http://deb.debian.org/debian-security bullseye-security InRelease [48.4 kB]
# Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183 kB]
# Get:5 http://deb.debian.org/debian-security bullseye-security/main amd64 Packages [245 kB]
# Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Packages [14.8 kB]
# Fetched 8650 kB in 2s (4590 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Calculating upgrade...
# The following packages will be upgraded:
#   libssl1.1
# 1 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Need to get 1559 kB of archives.
# After this operation, 4096 B disk space will be freed.
# Get:1 http://deb.debian.org/debian-security bullseye-security/main amd64 libssl1.1 amd64 1.1.1n-0+deb11u5 [1559 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 1559 kB in 0s (31.2 MB/s)
# (Reading database ... 6664 files and directories currently installed.)
# Preparing to unpack .../libssl1.1_1.1.1n-0+deb11u5_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1n-0+deb11u5) over (1.1.1n-0+deb11u4) ...
# Setting up libssl1.1:amd64 (1.1.1n-0+deb11u5) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.32.1 /usr/local/share/perl/5.32.1 /usr/lib/x86_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
# Processing triggers for libc-bin (2.31-13+deb11u6) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu bzip2 cpp cpp-10 dpkg-dev
#   g++ g++-10 gcc-10 git-man libasan6 libatomic1 libbinutils libbrotli1
#   libc-dev-bin libc6-dev libcc1-0 libcrypt-dev libctf-nobfd0 libctf0
#   libcurl3-gnutls libcurl4 libdpkg-perl liberror-perl libexpat1 libgcc-10-dev
#   libgdbm-compat4 libgdbm6 libgomp1 libisl23 libitm1 libldap-2.4-2 liblsan0
#   libmpc3 libmpfr6 libnghttp2-14 libnsl-dev libperl5.32 libpsl5 libquadmath0
#   librtmp1 libsasl2-2 libsasl2-modules-db libssh2-1 libstdc++-10-dev
#   libtirpc-dev libtsan0 libubsan1 linux-libc-dev make openssl patch perl
#   perl-modules-5.32 xz-utils
# Suggested packages:
#   binutils-doc bzip2-doc cpp-doc gcc-10-locales debian-keyring g++-multilib
#   g++-10-multilib gcc-10-doc gcc-multilib manpages-dev autoconf automake
#   libtool flex bison gdb gcc-doc gcc-10-multilib gettext-base git-daemon-run
#   | git-daemon-sysvinit git-doc git-el git-email git-gui gitk gitweb git-cvs
#   git-mediawiki git-svn glibc-doc gnupg sensible-utils bzr gdbm-l10n
#   libstdc++-10-doc make-doc ed diffutils-doc perl-doc
#   libterm-readline-gnu-perl | libterm-readline-perl-perl
#   libtap-harness-archive-perl
# Recommended packages:
#   fakeroot gnupg libalgorithm-merge-perl less ssh-client manpages manpages-dev
#   libc-devtools libfile-fcntllock-perl liblocale-gettext-perl libldap-common
#   publicsuffix libsasl2-modules netbase
# The following NEW packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu build-essential bzip2
#   ca-certificates cpp cpp-10 curl dpkg-dev g++ g++-10 gcc gcc-10 git git-man
#   libasan6 libatomic1 libbinutils libbrotli1 libc-dev-bin libc6-dev libcc1-0
#   libcrypt-dev libctf-nobfd0 libctf0 libcurl3-gnutls libcurl4 libdpkg-perl
#   liberror-perl libexpat1 libgcc-10-dev libgdbm-compat4 libgdbm6 libgomp1
#   libisl23 libitm1 libldap-2.4-2 liblsan0 libmpc3 libmpfr6 libnghttp2-14
#   libnsl-dev libperl5.32 libpsl5 libquadmath0 librtmp1 libsasl2-2
#   libsasl2-modules-db libssh2-1 libstdc++-10-dev libtirpc-dev libtsan0
#   libubsan1 linux-libc-dev make openssl patch perl perl-modules-5.32 sudo
#   xz-utils
# 0 upgraded, 62 newly installed, 0 to remove and 0 not upgraded.
# Need to get 80.7 MB of archives.
# After this operation, 325 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian bullseye/main amd64 perl-modules-5.32 all 5.32.1-4+deb11u2 [2823 kB]
# Get:2 http://deb.debian.org/debian bullseye/main amd64 libgdbm6 amd64 1.19-2 [64.9 kB]
# Get:3 http://deb.debian.org/debian bullseye/main amd64 libgdbm-compat4 amd64 1.19-2 [44.7 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 libperl5.32 amd64 5.32.1-4+deb11u2 [4106 kB]
# Get:5 http://deb.debian.org/debian bullseye/main amd64 perl amd64 5.32.1-4+deb11u2 [293 kB]
# Get:6 http://deb.debian.org/debian bullseye/main amd64 bzip2 amd64 1.0.8-4 [49.3 kB]
# Get:7 http://deb.debian.org/debian-security bullseye-security/main amd64 openssl amd64 1.1.1n-0+deb11u5 [854 kB]
# Get:8 http://deb.debian.org/debian bullseye/main amd64 ca-certificates all 20210119 [158 kB]
# Get:9 http://deb.debian.org/debian bullseye/main amd64 xz-utils amd64 5.2.5-2.1~deb11u1 [220 kB]
# Get:10 http://deb.debian.org/debian bullseye/main amd64 binutils-common amd64 2.35.2-2 [2220 kB]
# Get:11 http://deb.debian.org/debian bullseye/main amd64 libbinutils amd64 2.35.2-2 [570 kB]
# Get:12 http://deb.debian.org/debian bullseye/main amd64 libctf-nobfd0 amd64 2.35.2-2 [110 kB]
# Get:13 http://deb.debian.org/debian bullseye/main amd64 libctf0 amd64 2.35.2-2 [53.2 kB]
# Get:14 http://deb.debian.org/debian bullseye/main amd64 binutils-x86-64-linux-gnu amd64 2.35.2-2 [1809 kB]
# Get:15 http://deb.debian.org/debian bullseye/main amd64 binutils amd64 2.35.2-2 [61.2 kB]
# Get:16 http://deb.debian.org/debian bullseye/main amd64 libc-dev-bin amd64 2.31-13+deb11u6 [276 kB]
# Get:17 http://deb.debian.org/debian-security bullseye-security/main amd64 linux-libc-dev amd64 5.10.179-1 [1618 kB]
# Get:18 http://deb.debian.org/debian bullseye/main amd64 libcrypt-dev amd64 1:4.4.18-4 [104 kB]
# Get:19 http://deb.debian.org/debian bullseye/main amd64 libtirpc-dev amd64 1.3.1-1+deb11u1 [191 kB]
# Get:20 http://deb.debian.org/debian bullseye/main amd64 libnsl-dev amd64 1.3.0-2 [66.4 kB]
# Get:21 http://deb.debian.org/debian bullseye/main amd64 libc6-dev amd64 2.31-13+deb11u6 [2360 kB]
# Get:22 http://deb.debian.org/debian bullseye/main amd64 libisl23 amd64 0.23-1 [676 kB]
# Get:23 http://deb.debian.org/debian bullseye/main amd64 libmpfr6 amd64 4.1.0-3 [2012 kB]
# Get:24 http://deb.debian.org/debian bullseye/main amd64 libmpc3 amd64 1.2.0-1 [45.0 kB]
# Get:25 http://deb.debian.org/debian bullseye/main amd64 cpp-10 amd64 10.2.1-6 [8528 kB]
# Get:26 http://deb.debian.org/debian bullseye/main amd64 cpp amd64 4:10.2.1-1 [19.7 kB]
# Get:27 http://deb.debian.org/debian bullseye/main amd64 libcc1-0 amd64 10.2.1-6 [47.0 kB]
# Get:28 http://deb.debian.org/debian bullseye/main amd64 libgomp1 amd64 10.2.1-6 [99.9 kB]
# Get:29 http://deb.debian.org/debian bullseye/main amd64 libitm1 amd64 10.2.1-6 [25.8 kB]
# Get:30 http://deb.debian.org/debian bullseye/main amd64 libatomic1 amd64 10.2.1-6 [9008 B]
# Get:31 http://deb.debian.org/debian bullseye/main amd64 libasan6 amd64 10.2.1-6 [2065 kB]
# Get:32 http://deb.debian.org/debian bullseye/main amd64 liblsan0 amd64 10.2.1-6 [828 kB]
# Get:33 http://deb.debian.org/debian bullseye/main amd64 libtsan0 amd64 10.2.1-6 [2000 kB]
# Get:34 http://deb.debian.org/debian bullseye/main amd64 libubsan1 amd64 10.2.1-6 [777 kB]
# Get:35 http://deb.debian.org/debian bullseye/main amd64 libquadmath0 amd64 10.2.1-6 [145 kB]
# Get:36 http://deb.debian.org/debian bullseye/main amd64 libgcc-10-dev amd64 10.2.1-6 [2328 kB]
# Get:37 http://deb.debian.org/debian bullseye/main amd64 gcc-10 amd64 10.2.1-6 [17.0 MB]
# Get:38 http://deb.debian.org/debian bullseye/main amd64 gcc amd64 4:10.2.1-1 [5192 B]
# Get:39 http://deb.debian.org/debian bullseye/main amd64 libstdc++-10-dev amd64 10.2.1-6 [1741 kB]
# Get:40 http://deb.debian.org/debian bullseye/main amd64 g++-10 amd64 10.2.1-6 [9380 kB]
# Get:41 http://deb.debian.org/debian bullseye/main amd64 g++ amd64 4:10.2.1-1 [1644 B]
# Get:42 http://deb.debian.org/debian bullseye/main amd64 make amd64 4.3-4.1 [396 kB]
# Get:43 http://deb.debian.org/debian bullseye/main amd64 libdpkg-perl all 1.20.12 [1551 kB]
# Get:44 http://deb.debian.org/debian bullseye/main amd64 patch amd64 2.7.6-7 [128 kB]
# Get:45 http://deb.debian.org/debian bullseye/main amd64 dpkg-dev all 1.20.12 [2312 kB]
# Get:46 http://deb.debian.org/debian bullseye/main amd64 build-essential amd64 12.9 [7704 B]
# Get:47 http://deb.debian.org/debian bullseye/main amd64 libbrotli1 amd64 1.0.9-2+b2 [279 kB]
# Get:48 http://deb.debian.org/debian bullseye/main amd64 libsasl2-modules-db amd64 2.1.27+dfsg-2.1+deb11u1 [69.1 kB]
# Get:49 http://deb.debian.org/debian bullseye/main amd64 libsasl2-2 amd64 2.1.27+dfsg-2.1+deb11u1 [106 kB]
# Get:50 http://deb.debian.org/debian bullseye/main amd64 libldap-2.4-2 amd64 2.4.57+dfsg-3+deb11u1 [232 kB]
# Get:51 http://deb.debian.org/debian bullseye/main amd64 libnghttp2-14 amd64 1.43.0-1 [77.1 kB]
# Get:52 http://deb.debian.org/debian bullseye/main amd64 libpsl5 amd64 0.21.0-1.2 [57.3 kB]
# Get:53 http://deb.debian.org/debian bullseye/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-2+b2 [60.8 kB]
# Get:54 http://deb.debian.org/debian bullseye/main amd64 libssh2-1 amd64 1.9.0-2 [156 kB]
# Get:55 http://deb.debian.org/debian bullseye/main amd64 libcurl4 amd64 7.74.0-1.3+deb11u7 [346 kB]
# Get:56 http://deb.debian.org/debian bullseye/main amd64 curl amd64 7.74.0-1.3+deb11u7 [270 kB]
# Get:57 http://deb.debian.org/debian bullseye/main amd64 libcurl3-gnutls amd64 7.74.0-1.3+deb11u7 [343 kB]
# Get:58 http://deb.debian.org/debian bullseye/main amd64 libexpat1 amd64 2.2.10-2+deb11u5 [98.2 kB]
# Get:59 http://deb.debian.org/debian bullseye/main amd64 liberror-perl all 0.17029-1 [31.0 kB]
# Get:60 http://deb.debian.org/debian bullseye/main amd64 git-man all 1:2.30.2-1+deb11u2 [1828 kB]
# Get:61 http://deb.debian.org/debian bullseye/main amd64 git amd64 1:2.30.2-1+deb11u2 [5518 kB]
# Get:62 http://deb.debian.org/debian bullseye/main amd64 sudo amd64 1.9.5p2-3+deb11u1 [1061 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 80.7 MB in 1s (71.2 MB/s)
# Selecting previously unselected package perl-modules-5.32.
# (Reading database ... 6664 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.32_5.32.1-4+deb11u2_all.deb ...
# Unpacking perl-modules-5.32 (5.32.1-4+deb11u2) ...
# Selecting previously unselected package libgdbm6:amd64.
# Preparing to unpack .../01-libgdbm6_1.19-2_amd64.deb ...
# Unpacking libgdbm6:amd64 (1.19-2) ...
# Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.19-2_amd64.deb ...
# Unpacking libgdbm-compat4:amd64 (1.19-2) ...
# Selecting previously unselected package libperl5.32:amd64.
# Preparing to unpack .../03-libperl5.32_5.32.1-4+deb11u2_amd64.deb ...
# Unpacking libperl5.32:amd64 (5.32.1-4+deb11u2) ...
# Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.32.1-4+deb11u2_amd64.deb ...
# Unpacking perl (5.32.1-4+deb11u2) ...
# Selecting previously unselected package bzip2.
# Preparing to unpack .../05-bzip2_1.0.8-4_amd64.deb ...
# Unpacking bzip2 (1.0.8-4) ...
# Selecting previously unselected package openssl.
# Preparing to unpack .../06-openssl_1.1.1n-0+deb11u5_amd64.deb ...
# Unpacking openssl (1.1.1n-0+deb11u5) ...
# Selecting previously unselected package ca-certificates.
# Preparing to unpack .../07-ca-certificates_20210119_all.deb ...
# Unpacking ca-certificates (20210119) ...
# Selecting previously unselected package xz-utils.
# Preparing to unpack .../08-xz-utils_5.2.5-2.1~deb11u1_amd64.deb ...
# Unpacking xz-utils (5.2.5-2.1~deb11u1) ...
# Selecting previously unselected package binutils-common:amd64.
# Preparing to unpack .../09-binutils-common_2.35.2-2_amd64.deb ...
# Unpacking binutils-common:amd64 (2.35.2-2) ...
# Selecting previously unselected package libbinutils:amd64.
# Preparing to unpack .../10-libbinutils_2.35.2-2_amd64.deb ...
# Unpacking libbinutils:amd64 (2.35.2-2) ...
# Selecting previously unselected package libctf-nobfd0:amd64.
# Preparing to unpack .../11-libctf-nobfd0_2.35.2-2_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.35.2-2) ...
# Selecting previously unselected package libctf0:amd64.
# Preparing to unpack .../12-libctf0_2.35.2-2_amd64.deb ...
# Unpacking libctf0:amd64 (2.35.2-2) ...
# Selecting previously unselected package binutils-x86-64-linux-gnu.
# Preparing to unpack .../13-binutils-x86-64-linux-gnu_2.35.2-2_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.35.2-2) ...
# Selecting previously unselected package binutils.
# Preparing to unpack .../14-binutils_2.35.2-2_amd64.deb ...
# Unpacking binutils (2.35.2-2) ...
# Selecting previously unselected package libc-dev-bin.
# Preparing to unpack .../15-libc-dev-bin_2.31-13+deb11u6_amd64.deb ...
# Unpacking libc-dev-bin (2.31-13+deb11u6) ...
# Selecting previously unselected package linux-libc-dev:amd64.
# Preparing to unpack .../16-linux-libc-dev_5.10.179-1_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (5.10.179-1) ...
# Selecting previously unselected package libcrypt-dev:amd64.
# Preparing to unpack .../17-libcrypt-dev_1%3a4.4.18-4_amd64.deb ...
# Unpacking libcrypt-dev:amd64 (1:4.4.18-4) ...
# Selecting previously unselected package libtirpc-dev:amd64.
# Preparing to unpack .../18-libtirpc-dev_1.3.1-1+deb11u1_amd64.deb ...
# Unpacking libtirpc-dev:amd64 (1.3.1-1+deb11u1) ...
# Selecting previously unselected package libnsl-dev:amd64.
# Preparing to unpack .../19-libnsl-dev_1.3.0-2_amd64.deb ...
# Unpacking libnsl-dev:amd64 (1.3.0-2) ...
# Selecting previously unselected package libc6-dev:amd64.
# Preparing to unpack .../20-libc6-dev_2.31-13+deb11u6_amd64.deb ...
# Unpacking libc6-dev:amd64 (2.31-13+deb11u6) ...
# Selecting previously unselected package libisl23:amd64.
# Preparing to unpack .../21-libisl23_0.23-1_amd64.deb ...
# Unpacking libisl23:amd64 (0.23-1) ...
# Selecting previously unselected package libmpfr6:amd64.
# Preparing to unpack .../22-libmpfr6_4.1.0-3_amd64.deb ...
# Unpacking libmpfr6:amd64 (4.1.0-3) ...
# Selecting previously unselected package libmpc3:amd64.
# Preparing to unpack .../23-libmpc3_1.2.0-1_amd64.deb ...
# Unpacking libmpc3:amd64 (1.2.0-1) ...
# Selecting previously unselected package cpp-10.
# Preparing to unpack .../24-cpp-10_10.2.1-6_amd64.deb ...
# Unpacking cpp-10 (10.2.1-6) ...
# Selecting previously unselected package cpp.
# Preparing to unpack .../25-cpp_4%3a10.2.1-1_amd64.deb ...
# Unpacking cpp (4:10.2.1-1) ...
# Selecting previously unselected package libcc1-0:amd64.
# Preparing to unpack .../26-libcc1-0_10.2.1-6_amd64.deb ...
# Unpacking libcc1-0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../27-libgomp1_10.2.1-6_amd64.deb ...
# Unpacking libgomp1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libitm1:amd64.
# Preparing to unpack .../28-libitm1_10.2.1-6_amd64.deb ...
# Unpacking libitm1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../29-libatomic1_10.2.1-6_amd64.deb ...
# Unpacking libatomic1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libasan6:amd64.
# Preparing to unpack .../30-libasan6_10.2.1-6_amd64.deb ...
# Unpacking libasan6:amd64 (10.2.1-6) ...
# Selecting previously unselected package liblsan0:amd64.
# Preparing to unpack .../31-liblsan0_10.2.1-6_amd64.deb ...
# Unpacking liblsan0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libtsan0:amd64.
# Preparing to unpack .../32-libtsan0_10.2.1-6_amd64.deb ...
# Unpacking libtsan0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libubsan1:amd64.
# Preparing to unpack .../33-libubsan1_10.2.1-6_amd64.deb ...
# Unpacking libubsan1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libquadmath0:amd64.
# Preparing to unpack .../34-libquadmath0_10.2.1-6_amd64.deb ...
# Unpacking libquadmath0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libgcc-10-dev:amd64.
# Preparing to unpack .../35-libgcc-10-dev_10.2.1-6_amd64.deb ...
# Unpacking libgcc-10-dev:amd64 (10.2.1-6) ...
# Selecting previously unselected package gcc-10.
# Preparing to unpack .../36-gcc-10_10.2.1-6_amd64.deb ...
# Unpacking gcc-10 (10.2.1-6) ...
# Selecting previously unselected package gcc.
# Preparing to unpack .../37-gcc_4%3a10.2.1-1_amd64.deb ...
# Unpacking gcc (4:10.2.1-1) ...
# Selecting previously unselected package libstdc++-10-dev:amd64.
# Preparing to unpack .../38-libstdc++-10-dev_10.2.1-6_amd64.deb ...
# Unpacking libstdc++-10-dev:amd64 (10.2.1-6) ...
# Selecting previously unselected package g++-10.
# Preparing to unpack .../39-g++-10_10.2.1-6_amd64.deb ...
# Unpacking g++-10 (10.2.1-6) ...
# Selecting previously unselected package g++.
# Preparing to unpack .../40-g++_4%3a10.2.1-1_amd64.deb ...
# Unpacking g++ (4:10.2.1-1) ...
# Selecting previously unselected package make.
# Preparing to unpack .../41-make_4.3-4.1_amd64.deb ...
# Unpacking make (4.3-4.1) ...
# Selecting previously unselected package libdpkg-perl.
# Preparing to unpack .../42-libdpkg-perl_1.20.12_all.deb ...
# Unpacking libdpkg-perl (1.20.12) ...
# Selecting previously unselected package patch.
# Preparing to unpack .../43-patch_2.7.6-7_amd64.deb ...
# Unpacking patch (2.7.6-7) ...
# Selecting previously unselected package dpkg-dev.
# Preparing to unpack .../44-dpkg-dev_1.20.12_all.deb ...
# Unpacking dpkg-dev (1.20.12) ...
# Selecting previously unselected package build-essential.
# Preparing to unpack .../45-build-essential_12.9_amd64.deb ...
# Unpacking build-essential (12.9) ...
# Selecting previously unselected package libbrotli1:amd64.
# Preparing to unpack .../46-libbrotli1_1.0.9-2+b2_amd64.deb ...
# Unpacking libbrotli1:amd64 (1.0.9-2+b2) ...
# Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../47-libsasl2-modules-db_2.1.27+dfsg-2.1+deb11u1_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../48-libsasl2-2_2.1.27+dfsg-2.1+deb11u1_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../49-libldap-2.4-2_2.4.57+dfsg-3+deb11u1_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
# Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../50-libnghttp2-14_1.43.0-1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.43.0-1) ...
# Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../51-libpsl5_0.21.0-1.2_amd64.deb ...
# Unpacking libpsl5:amd64 (0.21.0-1.2) ...
# Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../52-librtmp1_2.4+20151223.gitfa8646d.1-2+b2_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
# Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../53-libssh2-1_1.9.0-2_amd64.deb ...
# Unpacking libssh2-1:amd64 (1.9.0-2) ...
# Selecting previously unselected package libcurl4:amd64.
# Preparing to unpack .../54-libcurl4_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking libcurl4:amd64 (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package curl.
# Preparing to unpack .../55-curl_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking curl (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../56-libcurl3-gnutls_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../57-libexpat1_2.2.10-2+deb11u5_amd64.deb ...
# Unpacking libexpat1:amd64 (2.2.10-2+deb11u5) ...
# Selecting previously unselected package liberror-perl.
# Preparing to unpack .../58-liberror-perl_0.17029-1_all.deb ...
# Unpacking liberror-perl (0.17029-1) ...
# Selecting previously unselected package git-man.
# Preparing to unpack .../59-git-man_1%3a2.30.2-1+deb11u2_all.deb ...
# Unpacking git-man (1:2.30.2-1+deb11u2) ...
# Selecting previously unselected package git.
# Preparing to unpack .../60-git_1%3a2.30.2-1+deb11u2_amd64.deb ...
# Unpacking git (1:2.30.2-1+deb11u2) ...
# Selecting previously unselected package sudo.
# Preparing to unpack .../61-sudo_1.9.5p2-3+deb11u1_amd64.deb ...
# Unpacking sudo (1.9.5p2-3+deb11u1) ...
# Setting up libexpat1:amd64 (2.2.10-2+deb11u5) ...
# Setting up libpsl5:amd64 (0.21.0-1.2) ...
# Setting up perl-modules-5.32 (5.32.1-4+deb11u2) ...
# Setting up libbrotli1:amd64 (1.0.9-2+b2) ...
# Setting up binutils-common:amd64 (2.35.2-2) ...
# Setting up libnghttp2-14:amd64 (1.43.0-1) ...
# Setting up linux-libc-dev:amd64 (5.10.179-1) ...
# Setting up libctf-nobfd0:amd64 (2.35.2-2) ...
# Setting up libgomp1:amd64 (10.2.1-6) ...
# Setting up bzip2 (1.0.8-4) ...
# Setting up libasan6:amd64 (10.2.1-6) ...
# Setting up libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Setting up libtirpc-dev:amd64 (1.3.1-1+deb11u1) ...
# Setting up make (4.3-4.1) ...
# Setting up libmpfr6:amd64 (4.1.0-3) ...
# Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
# Setting up xz-utils (5.2.5-2.1~deb11u1) ...
# update-alternatives: using /usr/bin/xz to provide /usr/bin/lzma (lzma) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzma.1.gz because associated file /usr/share/man/man1/xz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/unlzma.1.gz because associated file /usr/share/man/man1/unxz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcat.1.gz because associated file /usr/share/man/man1/xzcat.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzmore.1.gz because associated file /usr/share/man/man1/xzmore.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzless.1.gz because associated file /usr/share/man/man1/xzless.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzdiff.1.gz because associated file /usr/share/man/man1/xzdiff.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcmp.1.gz because associated file /usr/share/man/man1/xzcmp.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzgrep.1.gz because associated file /usr/share/man/man1/xzgrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzegrep.1.gz because associated file /usr/share/man/man1/xzegrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzfgrep.1.gz because associated file /usr/share/man/man1/xzfgrep.1.gz (of link group lzma) doesn't exist
# Setting up libquadmath0:amd64 (10.2.1-6) ...
# Setting up libmpc3:amd64 (1.2.0-1) ...
# Setting up libatomic1:amd64 (10.2.1-6) ...
# Setting up patch (2.7.6-7) ...
# Setting up sudo (1.9.5p2-3+deb11u1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Setting up libubsan1:amd64 (10.2.1-6) ...
# Setting up libnsl-dev:amd64 (1.3.0-2) ...
# Setting up libcrypt-dev:amd64 (1:4.4.18-4) ...
# Setting up git-man (1:2.30.2-1+deb11u2) ...
# Setting up libssh2-1:amd64 (1.9.0-2) ...
# Setting up libbinutils:amd64 (2.35.2-2) ...
# Setting up libisl23:amd64 (0.23-1) ...
# Setting up libc-dev-bin (2.31-13+deb11u6) ...
# Setting up openssl (1.1.1n-0+deb11u5) ...
# Setting up libcc1-0:amd64 (10.2.1-6) ...
# Setting up liblsan0:amd64 (10.2.1-6) ...
# Setting up cpp-10 (10.2.1-6) ...
# Setting up libitm1:amd64 (10.2.1-6) ...
# Setting up libgdbm6:amd64 (1.19-2) ...
# Setting up libtsan0:amd64 (10.2.1-6) ...
# Setting up libctf0:amd64 (2.35.2-2) ...
# Setting up libgcc-10-dev:amd64 (10.2.1-6) ...
# Setting up libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
# Setting up libcurl3-gnutls:amd64 (7.74.0-1.3+deb11u7) ...
# Setting up ca-certificates (20210119) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# Updating certificates in /etc/ssl/certs...
# 129 added, 0 removed; done.
# Setting up libgdbm-compat4:amd64 (1.19-2) ...
# Setting up libperl5.32:amd64 (5.32.1-4+deb11u2) ...
# Setting up cpp (4:10.2.1-1) ...
# Setting up libcurl4:amd64 (7.74.0-1.3+deb11u7) ...
# Setting up libc6-dev:amd64 (2.31-13+deb11u6) ...
# Setting up curl (7.74.0-1.3+deb11u7) ...
# Setting up binutils-x86-64-linux-gnu (2.35.2-2) ...
# Setting up libstdc++-10-dev:amd64 (10.2.1-6) ...
# Setting up binutils (2.35.2-2) ...
# Setting up perl (5.32.1-4+deb11u2) ...
# Setting up gcc-10 (10.2.1-6) ...
# Setting up libdpkg-perl (1.20.12) ...
# Setting up g++-10 (10.2.1-6) ...
# Setting up gcc (4:10.2.1-1) ...
# Setting up dpkg-dev (1.20.12) ...
# Setting up liberror-perl (0.17029-1) ...
# Setting up git (1:2.30.2-1+deb11u2) ...
# Setting up g++ (4:10.2.1-1) ...
# update-alternatives: using /usr/bin/g++ to provide /usr/bin/c++ (c++) in auto mode
# Setting up build-essential (12.9) ...
# Processing triggers for libc-bin (2.31-13+deb11u6) ...
# Processing triggers for ca-certificates (20210119) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
# done.
# WARN[0029] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 8b4d84d2cb0
# STEP 6/14: RUN echo $USERNAME ALL=\(root\) NOPASSWD:ALL > /etc/sudoers.d/$USERNAME     && chmod 0440 /etc/sudoers.d/$USERNAME
# WARN[0041] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 720a441c274
# STEP 7/14: RUN mkdir -p /srv/conda && chown -R mambauser:1000 /srv/conda/
# WARN[0046] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 3a9f9cb97e9
# STEP 8/14: RUN mkdir -p /workspaces/command-line-tools/otsu
# WARN[0050] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 2ed755f65ff
# STEP 9/14: RUN chown -R 1000:1000 /workspaces/command-line-tools/otsu
# WARN[0055] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> d73801d2022
# STEP 10/14: RUN chmod -R 777 /home/mambauser
# WARN[0060] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 9d77653a5d5
# STEP 11/14: USER mambauser
# WARN[0064] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> b4db2faf46b
# STEP 12/14: RUN micromamba create -r /srv/conda -n env_otsu -c conda-forge gdal scikit-image click
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
#
# Transaction
#
#   Prefix: /srv/conda/envs/env_otsu
#
#   Updating specs:
#
#    - gdal
#    - scikit-image
#    - click
#
#
#   Package                           Version  Build                Channel          Size
# ─────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                       0.1  conda_forge          conda-forge       3kB
#   + _openmp_mutex                       4.5  2_gnu                conda-forge      24kB
#   + aom                               3.5.0  h27087fc_0           conda-forge       3MB
#   + blosc                            1.21.4  h0f2a231_0           conda-forge      49kB
#   + boost-cpp                        1.78.0  h6582d0a_3           conda-forge      16MB
#   + brotli                            1.0.9  h166bdaf_8           conda-forge      19kB
#   + brotli-bin                        1.0.9  h166bdaf_8           conda-forge      20kB
#   + brunsli                             0.1  h9c3ff4c_0           conda-forge     205kB
#   + bzip2                             1.0.8  h7f98852_4           conda-forge     496kB
#   + c-ares                           1.19.1  hd590300_0           conda-forge     113kB
#   + c-blosc2                          2.9.2  hb4ffafa_0           conda-forge     305kB
#   + ca-certificates                2023.5.7  hbcca054_0           conda-forge     148kB
#   + cairo                            1.16.0  hbbf8b49_1016        conda-forge       1MB
#   + certifi                        2023.5.7  pyhd8ed1ab_0         conda-forge     152kB
#   + cfitsio                           4.2.0  hd9d235c_0           conda-forge     848kB
#   + charls                            2.4.2  h59595ed_0           conda-forge     150kB
#   + charset-normalizer                3.1.0  pyhd8ed1ab_0         conda-forge      45kB
#   + click                             8.1.3  unix_pyhd8ed1ab_2    conda-forge      76kB
#   + cloudpickle                       2.2.1  pyhd8ed1ab_0         conda-forge      28kB
#   + curl                              8.1.2  h409715c_0           conda-forge      91kB
#   + cytoolz                          0.12.0  py311hd4cff14_1      conda-forge     426kB
#   + dask-core                      2023.5.1  pyhd8ed1ab_0         conda-forge     846kB
#   + dav1d                             1.2.1  hd590300_0           conda-forge     760kB
#   + expat                             2.5.0  hcb278e6_1           conda-forge     137kB
#   + font-ttf-dejavu-sans-mono          2.37  hab24e00_0           conda-forge     397kB
#   + font-ttf-inconsolata              3.000  h77eed37_0           conda-forge      97kB
#   + font-ttf-source-code-pro          2.038  h77eed37_0           conda-forge     701kB
#   + font-ttf-ubuntu                    0.83  hab24e00_0           conda-forge       2MB
#   + fontconfig                       2.14.2  h14ed4e7_0           conda-forge     272kB
#   + fonts-conda-ecosystem                 1  0                    conda-forge       4kB
#   + fonts-conda-forge                     1  0                    conda-forge       4kB
#   + freetype                         2.12.1  hca18f0e_1           conda-forge     626kB
#   + freexl                            1.0.6  h166bdaf_1           conda-forge      50kB
#   + fsspec                         2023.5.0  pyh1a96a4e_0         conda-forge     116kB
#   + gdal                              3.7.0  py311h281082f_2      conda-forge       2MB
#   + geos                             3.11.2  hcb278e6_0           conda-forge       2MB
#   + geotiff                           1.7.1  h22adcc9_9           conda-forge     257kB
#   + gettext                          0.21.1  h27087fc_0           conda-forge       4MB
#   + giflib                            5.2.1  h0b41bf4_3           conda-forge      77kB
#   + hdf4                             4.2.15  h501b40f_6           conda-forge     758kB
#   + hdf5                             1.14.0  nompi_hb72d44e_103   conda-forge       4MB
#   + icu                                72.1  hcb278e6_0           conda-forge      12MB
#   + idna                                3.4  pyhd8ed1ab_0         conda-forge      57kB
#   + imagecodecs                   2023.1.23  py311hd374d05_2      conda-forge       2MB
#   + imageio                          2.28.1  pyh24c5eb1_0         conda-forge       3MB
#   + importlib-metadata                6.6.0  pyha770c72_0         conda-forge      26kB
#   + importlib_metadata                6.6.0  hd8ed1ab_0           conda-forge       9kB
#   + json-c                             0.16  hc379101_0           conda-forge     281kB
#   + jxrlib                              1.1  h7f98852_2           conda-forge     241kB
#   + kealib                            1.5.1  h3845be2_3           conda-forge     173kB
#   + keyutils                          1.6.1  h166bdaf_0           conda-forge     118kB
#   + krb5                             1.20.1  h81ceb04_0           conda-forge       1MB
#   + lazy_loader                         0.2  pyhd8ed1ab_0         conda-forge      14kB
#   + lcms2                              2.15  haa2dc70_1           conda-forge     242kB
#   + ld_impl_linux-64                   2.40  h41732ed_0           conda-forge     705kB
#   + lerc                              4.0.0  h27087fc_0           conda-forge     282kB
#   + libaec                            1.0.6  hcb278e6_1           conda-forge      34kB
#   + libarchive                        3.6.2  h039dbb9_1           conda-forge     844kB
#   + libavif                          0.11.1  h8182462_2           conda-forge     102kB
#   + libblas                           3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libbrotlicommon                   1.0.9  h166bdaf_8           conda-forge      67kB
#   + libbrotlidec                      1.0.9  h166bdaf_8           conda-forge      34kB
#   + libbrotlienc                      1.0.9  h166bdaf_8           conda-forge     295kB
#   + libcblas                          3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libcurl                           8.1.2  h409715c_0           conda-forge     373kB
#   + libdeflate                         1.18  h0b41bf4_0           conda-forge      65kB
#   + libedit                    3.1.20191231  he28a2e2_2           conda-forge     124kB
#   + libev                              4.33  h516909a_1           conda-forge     106kB
#   + libexpat                          2.5.0  hcb278e6_1           conda-forge      78kB
#   + libffi                            3.4.2  h7f98852_5           conda-forge      58kB
#   + libgcc-ng                        13.1.0  he5830b7_0           conda-forge     776kB
#   + libgdal                           3.7.0  h5418a03_2           conda-forge      11MB
#   + libgfortran-ng                   13.1.0  h69a702a_0           conda-forge      23kB
#   + libgfortran5                     13.1.0  h15d22d2_0           conda-forge       1MB
#   + libglib                          2.76.3  hebfc3b9_0           conda-forge       3MB
#   + libgomp                          13.1.0  he5830b7_0           conda-forge     419kB
#   + libiconv                           1.17  h166bdaf_0           conda-forge       1MB
#   + libjpeg-turbo                   2.1.5.1  h0b41bf4_0           conda-forge     491kB
#   + libkml                            1.3.0  h37653c0_1015        conda-forge     625kB
#   + liblapack                         3.9.0  17_linux64_openblas  conda-forge      14kB
#   + libnetcdf                         4.9.2  nompi_h0f3d0bb_105   conda-forge     841kB
#   + libnghttp2                       1.52.0  h61bc06f_0           conda-forge     622kB
#   + libnsl                            2.0.0  h7f98852_0           conda-forge      31kB
#   + libopenblas                      0.3.23  pthreads_h80387f5_0  conda-forge       5MB
#   + libpng                           1.6.39  h753d276_0           conda-forge     283kB
#   + libpq                              15.3  hbcd7760_1           conda-forge       3MB
#   + librttopo                         1.1.0  h0d5128d_13          conda-forge     234kB
#   + libspatialite                     5.0.1  hca56755_27          conda-forge       3MB
#   + libsqlite                        3.42.0  h2797004_0           conda-forge     829kB
#   + libssh2                          1.11.0  h0841786_0           conda-forge     271kB
#   + libstdcxx-ng                     13.1.0  hfd8a6a1_0           conda-forge       4MB
#   + libtiff                           4.5.0  ha587672_6           conda-forge     407kB
#   + libuuid                          2.38.1  h0b41bf4_0           conda-forge      34kB
#   + libwebp-base                      1.3.0  h0b41bf4_0           conda-forge     357kB
#   + libxcb                             1.15  h0b41bf4_0           conda-forge     384kB
#   + libxml2                          2.11.4  h0d562d8_0           conda-forge     704kB
#   + libzip                            1.9.2  hc929e4a_1           conda-forge      99kB
#   + libzlib                          1.2.13  h166bdaf_4           conda-forge      66kB
#   + libzopfli                         1.0.3  h9c3ff4c_0           conda-forge     168kB
#   + locket                            1.0.0  pyhd8ed1ab_0         conda-forge       8kB
#   + lz4-c                             1.9.4  hcb278e6_0           conda-forge     143kB
#   + lzo                                2.10  h516909a_1000        conda-forge     321kB
#   + ncurses                             6.3  h27087fc_1           conda-forge       1MB
#   + networkx                            3.1  pyhd8ed1ab_0         conda-forge       1MB
#   + nspr                               4.35  h27087fc_0           conda-forge     227kB
#   + nss                                3.89  he45b914_0           conda-forge       2MB
#   + numpy                            1.24.3  py311h64a7726_0      conda-forge       8MB
#   + openjpeg                          2.5.0  hfec8fc6_2           conda-forge     352kB
#   + openssl                           3.1.1  hd590300_1           conda-forge       3MB
#   + packaging                          23.1  pyhd8ed1ab_0         conda-forge      46kB
#   + partd                             1.4.0  pyhd8ed1ab_0         conda-forge      20kB
#   + pcre2                             10.40  hc3806b6_0           conda-forge       2MB
#   + pillow                            9.5.0  py311h0b84326_1      conda-forge      47MB
#   + pip                              23.1.2  pyhd8ed1ab_0         conda-forge       1MB
#   + pixman                           0.40.0  h36c2ea0_0           conda-forge     643kB
#   + platformdirs                      3.5.1  pyhd8ed1ab_0         conda-forge      19kB
#   + pooch                             1.7.0  pyha770c72_3         conda-forge      51kB
#   + poppler                         23.05.0  hd18248d_1           conda-forge      15MB
#   + poppler-data                     0.4.12  hd8ed1ab_0           conda-forge       2MB
#   + postgresql                         15.3  hd458b1d_1           conda-forge       5MB
#   + proj                              9.2.1  ha643af7_0           conda-forge       3MB
#   + pthread-stubs                       0.4  h36c2ea0_1001        conda-forge       6kB
#   + pysocks                           1.7.1  pyha2e5f31_6         conda-forge      19kB
#   + python                           3.11.3  h2755cc3_0_cpython   conda-forge      31MB
#   + python_abi                         3.11  3_cp311              conda-forge       6kB
#   + pywavelets                        1.4.1  py311hcb2cf0a_0      conda-forge       4MB
#   + pyyaml                              6.0  py311hd4cff14_5      conda-forge     207kB
#   + readline                            8.2  h8228510_1           conda-forge     281kB
#   + requests                         2.31.0  pyhd8ed1ab_0         conda-forge      57kB
#   + scikit-image                     0.20.0  py311h2872171_1      conda-forge      11MB
#   + scipy                            1.10.1  py311h64a7726_3      conda-forge      16MB
#   + setuptools                       67.7.2  pyhd8ed1ab_0         conda-forge     583kB
#   + snappy                           1.1.10  h9fff704_0           conda-forge      39kB
#   + sqlite                           3.42.0  h2c6b66d_0           conda-forge     818kB
#   + tifffile                      2023.4.12  pyhd8ed1ab_0         conda-forge     175kB
#   + tiledb                           2.13.2  hd532e3d_0           conda-forge       5MB
#   + tk                               8.6.12  h27826a3_0           conda-forge       3MB
#   + toolz                            0.12.0  pyhd8ed1ab_0         conda-forge      49kB
#   + typing-extensions                 4.6.3  hd8ed1ab_0           conda-forge      10kB
#   + typing_extensions                 4.6.3  pyha770c72_0         conda-forge      35kB
#   + tzcode                            2023c  h0b41bf4_0           conda-forge      69kB
#   + tzdata                            2023c  h71feb2d_0           conda-forge     118kB
#   + urllib3                           2.0.2  pyhd8ed1ab_0         conda-forge      98kB
#   + wheel                            0.40.0  pyhd8ed1ab_0         conda-forge      56kB
#   + xerces-c                          3.2.4  h8d71039_2           conda-forge       2MB
#   + xorg-kbproto                      1.0.7  h7f98852_1002        conda-forge      27kB
#   + xorg-libice                       1.1.1  hd590300_0           conda-forge      58kB
#   + xorg-libsm                        1.2.4  h7391055_0           conda-forge      27kB
#   + xorg-libx11                       1.8.4  h8ee46fc_1           conda-forge     833kB
#   + xorg-libxau                      1.0.11  hd590300_0           conda-forge      14kB
#   + xorg-libxdmcp                     1.1.3  h7f98852_0           conda-forge      19kB
#   + xorg-libxext                      1.3.4  h0b41bf4_2           conda-forge      50kB
#   + xorg-libxrender                  0.9.10  h7f98852_1003        conda-forge      33kB
#   + xorg-renderproto                 0.11.1  h7f98852_1002        conda-forge      10kB
#   + xorg-xextproto                    7.3.0  h0b41bf4_1003        conda-forge      30kB
#   + xorg-xproto                      7.0.31  h7f98852_1007        conda-forge      75kB
#   + xz                                5.2.6  h166bdaf_0           conda-forge     418kB
#   + yaml                              0.2.5  h7f98852_2           conda-forge      89kB
#   + zfp                               1.0.0  h27087fc_3           conda-forge     292kB
#   + zipp                             3.15.0  pyhd8ed1ab_0         conda-forge      17kB
#   + zlib                             1.2.13  h166bdaf_4           conda-forge      94kB
#   + zlib-ng                           2.0.7  h0b41bf4_0           conda-forge      95kB
#   + zstd                              1.5.2  h3eb15da_6           conda-forge     420kB
#
#   Summary:
#
#   Install: 163 packages
#
#   Total download: 273MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#
# Confirm changes: [Y/n]
# Transaction starting
# Linking font-ttf-dejavu-sans-mono-2.37-hab24e00_0
# Linking font-ttf-ubuntu-0.83-hab24e00_0
# Linking font-ttf-inconsolata-3.000-h77eed37_0
# Linking font-ttf-source-code-pro-2.038-h77eed37_0
# Linking tzdata-2023c-h71feb2d_0
# Linking poppler-data-0.4.12-hd8ed1ab_0
# Linking fonts-conda-forge-1-0
# Linking fonts-conda-ecosystem-1-0
# Linking _libgcc_mutex-0.1-conda_forge
# Linking libstdcxx-ng-13.1.0-hfd8a6a1_0
# Linking python_abi-3.11-3_cp311
# Linking ld_impl_linux-64-2.40-h41732ed_0
# Linking ca-certificates-2023.5.7-hbcca054_0
# Linking libgfortran5-13.1.0-h15d22d2_0
# Linking libgomp-13.1.0-he5830b7_0
# Linking libgfortran-ng-13.1.0-h69a702a_0
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-ng-13.1.0-he5830b7_0
# Linking xorg-xproto-7.0.31-h7f98852_1007
# Linking xorg-kbproto-1.0.7-h7f98852_1002
# Linking xorg-renderproto-0.11.1-h7f98852_1002
# Linking libzopfli-1.0.3-h9c3ff4c_0
# Linking jxrlib-1.1-h7f98852_2
# Linking lzo-2.10-h516909a_1000
# Linking xorg-libxdmcp-1.1.3-h7f98852_0
# Linking pthread-stubs-0.4-h36c2ea0_1001
# Linking yaml-0.2.5-h7f98852_2
# Linking tzcode-2023c-h0b41bf4_0
# Linking xorg-xextproto-7.3.0-h0b41bf4_1003
# Linking xorg-libice-1.1.1-hd590300_0
# Linking charls-2.4.2-h59595ed_0
# Linking zlib-ng-2.0.7-h0b41bf4_0
# Linking zfp-1.0.0-h27087fc_3
# Linking libbrotlicommon-1.0.9-h166bdaf_8
# Linking dav1d-1.2.1-hd590300_0
# Linking aom-3.5.0-h27087fc_0
# Linking libaec-1.0.6-hcb278e6_1
# Linking libopenblas-0.3.23-pthreads_h80387f5_0
# Linking lz4-c-1.9.4-hcb278e6_0
# Linking giflib-5.2.1-h0b41bf4_3
# Linking libev-4.33-h516909a_1
# Linking c-ares-1.19.1-hd590300_0
# Linking freexl-1.0.6-h166bdaf_1
# Linking xorg-libxau-1.0.11-hd590300_0
# Linking keyutils-1.6.1-h166bdaf_0
# Linking openssl-3.1.1-hd590300_1
# Linking libffi-3.4.2-h7f98852_5
# Linking bzip2-1.0.8-h7f98852_4
# Linking ncurses-6.3-h27087fc_1
# Linking pixman-0.40.0-h36c2ea0_0
# Linking libnsl-2.0.0-h7f98852_0
# Linking nspr-4.35-h27087fc_0
# Linking gettext-0.21.1-h27087fc_0
# Linking snappy-1.1.10-h9fff704_0
# Linking libwebp-base-1.3.0-h0b41bf4_0
# Linking libuuid-2.38.1-h0b41bf4_0
# Linking libjpeg-turbo-2.1.5.1-h0b41bf4_0
# Linking libexpat-2.5.0-hcb278e6_1
# Linking libdeflate-1.18-h0b41bf4_0
# Linking icu-72.1-hcb278e6_0
# Linking geos-3.11.2-hcb278e6_0
# Linking xz-5.2.6-h166bdaf_0
# Linking libzlib-1.2.13-h166bdaf_4
# Linking libiconv-1.17-h166bdaf_0
# Linking lerc-4.0.0-h27087fc_0
# Linking json-c-0.16-hc379101_0
# Linking libbrotlidec-1.0.9-h166bdaf_8
# Linking libbrotlienc-1.0.9-h166bdaf_8
# Linking libavif-0.11.1-h8182462_2
# Linking libblas-3.9.0-17_linux64_openblas
# Linking libxcb-1.15-h0b41bf4_0
# Linking libedit-3.1.20191231-he28a2e2_2
# Linking readline-8.2-h8228510_1
# Linking xorg-libsm-1.2.4-h7391055_0
# Linking expat-2.5.0-hcb278e6_1
# Linking librttopo-1.1.0-h0d5128d_13
# Linking libzip-1.9.2-hc929e4a_1
# Linking libssh2-1.11.0-h0841786_0
# Linking zstd-1.5.2-h3eb15da_6
# Linking tk-8.6.12-h27826a3_0
# Linking zlib-1.2.13-h166bdaf_4
# Linking hdf4-4.2.15-h501b40f_6
# Linking libnghttp2-1.52.0-h61bc06f_0
# Linking libsqlite-3.42.0-h2797004_0
# Linking libpng-1.6.39-h753d276_0
# Linking pcre2-10.40-hc3806b6_0
# Linking libxml2-2.11.4-h0d562d8_0
# Linking brotli-bin-1.0.9-h166bdaf_8
# Linking libcblas-3.9.0-17_linux64_openblas
# Linking liblapack-3.9.0-17_linux64_openblas
# Linking xorg-libx11-1.8.4-h8ee46fc_1
# Linking krb5-1.20.1-h81ceb04_0
# Linking c-blosc2-2.9.2-hb4ffafa_0
# Linking libtiff-4.5.0-ha587672_6
# Linking boost-cpp-1.78.0-h6582d0a_3
# Linking blosc-1.21.4-h0f2a231_0
# Linking sqlite-3.42.0-h2c6b66d_0
# Linking python-3.11.3-h2755cc3_0_cpython
# Linking nss-3.89-he45b914_0
# Linking freetype-2.12.1-hca18f0e_1
# Linking libglib-2.76.3-hebfc3b9_0
# Linking libarchive-3.6.2-h039dbb9_1
# Linking brotli-1.0.9-h166bdaf_8
# Linking xorg-libxext-1.3.4-h0b41bf4_2
# Linking xorg-libxrender-0.9.10-h7f98852_1003
# Linking libpq-15.3-hbcd7760_1
# Linking libcurl-8.1.2-h409715c_0
# Linking openjpeg-2.5.0-hfec8fc6_2
# Linking lcms2-2.15-haa2dc70_1
# Linking libkml-1.3.0-h37653c0_1015
# Linking fontconfig-2.14.2-h14ed4e7_0
# Linking brunsli-0.1-h9c3ff4c_0
# Linking postgresql-15.3-hd458b1d_1
# Linking hdf5-1.14.0-nompi_hb72d44e_103
# Linking curl-8.1.2-h409715c_0
# Linking xerces-c-3.2.4-h8d71039_2
# Linking proj-9.2.1-ha643af7_0
# Linking cfitsio-4.2.0-hd9d235c_0
# Linking cairo-1.16.0-hbbf8b49_1016
# Linking kealib-1.5.1-h3845be2_3
# Linking libnetcdf-4.9.2-nompi_h0f3d0bb_105
# Linking tiledb-2.13.2-hd532e3d_0
# Linking geotiff-1.7.1-h22adcc9_9
# Linking libspatialite-5.0.1-hca56755_27
# Linking poppler-23.05.0-hd18248d_1
# Linking libgdal-3.7.0-h5418a03_2
# Linking wheel-0.40.0-pyhd8ed1ab_0
# Linking setuptools-67.7.2-pyhd8ed1ab_0
# Linking pip-23.1.2-pyhd8ed1ab_0
# Linking charset-normalizer-3.1.0-pyhd8ed1ab_0
# Linking pysocks-1.7.1-pyha2e5f31_6
# Linking idna-3.4-pyhd8ed1ab_0
# Linking certifi-2023.5.7-pyhd8ed1ab_0
# Linking zipp-3.15.0-pyhd8ed1ab_0
# Linking locket-1.0.0-pyhd8ed1ab_0
# Linking typing_extensions-4.6.3-pyha770c72_0
# Linking fsspec-2023.5.0-pyh1a96a4e_0
# Linking packaging-23.1-pyhd8ed1ab_0
# Linking networkx-3.1-pyhd8ed1ab_0
# Linking lazy_loader-0.2-pyhd8ed1ab_0
# Linking toolz-0.12.0-pyhd8ed1ab_0
# Linking cloudpickle-2.2.1-pyhd8ed1ab_0
# Linking click-8.1.3-unix_pyhd8ed1ab_2
# Linking urllib3-2.0.2-pyhd8ed1ab_0
# Linking importlib-metadata-6.6.0-pyha770c72_0
# Linking typing-extensions-4.6.3-hd8ed1ab_0
# Linking partd-1.4.0-pyhd8ed1ab_0
# Linking requests-2.31.0-pyhd8ed1ab_0
# Linking importlib_metadata-6.6.0-hd8ed1ab_0
# Linking platformdirs-3.5.1-pyhd8ed1ab_0
# Linking pooch-1.7.0-pyha770c72_3
# Linking pyyaml-6.0-py311hd4cff14_5
# Linking numpy-1.24.3-py311h64a7726_0
# Linking pillow-9.5.0-py311h0b84326_1
# Linking cytoolz-0.12.0-py311hd4cff14_1
# Linking imagecodecs-2023.1.23-py311hd374d05_2
# Linking scipy-1.10.1-py311h64a7726_3
# Linking pywavelets-1.4.1-py311hcb2cf0a_0
# Linking gdal-3.7.0-py311h281082f_2
# Linking dask-core-2023.5.1-pyhd8ed1ab_0
# Linking imageio-2.28.1-pyh24c5eb1_0
# Linking tifffile-2023.4.12-pyhd8ed1ab_0
# Linking scikit-image-0.20.0-py311h2872171_1
#
# Transaction finished
#
# To activate this environment, use:
#
#     micromamba activate env_otsu
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -n env_otsu mycommand
#
# WARN[0134] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 9b94fedd917
# STEP 13/14: ADD water-bodies/command-line-tools/otsu/app.py /workspaces/command-line-tools/otsu/app.py
# WARN[0228] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> fc86997ce86
# STEP 14/14: WORKDIR /home/mambauser
# COMMIT simonevaccari/otsu:0.1.0
# WARN[0262] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 9ee6e070778
# Successfully tagged localhost/simonevaccari/otsu:0.1.0
# 9ee6e070778303454646a186f9cfaaaf57e715ad7e3cde87b29891f56cdad620

# %%
# !docker build -t simonevaccari/stac:0.1.0 --no-cache -f water-bodies/command-line-tools/stac/Dockerfile .
# Out:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# STEP 1/13: FROM docker.io/mambaorg/micromamba:latest
# STEP 2/13: USER root
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 239a96eafb9
# STEP 3/13: ENV USERNAME=mambauser
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 377cd221245
# STEP 4/13: ENV PATH=/srv/conda/envs/env_stac/bin:$PATH
# WARN[0000] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> a59f57e2d64
# STEP 5/13: RUN apt-get update -y  && apt-get upgrade -y  && apt-get install -y --no-install-recommends         ca-certificates         curl sudo git gcc build-essential
# Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
# Get:2 http://deb.debian.org/debian-security bullseye-security InRelease [48.4 kB]
# Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183 kB]
# Get:5 http://deb.debian.org/debian-security bullseye-security/main amd64 Packages [245 kB]
# Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Packages [14.8 kB]
# Fetched 8650 kB in 2s (4645 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Calculating upgrade...
# The following packages will be upgraded:
#   libssl1.1
# 1 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Need to get 1559 kB of archives.
# After this operation, 4096 B disk space will be freed.
# Get:1 http://deb.debian.org/debian-security bullseye-security/main amd64 libssl1.1 amd64 1.1.1n-0+deb11u5 [1559 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 1559 kB in 0s (33.8 MB/s)
# (Reading database ... 6664 files and directories currently installed.)
# Preparing to unpack .../libssl1.1_1.1.1n-0+deb11u5_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1n-0+deb11u5) over (1.1.1n-0+deb11u4) ...
# Setting up libssl1.1:amd64 (1.1.1n-0+deb11u5) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.32.1 /usr/local/share/perl/5.32.1 /usr/lib/x86_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
# Processing triggers for libc-bin (2.31-13+deb11u6) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu bzip2 cpp cpp-10 dpkg-dev
#   g++ g++-10 gcc-10 git-man libasan6 libatomic1 libbinutils libbrotli1
#   libc-dev-bin libc6-dev libcc1-0 libcrypt-dev libctf-nobfd0 libctf0
#   libcurl3-gnutls libcurl4 libdpkg-perl liberror-perl libexpat1 libgcc-10-dev
#   libgdbm-compat4 libgdbm6 libgomp1 libisl23 libitm1 libldap-2.4-2 liblsan0
#   libmpc3 libmpfr6 libnghttp2-14 libnsl-dev libperl5.32 libpsl5 libquadmath0
#   librtmp1 libsasl2-2 libsasl2-modules-db libssh2-1 libstdc++-10-dev
#   libtirpc-dev libtsan0 libubsan1 linux-libc-dev make openssl patch perl
#   perl-modules-5.32 xz-utils
# Suggested packages:
#   binutils-doc bzip2-doc cpp-doc gcc-10-locales debian-keyring g++-multilib
#   g++-10-multilib gcc-10-doc gcc-multilib manpages-dev autoconf automake
#   libtool flex bison gdb gcc-doc gcc-10-multilib gettext-base git-daemon-run
#   | git-daemon-sysvinit git-doc git-el git-email git-gui gitk gitweb git-cvs
#   git-mediawiki git-svn glibc-doc gnupg sensible-utils bzr gdbm-l10n
#   libstdc++-10-doc make-doc ed diffutils-doc perl-doc
#   libterm-readline-gnu-perl | libterm-readline-perl-perl
#   libtap-harness-archive-perl
# Recommended packages:
#   fakeroot gnupg libalgorithm-merge-perl less ssh-client manpages manpages-dev
#   libc-devtools libfile-fcntllock-perl liblocale-gettext-perl libldap-common
#   publicsuffix libsasl2-modules netbase
# The following NEW packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu build-essential bzip2
#   ca-certificates cpp cpp-10 curl dpkg-dev g++ g++-10 gcc gcc-10 git git-man
#   libasan6 libatomic1 libbinutils libbrotli1 libc-dev-bin libc6-dev libcc1-0
#   libcrypt-dev libctf-nobfd0 libctf0 libcurl3-gnutls libcurl4 libdpkg-perl
#   liberror-perl libexpat1 libgcc-10-dev libgdbm-compat4 libgdbm6 libgomp1
#   libisl23 libitm1 libldap-2.4-2 liblsan0 libmpc3 libmpfr6 libnghttp2-14
#   libnsl-dev libperl5.32 libpsl5 libquadmath0 librtmp1 libsasl2-2
#   libsasl2-modules-db libssh2-1 libstdc++-10-dev libtirpc-dev libtsan0
#   libubsan1 linux-libc-dev make openssl patch perl perl-modules-5.32 sudo
#   xz-utils
# 0 upgraded, 62 newly installed, 0 to remove and 0 not upgraded.
# Need to get 80.7 MB of archives.
# After this operation, 325 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian bullseye/main amd64 perl-modules-5.32 all 5.32.1-4+deb11u2 [2823 kB]
# Get:2 http://deb.debian.org/debian bullseye/main amd64 libgdbm6 amd64 1.19-2 [64.9 kB]
# Get:3 http://deb.debian.org/debian bullseye/main amd64 libgdbm-compat4 amd64 1.19-2 [44.7 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 libperl5.32 amd64 5.32.1-4+deb11u2 [4106 kB]
# Get:5 http://deb.debian.org/debian bullseye/main amd64 perl amd64 5.32.1-4+deb11u2 [293 kB]
# Get:6 http://deb.debian.org/debian bullseye/main amd64 bzip2 amd64 1.0.8-4 [49.3 kB]
# Get:7 http://deb.debian.org/debian-security bullseye-security/main amd64 openssl amd64 1.1.1n-0+deb11u5 [854 kB]
# Get:8 http://deb.debian.org/debian bullseye/main amd64 ca-certificates all 20210119 [158 kB]
# Get:9 http://deb.debian.org/debian bullseye/main amd64 xz-utils amd64 5.2.5-2.1~deb11u1 [220 kB]
# Get:10 http://deb.debian.org/debian bullseye/main amd64 binutils-common amd64 2.35.2-2 [2220 kB]
# Get:11 http://deb.debian.org/debian bullseye/main amd64 libbinutils amd64 2.35.2-2 [570 kB]
# Get:12 http://deb.debian.org/debian bullseye/main amd64 libctf-nobfd0 amd64 2.35.2-2 [110 kB]
# Get:13 http://deb.debian.org/debian bullseye/main amd64 libctf0 amd64 2.35.2-2 [53.2 kB]
# Get:14 http://deb.debian.org/debian bullseye/main amd64 binutils-x86-64-linux-gnu amd64 2.35.2-2 [1809 kB]
# Get:15 http://deb.debian.org/debian bullseye/main amd64 binutils amd64 2.35.2-2 [61.2 kB]
# Get:16 http://deb.debian.org/debian bullseye/main amd64 libc-dev-bin amd64 2.31-13+deb11u6 [276 kB]
# Get:17 http://deb.debian.org/debian-security bullseye-security/main amd64 linux-libc-dev amd64 5.10.179-1 [1618 kB]
# Get:18 http://deb.debian.org/debian bullseye/main amd64 libcrypt-dev amd64 1:4.4.18-4 [104 kB]
# Get:19 http://deb.debian.org/debian bullseye/main amd64 libtirpc-dev amd64 1.3.1-1+deb11u1 [191 kB]
# Get:20 http://deb.debian.org/debian bullseye/main amd64 libnsl-dev amd64 1.3.0-2 [66.4 kB]
# Get:21 http://deb.debian.org/debian bullseye/main amd64 libc6-dev amd64 2.31-13+deb11u6 [2360 kB]
# Get:22 http://deb.debian.org/debian bullseye/main amd64 libisl23 amd64 0.23-1 [676 kB]
# Get:23 http://deb.debian.org/debian bullseye/main amd64 libmpfr6 amd64 4.1.0-3 [2012 kB]
# Get:24 http://deb.debian.org/debian bullseye/main amd64 libmpc3 amd64 1.2.0-1 [45.0 kB]
# Get:25 http://deb.debian.org/debian bullseye/main amd64 cpp-10 amd64 10.2.1-6 [8528 kB]
# Get:26 http://deb.debian.org/debian bullseye/main amd64 cpp amd64 4:10.2.1-1 [19.7 kB]
# Get:27 http://deb.debian.org/debian bullseye/main amd64 libcc1-0 amd64 10.2.1-6 [47.0 kB]
# Get:28 http://deb.debian.org/debian bullseye/main amd64 libgomp1 amd64 10.2.1-6 [99.9 kB]
# Get:29 http://deb.debian.org/debian bullseye/main amd64 libitm1 amd64 10.2.1-6 [25.8 kB]
# Get:30 http://deb.debian.org/debian bullseye/main amd64 libatomic1 amd64 10.2.1-6 [9008 B]
# Get:31 http://deb.debian.org/debian bullseye/main amd64 libasan6 amd64 10.2.1-6 [2065 kB]
# Get:32 http://deb.debian.org/debian bullseye/main amd64 liblsan0 amd64 10.2.1-6 [828 kB]
# Get:33 http://deb.debian.org/debian bullseye/main amd64 libtsan0 amd64 10.2.1-6 [2000 kB]
# Get:34 http://deb.debian.org/debian bullseye/main amd64 libubsan1 amd64 10.2.1-6 [777 kB]
# Get:35 http://deb.debian.org/debian bullseye/main amd64 libquadmath0 amd64 10.2.1-6 [145 kB]
# Get:36 http://deb.debian.org/debian bullseye/main amd64 libgcc-10-dev amd64 10.2.1-6 [2328 kB]
# Get:37 http://deb.debian.org/debian bullseye/main amd64 gcc-10 amd64 10.2.1-6 [17.0 MB]
# Get:38 http://deb.debian.org/debian bullseye/main amd64 gcc amd64 4:10.2.1-1 [5192 B]
# Get:39 http://deb.debian.org/debian bullseye/main amd64 libstdc++-10-dev amd64 10.2.1-6 [1741 kB]
# Get:40 http://deb.debian.org/debian bullseye/main amd64 g++-10 amd64 10.2.1-6 [9380 kB]
# Get:41 http://deb.debian.org/debian bullseye/main amd64 g++ amd64 4:10.2.1-1 [1644 B]
# Get:42 http://deb.debian.org/debian bullseye/main amd64 make amd64 4.3-4.1 [396 kB]
# Get:43 http://deb.debian.org/debian bullseye/main amd64 libdpkg-perl all 1.20.12 [1551 kB]
# Get:44 http://deb.debian.org/debian bullseye/main amd64 patch amd64 2.7.6-7 [128 kB]
# Get:45 http://deb.debian.org/debian bullseye/main amd64 dpkg-dev all 1.20.12 [2312 kB]
# Get:46 http://deb.debian.org/debian bullseye/main amd64 build-essential amd64 12.9 [7704 B]
# Get:47 http://deb.debian.org/debian bullseye/main amd64 libbrotli1 amd64 1.0.9-2+b2 [279 kB]
# Get:48 http://deb.debian.org/debian bullseye/main amd64 libsasl2-modules-db amd64 2.1.27+dfsg-2.1+deb11u1 [69.1 kB]
# Get:49 http://deb.debian.org/debian bullseye/main amd64 libsasl2-2 amd64 2.1.27+dfsg-2.1+deb11u1 [106 kB]
# Get:50 http://deb.debian.org/debian bullseye/main amd64 libldap-2.4-2 amd64 2.4.57+dfsg-3+deb11u1 [232 kB]
# Get:51 http://deb.debian.org/debian bullseye/main amd64 libnghttp2-14 amd64 1.43.0-1 [77.1 kB]
# Get:52 http://deb.debian.org/debian bullseye/main amd64 libpsl5 amd64 0.21.0-1.2 [57.3 kB]
# Get:53 http://deb.debian.org/debian bullseye/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-2+b2 [60.8 kB]
# Get:54 http://deb.debian.org/debian bullseye/main amd64 libssh2-1 amd64 1.9.0-2 [156 kB]
# Get:55 http://deb.debian.org/debian bullseye/main amd64 libcurl4 amd64 7.74.0-1.3+deb11u7 [346 kB]
# Get:56 http://deb.debian.org/debian bullseye/main amd64 curl amd64 7.74.0-1.3+deb11u7 [270 kB]
# Get:57 http://deb.debian.org/debian bullseye/main amd64 libcurl3-gnutls amd64 7.74.0-1.3+deb11u7 [343 kB]
# Get:58 http://deb.debian.org/debian bullseye/main amd64 libexpat1 amd64 2.2.10-2+deb11u5 [98.2 kB]
# Get:59 http://deb.debian.org/debian bullseye/main amd64 liberror-perl all 0.17029-1 [31.0 kB]
# Get:60 http://deb.debian.org/debian bullseye/main amd64 git-man all 1:2.30.2-1+deb11u2 [1828 kB]
# Get:61 http://deb.debian.org/debian bullseye/main amd64 git amd64 1:2.30.2-1+deb11u2 [5518 kB]
# Get:62 http://deb.debian.org/debian bullseye/main amd64 sudo amd64 1.9.5p2-3+deb11u1 [1061 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 80.7 MB in 1s (70.3 MB/s)
# Selecting previously unselected package perl-modules-5.32.
# (Reading database ... 6664 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.32_5.32.1-4+deb11u2_all.deb ...
# Unpacking perl-modules-5.32 (5.32.1-4+deb11u2) ...
# Selecting previously unselected package libgdbm6:amd64.
# Preparing to unpack .../01-libgdbm6_1.19-2_amd64.deb ...
# Unpacking libgdbm6:amd64 (1.19-2) ...
# Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.19-2_amd64.deb ...
# Unpacking libgdbm-compat4:amd64 (1.19-2) ...
# Selecting previously unselected package libperl5.32:amd64.
# Preparing to unpack .../03-libperl5.32_5.32.1-4+deb11u2_amd64.deb ...
# Unpacking libperl5.32:amd64 (5.32.1-4+deb11u2) ...
# Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.32.1-4+deb11u2_amd64.deb ...
# Unpacking perl (5.32.1-4+deb11u2) ...
# Selecting previously unselected package bzip2.
# Preparing to unpack .../05-bzip2_1.0.8-4_amd64.deb ...
# Unpacking bzip2 (1.0.8-4) ...
# Selecting previously unselected package openssl.
# Preparing to unpack .../06-openssl_1.1.1n-0+deb11u5_amd64.deb ...
# Unpacking openssl (1.1.1n-0+deb11u5) ...
# Selecting previously unselected package ca-certificates.
# Preparing to unpack .../07-ca-certificates_20210119_all.deb ...
# Unpacking ca-certificates (20210119) ...
# Selecting previously unselected package xz-utils.
# Preparing to unpack .../08-xz-utils_5.2.5-2.1~deb11u1_amd64.deb ...
# Unpacking xz-utils (5.2.5-2.1~deb11u1) ...
# Selecting previously unselected package binutils-common:amd64.
# Preparing to unpack .../09-binutils-common_2.35.2-2_amd64.deb ...
# Unpacking binutils-common:amd64 (2.35.2-2) ...
# Selecting previously unselected package libbinutils:amd64.
# Preparing to unpack .../10-libbinutils_2.35.2-2_amd64.deb ...
# Unpacking libbinutils:amd64 (2.35.2-2) ...
# Selecting previously unselected package libctf-nobfd0:amd64.
# Preparing to unpack .../11-libctf-nobfd0_2.35.2-2_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.35.2-2) ...
# Selecting previously unselected package libctf0:amd64.
# Preparing to unpack .../12-libctf0_2.35.2-2_amd64.deb ...
# Unpacking libctf0:amd64 (2.35.2-2) ...
# Selecting previously unselected package binutils-x86-64-linux-gnu.
# Preparing to unpack .../13-binutils-x86-64-linux-gnu_2.35.2-2_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.35.2-2) ...
# Selecting previously unselected package binutils.
# Preparing to unpack .../14-binutils_2.35.2-2_amd64.deb ...
# Unpacking binutils (2.35.2-2) ...
# Selecting previously unselected package libc-dev-bin.
# Preparing to unpack .../15-libc-dev-bin_2.31-13+deb11u6_amd64.deb ...
# Unpacking libc-dev-bin (2.31-13+deb11u6) ...
# Selecting previously unselected package linux-libc-dev:amd64.
# Preparing to unpack .../16-linux-libc-dev_5.10.179-1_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (5.10.179-1) ...
# Selecting previously unselected package libcrypt-dev:amd64.
# Preparing to unpack .../17-libcrypt-dev_1%3a4.4.18-4_amd64.deb ...
# Unpacking libcrypt-dev:amd64 (1:4.4.18-4) ...
# Selecting previously unselected package libtirpc-dev:amd64.
# Preparing to unpack .../18-libtirpc-dev_1.3.1-1+deb11u1_amd64.deb ...
# Unpacking libtirpc-dev:amd64 (1.3.1-1+deb11u1) ...
# Selecting previously unselected package libnsl-dev:amd64.
# Preparing to unpack .../19-libnsl-dev_1.3.0-2_amd64.deb ...
# Unpacking libnsl-dev:amd64 (1.3.0-2) ...
# Selecting previously unselected package libc6-dev:amd64.
# Preparing to unpack .../20-libc6-dev_2.31-13+deb11u6_amd64.deb ...
# Unpacking libc6-dev:amd64 (2.31-13+deb11u6) ...
# Selecting previously unselected package libisl23:amd64.
# Preparing to unpack .../21-libisl23_0.23-1_amd64.deb ...
# Unpacking libisl23:amd64 (0.23-1) ...
# Selecting previously unselected package libmpfr6:amd64.
# Preparing to unpack .../22-libmpfr6_4.1.0-3_amd64.deb ...
# Unpacking libmpfr6:amd64 (4.1.0-3) ...
# Selecting previously unselected package libmpc3:amd64.
# Preparing to unpack .../23-libmpc3_1.2.0-1_amd64.deb ...
# Unpacking libmpc3:amd64 (1.2.0-1) ...
# Selecting previously unselected package cpp-10.
# Preparing to unpack .../24-cpp-10_10.2.1-6_amd64.deb ...
# Unpacking cpp-10 (10.2.1-6) ...
# Selecting previously unselected package cpp.
# Preparing to unpack .../25-cpp_4%3a10.2.1-1_amd64.deb ...
# Unpacking cpp (4:10.2.1-1) ...
# Selecting previously unselected package libcc1-0:amd64.
# Preparing to unpack .../26-libcc1-0_10.2.1-6_amd64.deb ...
# Unpacking libcc1-0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../27-libgomp1_10.2.1-6_amd64.deb ...
# Unpacking libgomp1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libitm1:amd64.
# Preparing to unpack .../28-libitm1_10.2.1-6_amd64.deb ...
# Unpacking libitm1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../29-libatomic1_10.2.1-6_amd64.deb ...
# Unpacking libatomic1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libasan6:amd64.
# Preparing to unpack .../30-libasan6_10.2.1-6_amd64.deb ...
# Unpacking libasan6:amd64 (10.2.1-6) ...
# Selecting previously unselected package liblsan0:amd64.
# Preparing to unpack .../31-liblsan0_10.2.1-6_amd64.deb ...
# Unpacking liblsan0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libtsan0:amd64.
# Preparing to unpack .../32-libtsan0_10.2.1-6_amd64.deb ...
# Unpacking libtsan0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libubsan1:amd64.
# Preparing to unpack .../33-libubsan1_10.2.1-6_amd64.deb ...
# Unpacking libubsan1:amd64 (10.2.1-6) ...
# Selecting previously unselected package libquadmath0:amd64.
# Preparing to unpack .../34-libquadmath0_10.2.1-6_amd64.deb ...
# Unpacking libquadmath0:amd64 (10.2.1-6) ...
# Selecting previously unselected package libgcc-10-dev:amd64.
# Preparing to unpack .../35-libgcc-10-dev_10.2.1-6_amd64.deb ...
# Unpacking libgcc-10-dev:amd64 (10.2.1-6) ...
# Selecting previously unselected package gcc-10.
# Preparing to unpack .../36-gcc-10_10.2.1-6_amd64.deb ...
# Unpacking gcc-10 (10.2.1-6) ...
# Selecting previously unselected package gcc.
# Preparing to unpack .../37-gcc_4%3a10.2.1-1_amd64.deb ...
# Unpacking gcc (4:10.2.1-1) ...
# Selecting previously unselected package libstdc++-10-dev:amd64.
# Preparing to unpack .../38-libstdc++-10-dev_10.2.1-6_amd64.deb ...
# Unpacking libstdc++-10-dev:amd64 (10.2.1-6) ...
# Selecting previously unselected package g++-10.
# Preparing to unpack .../39-g++-10_10.2.1-6_amd64.deb ...
# Unpacking g++-10 (10.2.1-6) ...
# Selecting previously unselected package g++.
# Preparing to unpack .../40-g++_4%3a10.2.1-1_amd64.deb ...
# Unpacking g++ (4:10.2.1-1) ...
# Selecting previously unselected package make.
# Preparing to unpack .../41-make_4.3-4.1_amd64.deb ...
# Unpacking make (4.3-4.1) ...
# Selecting previously unselected package libdpkg-perl.
# Preparing to unpack .../42-libdpkg-perl_1.20.12_all.deb ...
# Unpacking libdpkg-perl (1.20.12) ...
# Selecting previously unselected package patch.
# Preparing to unpack .../43-patch_2.7.6-7_amd64.deb ...
# Unpacking patch (2.7.6-7) ...
# Selecting previously unselected package dpkg-dev.
# Preparing to unpack .../44-dpkg-dev_1.20.12_all.deb ...
# Unpacking dpkg-dev (1.20.12) ...
# Selecting previously unselected package build-essential.
# Preparing to unpack .../45-build-essential_12.9_amd64.deb ...
# Unpacking build-essential (12.9) ...
# Selecting previously unselected package libbrotli1:amd64.
# Preparing to unpack .../46-libbrotli1_1.0.9-2+b2_amd64.deb ...
# Unpacking libbrotli1:amd64 (1.0.9-2+b2) ...
# Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../47-libsasl2-modules-db_2.1.27+dfsg-2.1+deb11u1_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../48-libsasl2-2_2.1.27+dfsg-2.1+deb11u1_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../49-libldap-2.4-2_2.4.57+dfsg-3+deb11u1_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
# Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../50-libnghttp2-14_1.43.0-1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.43.0-1) ...
# Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../51-libpsl5_0.21.0-1.2_amd64.deb ...
# Unpacking libpsl5:amd64 (0.21.0-1.2) ...
# Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../52-librtmp1_2.4+20151223.gitfa8646d.1-2+b2_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
# Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../53-libssh2-1_1.9.0-2_amd64.deb ...
# Unpacking libssh2-1:amd64 (1.9.0-2) ...
# Selecting previously unselected package libcurl4:amd64.
# Preparing to unpack .../54-libcurl4_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking libcurl4:amd64 (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package curl.
# Preparing to unpack .../55-curl_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking curl (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../56-libcurl3-gnutls_7.74.0-1.3+deb11u7_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.74.0-1.3+deb11u7) ...
# Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../57-libexpat1_2.2.10-2+deb11u5_amd64.deb ...
# Unpacking libexpat1:amd64 (2.2.10-2+deb11u5) ...
# Selecting previously unselected package liberror-perl.
# Preparing to unpack .../58-liberror-perl_0.17029-1_all.deb ...
# Unpacking liberror-perl (0.17029-1) ...
# Selecting previously unselected package git-man.
# Preparing to unpack .../59-git-man_1%3a2.30.2-1+deb11u2_all.deb ...
# Unpacking git-man (1:2.30.2-1+deb11u2) ...
# Selecting previously unselected package git.
# Preparing to unpack .../60-git_1%3a2.30.2-1+deb11u2_amd64.deb ...
# Unpacking git (1:2.30.2-1+deb11u2) ...
# Selecting previously unselected package sudo.
# Preparing to unpack .../61-sudo_1.9.5p2-3+deb11u1_amd64.deb ...
# Unpacking sudo (1.9.5p2-3+deb11u1) ...
# Setting up libexpat1:amd64 (2.2.10-2+deb11u5) ...
# Setting up libpsl5:amd64 (0.21.0-1.2) ...
# Setting up perl-modules-5.32 (5.32.1-4+deb11u2) ...
# Setting up libbrotli1:amd64 (1.0.9-2+b2) ...
# Setting up binutils-common:amd64 (2.35.2-2) ...
# Setting up libnghttp2-14:amd64 (1.43.0-1) ...
# Setting up linux-libc-dev:amd64 (5.10.179-1) ...
# Setting up libctf-nobfd0:amd64 (2.35.2-2) ...
# Setting up libgomp1:amd64 (10.2.1-6) ...
# Setting up bzip2 (1.0.8-4) ...
# Setting up libasan6:amd64 (10.2.1-6) ...
# Setting up libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Setting up libtirpc-dev:amd64 (1.3.1-1+deb11u1) ...
# Setting up make (4.3-4.1) ...
# Setting up libmpfr6:amd64 (4.1.0-3) ...
# Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
# Setting up xz-utils (5.2.5-2.1~deb11u1) ...
# update-alternatives: using /usr/bin/xz to provide /usr/bin/lzma (lzma) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzma.1.gz because associated file /usr/share/man/man1/xz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/unlzma.1.gz because associated file /usr/share/man/man1/unxz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcat.1.gz because associated file /usr/share/man/man1/xzcat.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzmore.1.gz because associated file /usr/share/man/man1/xzmore.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzless.1.gz because associated file /usr/share/man/man1/xzless.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzdiff.1.gz because associated file /usr/share/man/man1/xzdiff.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcmp.1.gz because associated file /usr/share/man/man1/xzcmp.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzgrep.1.gz because associated file /usr/share/man/man1/xzgrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzegrep.1.gz because associated file /usr/share/man/man1/xzegrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzfgrep.1.gz because associated file /usr/share/man/man1/xzfgrep.1.gz (of link group lzma) doesn't exist
# Setting up libquadmath0:amd64 (10.2.1-6) ...
# Setting up libmpc3:amd64 (1.2.0-1) ...
# Setting up libatomic1:amd64 (10.2.1-6) ...
# Setting up patch (2.7.6-7) ...
# Setting up sudo (1.9.5p2-3+deb11u1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# Setting up libubsan1:amd64 (10.2.1-6) ...
# Setting up libnsl-dev:amd64 (1.3.0-2) ...
# Setting up libcrypt-dev:amd64 (1:4.4.18-4) ...
# Setting up git-man (1:2.30.2-1+deb11u2) ...
# Setting up libssh2-1:amd64 (1.9.0-2) ...
# Setting up libbinutils:amd64 (2.35.2-2) ...
# Setting up libisl23:amd64 (0.23-1) ...
# Setting up libc-dev-bin (2.31-13+deb11u6) ...
# Setting up openssl (1.1.1n-0+deb11u5) ...
# Setting up libcc1-0:amd64 (10.2.1-6) ...
# Setting up liblsan0:amd64 (10.2.1-6) ...
# Setting up cpp-10 (10.2.1-6) ...
# Setting up libitm1:amd64 (10.2.1-6) ...
# Setting up libgdbm6:amd64 (1.19-2) ...
# Setting up libtsan0:amd64 (10.2.1-6) ...
# Setting up libctf0:amd64 (2.35.2-2) ...
# Setting up libgcc-10-dev:amd64 (10.2.1-6) ...
# Setting up libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
# Setting up libcurl3-gnutls:amd64 (7.74.0-1.3+deb11u7) ...
# Setting up ca-certificates (20210119) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# Updating certificates in /etc/ssl/certs...
# 129 added, 0 removed; done.
# Setting up libgdbm-compat4:amd64 (1.19-2) ...
# Setting up libperl5.32:amd64 (5.32.1-4+deb11u2) ...
# Setting up cpp (4:10.2.1-1) ...
# Setting up libcurl4:amd64 (7.74.0-1.3+deb11u7) ...
# Setting up libc6-dev:amd64 (2.31-13+deb11u6) ...
# Setting up curl (7.74.0-1.3+deb11u7) ...
# Setting up binutils-x86-64-linux-gnu (2.35.2-2) ...
# Setting up libstdc++-10-dev:amd64 (10.2.1-6) ...
# Setting up binutils (2.35.2-2) ...
# Setting up perl (5.32.1-4+deb11u2) ...
# Setting up gcc-10 (10.2.1-6) ...
# Setting up libdpkg-perl (1.20.12) ...
# Setting up g++-10 (10.2.1-6) ...
# Setting up gcc (4:10.2.1-1) ...
# Setting up dpkg-dev (1.20.12) ...
# Setting up liberror-perl (0.17029-1) ...
# Setting up git (1:2.30.2-1+deb11u2) ...
# Setting up g++ (4:10.2.1-1) ...
# update-alternatives: using /usr/bin/g++ to provide /usr/bin/c++ (c++) in auto mode
# Setting up build-essential (12.9) ...
# Processing triggers for libc-bin (2.31-13+deb11u6) ...
# Processing triggers for ca-certificates (20210119) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
# done.
# WARN[0030] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 2b07476b440
# STEP 6/13: RUN echo $USERNAME ALL=\(root\) NOPASSWD:ALL > /etc/sudoers.d/$USERNAME     && chmod 0440 /etc/sudoers.d/$USERNAME
# WARN[0042] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> c5a46e8b520
# STEP 7/13: RUN mkdir -p /srv/conda && chown -R mambauser:1000 /srv/conda/
# WARN[0046] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> a13bc051eaf
# STEP 8/13: RUN mkdir -p /workspaces/command-line-tools/stac
# WARN[0051] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 9e19223d42c
# STEP 9/13: RUN chown -R 1000:1000 /workspaces/command-line-tools/stac
# WARN[0056] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> a06e299bcad
# STEP 10/13: USER mambauser
# WARN[0060] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 862fd9eec00
# STEP 11/13: RUN micromamba create -r /srv/conda -n env_stac -c conda-forge pystac python=3.9 pip &&     /srv/conda/envs/env_stac/bin/pip install rio_stac
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
#
# Transaction
#
#   Prefix: /srv/conda/envs/env_stac
#
#   Updating specs:
#
#    - pystac
#    - python=3.9
#    - pip
#
#
#   Package              Version  Build               Channel          Size
# ───────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex          0.1  conda_forge         conda-forge       3kB
#   + _openmp_mutex          4.5  2_gnu               conda-forge      24kB
#   + bzip2                1.0.8  h7f98852_4          conda-forge     496kB
#   + ca-certificates   2023.5.7  hbcca054_0          conda-forge     148kB
#   + ld_impl_linux-64      2.40  h41732ed_0          conda-forge     705kB
#   + libffi               3.4.2  h7f98852_5          conda-forge      58kB
#   + libgcc-ng           13.1.0  he5830b7_0          conda-forge     776kB
#   + libgomp             13.1.0  he5830b7_0          conda-forge     419kB
#   + libnsl               2.0.0  h7f98852_0          conda-forge      31kB
#   + libsqlite           3.42.0  h2797004_0          conda-forge     829kB
#   + libuuid             2.38.1  h0b41bf4_0          conda-forge      34kB
#   + libzlib             1.2.13  h166bdaf_4          conda-forge      66kB
#   + ncurses                6.3  h27087fc_1          conda-forge       1MB
#   + openssl              3.1.1  hd590300_1          conda-forge       3MB
#   + pip                 23.1.2  pyhd8ed1ab_0        conda-forge       1MB
#   + pystac               1.7.3  pyhd8ed1ab_0        conda-forge      99kB
#   + python              3.9.16  h2782a2a_0_cpython  conda-forge      24MB
#   + python-dateutil      2.8.2  pyhd8ed1ab_0        conda-forge     246kB
#   + readline               8.2  h8228510_1          conda-forge     281kB
#   + setuptools          67.7.2  pyhd8ed1ab_0        conda-forge     583kB
#   + six                 1.16.0  pyh6c4a22f_0        conda-forge      14kB
#   + tk                  8.6.12  h27826a3_0          conda-forge       3MB
#   + tzdata               2023c  h71feb2d_0          conda-forge     118kB
#   + wheel               0.40.0  pyhd8ed1ab_0        conda-forge      56kB
#   + xz                   5.2.6  h166bdaf_0          conda-forge     418kB
#
#   Summary:
#
#   Install: 25 packages
#
#   Total download: 38MB
#
# ───────────────────────────────────────────────────────────────────────────
#
#
# Confirm changes: [Y/n]
# Transaction starting
# Linking ld_impl_linux-64-2.40-h41732ed_0
# Linking _libgcc_mutex-0.1-conda_forge
# Linking ca-certificates-2023.5.7-hbcca054_0
# Linking libgomp-13.1.0-he5830b7_0
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-ng-13.1.0-he5830b7_0
# Linking openssl-3.1.1-hd590300_1
# Linking ncurses-6.3-h27087fc_1
# Linking libuuid-2.38.1-h0b41bf4_0
# Linking libffi-3.4.2-h7f98852_5
# Linking bzip2-1.0.8-h7f98852_4
# Linking xz-5.2.6-h166bdaf_0
# Linking libzlib-1.2.13-h166bdaf_4
# Linking libnsl-2.0.0-h7f98852_0
# Linking readline-8.2-h8228510_1
# Linking libsqlite-3.42.0-h2797004_0
# Linking tk-8.6.12-h27826a3_0
# Linking tzdata-2023c-h71feb2d_0
# Linking python-3.9.16-h2782a2a_0_cpython
# Linking wheel-0.40.0-pyhd8ed1ab_0
# Linking setuptools-67.7.2-pyhd8ed1ab_0
# Linking pip-23.1.2-pyhd8ed1ab_0
# Linking six-1.16.0-pyh6c4a22f_0
# Linking python-dateutil-2.8.2-pyhd8ed1ab_0
# Linking pystac-1.7.3-pyhd8ed1ab_0
#
# Transaction finished
#
# To activate this environment, use:
#
#     micromamba activate env_stac
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -n env_stac mycommand
#
# Collecting rio_stac
#   Downloading rio_stac-0.8.0-py3-none-any.whl (10 kB)
# Collecting rasterio (from rio_stac)
#   Downloading rasterio-1.3.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: pystac<2.0.0,>=1.0.0 in /srv/conda/envs/env_stac/lib/python3.9/site-packages (from rio_stac) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/envs/env_stac/lib/python3.9/site-packages (from pystac<2.0.0,>=1.0.0->rio_stac) (2.8.2)
# Collecting affine (from rasterio->rio_stac)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting attrs (from rasterio->rio_stac)
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 9.7 MB/s eta 0:00:00
# Collecting certifi (from rasterio->rio_stac)
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 19.2 MB/s eta 0:00:00
# Collecting click>=4.0 (from rasterio->rio_stac)
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 22.0 MB/s eta 0:00:00
# Collecting cligj>=0.5 (from rasterio->rio_stac)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting numpy>=1.18 (from rasterio->rio_stac)
#   Downloading numpy-1.24.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 39.2 MB/s eta 0:00:00
# Collecting snuggs>=1.4.1 (from rasterio->rio_stac)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting click-plugins (from rasterio->rio_stac)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /srv/conda/envs/env_stac/lib/python3.9/site-packages (from rasterio->rio_stac) (67.7.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/env_stac/lib/python3.9/site-packages (from python-dateutil>=2.7.0->pystac<2.0.0,>=1.0.0->rio_stac) (1.16.0)
# Collecting pyparsing>=2.1.6 (from snuggs>=1.4.1->rasterio->rio_stac)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 22.9 MB/s eta 0:00:00
# Installing collected packages: pyparsing, numpy, click, certifi, attrs, affine, snuggs, cligj, click-plugins, rasterio, rio_stac
# Successfully installed affine-2.4.0 attrs-23.1.0 certifi-2023.5.7 click-8.1.3 click-plugins-1.1.1 cligj-0.7.2 numpy-1.24.3 pyparsing-3.0.9 rasterio-1.3.7 rio_stac-0.8.0 snuggs-1.4.7
# WARN[0101] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 8c5f1c20cb4
# STEP 12/13: ADD water-bodies/command-line-tools/stac/app.py /workspaces/command-line-tools/stac/app.py
# WARN[0134] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> bfd52126d8a
# STEP 13/13: WORKDIR /home/mambauser
# COMMIT simonevaccari/stac:0.1.0
# WARN[0144] SHELL is not supported for OCI image format, [/usr/local/bin/_dockerfile_shell.sh] will be ignored. Must use `docker` format
# --> 31d30935081
# Successfully tagged localhost/simonevaccari/stac:0.1.0
# 31d309350812510dc5c62772e4691a6a9d1bcadf853ae2a51a251638ad20e487

# %% [markdown]
# ## Application Package inspection
#
# Open the `app-package.cwl` Application Package and familiarise yourself with its structure, to understand what's going on during execution:
#
# 1. Inspect the main workflow which `id` is **`water_bodies`**:
#     1.1. What are the input parameters? *(stac_items, aoi, epsg)*
#     1.2. What are the steps of this workflow? *(node_water_bodies, node_stac)*
# 2. Inspect the workflow which `id` is **`detect_water_body`**:
#     2.1. What are the steps of this workflow? *(node_crop, node_normalized_difference, node_otsu)*
# 3. Inspect each of the `CommandLineTool` of `id`: **`crop`**, **`norm_diff`**, **`otsu`** and **`stac`**
#     3.1. Inspect each of the `Dockerfile`

# %%
print('Dockers built successfully:')
# !docker images
# Out:
# Dockers built successfully:
# /usr/bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# REPOSITORY                         TAG         IMAGE ID      CREATED         SIZE
# localhost/simonevaccari/stac       0.1.0       31d309350812  4 minutes ago   1.24 GB
# localhost/simonevaccari/otsu       0.1.0       9ee6e0707783  6 minutes ago   2.44 GB
# localhost/simonevaccari/norm_diff  0.1.0       3f4f8923266c  11 minutes ago  2.08 GB
# localhost/simonevaccari/crop       0.1.0       1fa483aa5638  14 minutes ago  2.08 GB
# docker.io/mambaorg/micromamba      latest      bcfdda4930c6  2 weeks ago     98.2 MB

# %% [markdown]
# ## Application Package execution
#
# The water bodies Application Package can be executed with:
# ```
# cwltool --no-container app-package.cwl#water_bodies params.yml > out.json
# ```
# where:
# * `cwltool` is a Common Workflow Language runner.
# * The flag `--no-container` is used to instruct `cwltool` to use the local command-line tools instead of using the containers.
# * `app-package.cwl#water_bodies` defines the CWL file to execute as well as the entry point after the `#` symbol. Here it's the `Workflow` with the id `water_bodies`.
# * The file **`params.yml`** is used to define the input parameters. In this case, these are:
#
# ```
# stac_items:
# - "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_10TFK_20210713_0_L2A"
# - "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20220524_0_L2A"
#
# aoi: "-121.399,39.834,-120.74,40.472"
# epsg: "EPSG:4326"
# ```
# * `out.json` is used to store the execution logs

# %%
# Execute the app-package with the local modules without using containers
# !cwltool --no-container water-bodies/app-package.cwl#water_bodies water-bodies/params.yml > out.json

# %%
# Execute the app-package with containers
# !cwltool water-bodies/app-package.cwl#water_bodies water-bodies/params.yml > out.json

# %% [markdown]
# ## Result inspection
#
# The execution of the `cwltool` generates the output `out.json` file, as well as a folder which name is a 8-character alphanumeric string. In this folder are stored the generated `catalog.json` and the `otsu.tif` and related STAC item for each of the two input Sentinel-2 images, in the structure below:
# * `catalog.json`
# * `S2A_10TFK_20220524_0_L2A`
#     * `otsu.tif`
#     * `S2A_10TFK_20220524_0_L2A.json`
# * `S2A_10TFK_20220524_0_L2A`
#     * `otsu.tif`
#     * `S2A_10TFK_20220524_0_L2A`

# %% [markdown]
# You can plot the output `otsu.tif` files with the `visualisation.ipynb` Jupyter Notebook. This Notebook uses `pystac` to access the geotiffs produced, `leafmap` to plot the tiles served by a local tile server. Open the Notebook and run all cells.
#
# First, run the commands below to create the environment:

# %%
# "VISUALISATION" environment
# !mamba create -c conda-forge -y -q -p /srv/conda/envs/env_visual pystac ipykernel jupyterlab localtileserver jupyter-server-proxy pip && \
    /srv/conda/envs/env_visual/bin/pip install leafmap

# %%
# Import liraries
from localtileserver import TileClient, get_leaflet_tile_layer
import leafmap.foliumap as leafmap

import pystac
import json
import numpy as np
import os

# Define env variables for localtileserver
os.environ["GTIFF_SRS_SOURCE"] = "EPSG"
os.environ['LOCALTILESERVER_CLIENT_PREFIX'] = 'proxy/{port}'
os.environ['PROJ_DATA'] = '/srv/conda/envs/env_visual/share/proj/'
os.environ['GDAL_DATA'] = '/srv/conda/envs/env_visual/share/gdal/'

# %% [markdown]
# **Note** if you get a `ModuleNotFoundError: No module named 'localtileserver'` error: click on **Kernel** on the top tab, click on **Change Kernel...** and select `Python [conda env:env_visual]`. Then re-run the cell above.

# %% [markdown]
# Load the JSON result listing generated by `cwltool`:

# %%
with open("out.json") as f: 
    results = json.load(f)

# %% [markdown]
# Look for the `catalog.json` file:

# %%
for item in results["stac_catalog"]["listing"]:
    
    if item['basename'] == "catalog.json":
        catalog = pystac.read_file(item["path"])
        break

# %% [markdown]
# List the contents of the STAC Catalog

# %%
catalog.describe()

# %%
it1 = catalog.get_item('S2B_10TFK_20210713_0_L2A')
it1

# %%
it1.properties

# %%
m = leafmap.Map()

for item in catalog.get_all_items():
    m.add_raster(item.get_assets()["data"].get_absolute_href(), layer_name=item.id) #, crs="EPSG:32610")

m
